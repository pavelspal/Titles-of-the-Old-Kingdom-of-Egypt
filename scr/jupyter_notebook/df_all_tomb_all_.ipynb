# %% [markdown]
# # Merge of all dataframes related to "tomb"

# %% [markdown]
# This notebook aims to merge all dataframes that are related to "tomb" in Maatbase database. Specifically:
#
# - df_tomb
# - df_tomb_chapel
# - df_tomb_osiris
# - df_tomb_statue_material
# - df_tomb_dim
# - df_tomb_king_name

# %% [markdown]
# ### database schema

# %% [markdown]
# ![title](db_schema\Maatbase_schema_colored.svg)

# %% [markdown]
# ### imports and load

# %%
import os
import numpy as np
import pandas as pd
import set_path
import supp.support_load as sl
from supp.support_merge import merge, group_to_list, merge_get_prefix, merge_add_prefix
from supp.support_save import save_df
from supp.support_analyzer import make_excel_analysis

# %%
dfs, dfs_name, dfs_export_date = sl.load_pickle()
iton, ntoi = sl.get_name_dicts(dfs_name)
dfs_export_date
# Out:
# Pickle database loaded.
# '2024-10-11'

# %%
df_tomb = dfs[ntoi['df_tomb']]
df_tomb_chapel = dfs[ntoi['df_tomb_chapel']]
df_tomb_osiris = dfs[ntoi['df_tomb_osiris']]
df_tomb_statue_material = dfs[ntoi['df_tomb_statue_material']]
df_tomb_dim = dfs[ntoi['df_tomb_dim']]
df_tomb_king_name = dfs[ntoi['df_tomb_king_name']]

# %% [markdown]
# ### heads of dataframes

# %%
df_tomb.head(2)
# Out:
#   tomb_code        tomb_type                     provenance excavator  \
# 1      AC 3  pyramid complex   Raneferef's papyrus archive        NaN
# 7     AC 14  pyramid complex  papyrus archive of Khentkaus        NaN
#
#   excavation_year spacial_distribution number_of_shafts label_of_shaft  \
# 1             NaN                  NaN              NaN            NaN
# 7             NaN                  NaN              NaN            NaN
#
#   type_of_decoration ch_workmanship ch_false_door presence_of_wife embracing  \
# 1                NaN            NaN           NaN              NaN       NaN
# 7                NaN            NaN           NaN              NaN       NaN
#
#    statues curiosity servant_statues A40_great_god tomb_code_id  catalogized
# 1      NaN       NaN             NaN           NaN         AC 3         True
# 7      NaN       NaN             NaN           NaN        AC 14         True

# %%
df_tomb_chapel.head(2)
# Out:
#     tomb_code_id chapel_dimensions  chapel_area chapel_dimension_certainty  \
# 0  tomb of Nefer           unknown          NaN                        NaN
# 1          AC 17   6.9×0.8+1.0×1.3         6.65                        NaN
#
#     length    width
# 0  unknown  unknown
# 1      6.9      0.8

# %%
df_tomb_osiris.head(2)
# Out:
#   tomb_code_id   Osiris
# 0        AC 17  epithet
# 1         AS 7  epithet

# %%
df_tomb_statue_material.head(2)
# Out:
#   tomb_code_id statue_material
# 0       G 2150      travertine
# 1       AS 68d       limestone

# %%
df_tomb_dim.head(2)
# Out:
#     tomb_code_id tomb_dimensions tomb_dimension_certainty  tomb_area   length  \
# 0  tomb of Nefer         unknown                      NaN        NaN  unknown
# 1          AC 17        11.7×7.4                      NaN      86.58     11.7
#
#      width
# 0  unknown
# 1      7.4

# %%
df_tomb_king_name.head(2)
# Out:
#    ID_official tomb_code_id         source dynasty
# 0            4         AC 3  personal name     V.5
# 1           16         AC 2  personal name     V.3

# %% [markdown]
# ### preparing df_tomb_chapel for merge

# %% [markdown]
# #### removing invalid rows from df_tomb_chapel

# %%
df_tomb_chapel.shape
# Out:
# (347, 6)

# %%
# invalid values
invalid_values = [np.nan, pd.NA, 'unknown', '×', 'nn', 'no superstructure', 'unobservable', 'unexcavated', 'undetectable', 'destroyed', 'unobesrvable']
# invalid tomb recors
# 'No. 24 = D 38' has only chapel_area value
# 'No. 39 = C 16' has only length value
tomb_code_id_to_omit = ['No. 24 = D 38', 'No. 39 = C 16', 'G 4461']

# %%
# show tombs with issues
df_tomb_chapel[df_tomb_chapel['tomb_code_id'].isin(tomb_code_id_to_omit + ['H 2 = LS 17'])]
# Out:
#       tomb_code_id              chapel_dimensions  chapel_area  \
# 114  No. 24 = D 38                   unobservable         2.05
# 143    H 2 = LS 17                    13.50×5.60?        75.60
# 170  No. 39 = C 16                         4.35×?          NaN
# 305         G 4461  S 2044,S 2045, S 2046, S 2047         2.44
# 306         G 4461  S 2044,S 2045, S 2046, S 2047         2.44
# 307         G 4461  S 2044,S 2045, S 2046, S 2047         2.44
#
#     chapel_dimension_certainty        length         width
# 114                         ca  unobservable  unobservable
# 143                        NaN          13.5           NaN
# 170                        NaN          4.35           NaN
# 305                        NaN           NaN        2044.0
# 306                        NaN           NaN        2045.0
# 307                        NaN           NaN           NaN

# %%
# get all columns except tomb_code_id
columns = [col for col in df_tomb_chapel if col != 'tomb_code_id']

# remove rows where all values are in invalid_values
mask = df_tomb_chapel[columns].isin(invalid_values).all(axis=1)
df_tomb_chapel_v2 = df_tomb_chapel[~mask]

# remove insufficiently described tombs
mask2 = df_tomb_chapel_v2['tomb_code_id'].isin(tomb_code_id_to_omit)
df_tomb_chapel_v2 = df_tomb_chapel_v2[~mask2]

# tomb 'H 2 = LS 17' has potentionaly known width
df_tomb_chapel_v2.loc[df_tomb_chapel_v2['tomb_code_id']=='H 2 = LS 17', 'width'] = 5.6

df_tomb_chapel_v2.shape
# Out:
# (271, 6)

# %%
# removed rows
print(df_tomb_chapel[mask].shape)
df_tomb_chapel[mask][:10]
# Out:
# (71, 6)
#       tomb_code_id chapel_dimensions  chapel_area chapel_dimension_certainty  \
# 0    tomb of Nefer           unknown          NaN                        NaN
# 3             AC 1           unknown          NaN                        NaN
# 7             AC 2           unknown          NaN                        NaN
# 8             AC 4           unknown          NaN                        NaN
# 15            nn 0           unknown          NaN                        NaN
# 16            nn 1           unknown          NaN                        NaN
# 17    tomb of Imem           unknown          NaN                        NaN
# 22            nn 2           unknown          NaN                        NaN
# 29          G 2086                 ×          NaN                        NaN
# 37  AS 68, shaft 4                nn          NaN                        NaN
#
#      length    width
# 0   unknown  unknown
# 3   unknown  unknown
# 7   unknown  unknown
# 8   unknown  unknown
# 15  unknown  unknown
# 16  unknown  unknown
# 17  unknown  unknown
# 22  unknown  unknown
# 29      NaN      NaN
# 37       nn       nn

# %% [markdown]
# #### recalculate area

# %%
df_tomb_chapel_v2.head()
# Out:
#   tomb_code_id chapel_dimensions  chapel_area chapel_dimension_certainty  \
# 1        AC 17   6.9×0.8+1.0×1.3         6.65                        NaN
# 2        AC 17   6.9×0.8+1.0×1.3         6.65                        NaN
# 4         AC 5           4.7×2.1         9.87                        NaN
# 5         AC 8         5.24×3.50        18.34                        NaN
# 6         AC 9         5.26×2.12        11.15                        NaN
#
#   length width
# 1    6.9   0.8
# 2    1.0   1.3
# 4    4.7   2.1
# 5   5.24   3.5
# 6   5.26  2.12

# %%
df_tomb_chapel_v2 = df_tomb_chapel_v2[['tomb_code_id', 'length', 'width']]
# recalculate area
df_tomb_chapel_v2['chapel_area_total'] = df_tomb_chapel_v2.apply(lambda x: round(x['length']*x['width'], 2), axis=1)
# calculate sum of area for aech tomb
df_tomb_chapel_v2['chapel_area_total_sum'] = df_tomb_chapel_v2.groupby('tomb_code_id')['chapel_area_total'].transform('sum')
# calculate number of chaper per tomb
df_tomb_chapel_v2['n_tomb_chapel'] = df_tomb_chapel_v2.groupby('tomb_code_id')['chapel_area_total'].transform('size')

# %%
df_tomb_chapel_v2.head()
# Out:
#   tomb_code_id length width  chapel_area_total  chapel_area_total_sum  \
# 1        AC 17    6.9   0.8               5.52                   6.82
# 2        AC 17    1.0   1.3               1.30                   6.82
# 4         AC 5    4.7   2.1               9.87                  16.37
# 5         AC 8   5.24   3.5              18.34                  18.34
# 6         AC 9   5.26  2.12              11.15                  11.15
#
#    n_tomb_chapel
# 1              2
# 2              2
# 4              2
# 5              1
# 6              1

# %% [markdown]
# #### add prefix and columns convert to list

# %%
# add prefix
prefix = merge_get_prefix(df_tomb_chapel)
df_tomb_chapel_v2 = merge_add_prefix(df_tomb_chapel_v2, prefix)

# %%
df_tomb_chapel_v2.head()
# Out:
#   tomb_code_id 03_length 03_width  03_chapel_area_total  \
# 1        AC 17       6.9      0.8                  5.52
# 2        AC 17       1.0      1.3                  1.30
# 4         AC 5       4.7      2.1                  9.87
# 5         AC 8      5.24      3.5                 18.34
# 6         AC 9      5.26     2.12                 11.15
#
#    03_chapel_area_total_sum  03_n_tomb_chapel
# 1                      6.82                 2
# 2                      6.82                 2
# 4                     16.37                 2
# 5                     18.34                 1
# 6                     11.15                 1

# %%
# duplicates will be removed outomatecali in next step
df_tomb_chapel_v2[df_tomb_chapel_v2.duplicated(keep=False)]
# Out:
#          tomb_code_id 03_length 03_width  03_chapel_area_total  \
# 102            G 8974      10.0      1.0                 10.00
# 103            G 8974      10.0      1.0                 10.00
# 373  mastaba of Remni       4.3      1.2                  5.16
# 374  mastaba of Remni       4.3      1.2                  5.16
#
#      03_chapel_area_total_sum  03_n_tomb_chapel
# 102                     20.00                 2
# 103                     20.00                 2
# 373                     10.32                 2
# 374                     10.32                 2

# %%
print(f'shape={df_tomb_chapel_v2.shape}, df_tomb_chapel_v2 shape')
# group attributes and possitions into list
df_tomb_chapel_all = group_to_list(df_tomb_chapel_v2, ['tomb_code_id'])
print(f'shape={df_tomb_chapel_all.shape}, group into list according to tomb_code_id')
df_tomb_chapel_all.head()
# Out:
# shape=(271, 6), df_tomb_chapel_v2 shape
# shape=(243, 6), group into list according to tomb_code_id
#   tomb_code_id 03_length_list 03_width_list 03_chapel_area_total_list  \
# 0        AC 15    [2.78, 3.5]  [1.56, 1.59]              [4.42, 5.46]
# 1        AC 17     [1.0, 6.9]    [0.8, 1.3]               [1.3, 5.52]
# 2        AC 18          [2.4]         [1.6]                    [3.84]
# 3        AC 19          [2.3]         [1.4]                    [3.22]
# 4        AC 22         [11.4]        [21.1]                  [240.54]
#
#   03_chapel_area_total_sum_list 03_n_tomb_chapel_list
# 0           [9.879999999999999]                   [2]
# 1           [6.819999999999999]                   [2]
# 2                        [3.84]                   [1]
# 3                        [3.22]                   [1]
# 4                      [240.54]                   [1]

# %% [markdown]
# ### preparing df_tomb_osiris for merge

# %%
df_tomb_osiris_v2 = df_tomb_osiris.drop_duplicates()

# %%
print(df_tomb_osiris.shape)
print(df_tomb_osiris_v2.shape)
# Out:
# (200, 2)
# (180, 2)

# %%
df_tomb_osiris_v2.head()
# Out:
#   tomb_code_id            Osiris
# 0        AC 17           epithet
# 1         AS 7           epithet
# 2        AC 15  offering formula
# 3         AC 4           epithet
# 4         nn 0  offering formula

# %%
df_tomb_osiris_v2['Osiris'].value_counts()
# Out:
# Osiris
# offering formula    121
# epithet              58
# title                 1
# Name: count, dtype: int64

# %%
df_tomb_osiris_v2['Osiris'].isna().sum()
# Out:
# 0

# %%
df_tomb_osiris_v2['tomb_code_id'].duplicated().sum()
# Out:
# 35

# %%
# add prefix
prefix = merge_get_prefix(df_tomb_osiris)
df_tomb_osiris_v2 = merge_add_prefix(df_tomb_osiris_v2, prefix)

# %%
print(f'shape={df_tomb_osiris.shape}, df_tomb_osiris shape')
print(f'shape={df_tomb_osiris_v2.shape}, df_tomb_osiris_v2 shape')
# group attributes and possitions into list
df_tomb_osiris_all = group_to_list(df_tomb_osiris_v2, ['tomb_code_id'])
print(f'shape={df_tomb_osiris_all.shape}, group into list according to tomb_code_id')
df_tomb_osiris_all.head()
# Out:
# shape=(200, 2), df_tomb_osiris shape
# shape=(180, 2), df_tomb_osiris_v2 shape
# shape=(145, 2), group into list according to tomb_code_id
#   tomb_code_id               04_Osiris_list
# 0        AC 15           [offering formula]
# 1        AC 17                    [epithet]
# 2         AC 4                    [epithet]
# 3        AS 16  [epithet, offering formula]
# 4        AS 19                    [epithet]

# %% [markdown]
# ### preparing df_tomb_statue_material for merge

# %%
df_tomb_statue_material_v2 = df_tomb_statue_material.drop_duplicates()

# %%
df_tomb_statue_material_v2.shape
# Out:
# (40, 2)

# %%
df_tomb_statue_material_v2.head()
# Out:
#   tomb_code_id statue_material
# 0       G 2150      travertine
# 1       AS 68d       limestone
# 3       G 5080      travertine
# 4       G 5080       limestone
# 5       G 5080         granite

# %%
df_tomb_statue_material_v2['statue_material'].value_counts()
# Out:
# statue_material
# limestone     22
# travertine     6
# wood           6
# granite        5
# diorite        1
# Name: count, dtype: int64

# %%
df_tomb_statue_material_v2['statue_material'].isna().sum()
# Out:
# 0

# %%
df_tomb_statue_material_v2['tomb_code_id'].duplicated().sum()
# Out:
# 8

# %%
# add prefix
prefix = merge_get_prefix(df_tomb_statue_material)
df_tomb_statue_material_v2 = merge_add_prefix(df_tomb_statue_material_v2, prefix)

# %%
print(f'shape={df_tomb_statue_material.shape}, df_tomb_statue_material shape')
print(f'shape={df_tomb_statue_material_v2.shape}, df_tomb_statue_material_v2 shape')
# group attributes and possitions into list
df_tomb_statue_material_all = group_to_list(df_tomb_statue_material_v2, ['tomb_code_id'])
print(f'shape={df_tomb_statue_material_all.shape}, group into list according to tomb_code_id')
df_tomb_statue_material_all.head()
# Out:
# shape=(45, 2), df_tomb_statue_material shape
# shape=(40, 2), df_tomb_statue_material_v2 shape
# shape=(32, 2), group into list according to tomb_code_id
#   tomb_code_id         05_statue_material_list
# 0       AS 104                     [limestone]
# 1       AS 68d                     [limestone]
# 2        AS 98                          [wood]
# 3        D 208                       [granite]
# 4         D 47  [diorite , granite, limestone]

# %% [markdown]
# ### preparing df_tomb_dim for merge

# %%
print(df_tomb_dim.shape)
df_tomb_dim.head()
# Out:
# (354, 6)
#     tomb_code_id tomb_dimensions tomb_dimension_certainty  tomb_area   length  \
# 0  tomb of Nefer         unknown                      NaN        NaN  unknown
# 1          AC 17        11.7×7.4                      NaN      86.58     11.7
# 2           AC 1         unknown                      NaN        NaN  unknown
# 3           AC 5         16×18.3                      NaN     292.80     16.0
# 4           AC 8    42.24×56.24                       NaN    2375.60    42.24
#
#      width
# 0  unknown
# 1      7.4
# 2  unknown
# 3     18.3
# 4    56.24

# %%
df_tomb_dim[df_tomb_dim['tomb_code_id'].duplicated(keep=False)].sort_values(['tomb_code_id', 'tomb_area', 'length'])
# Out:
#         tomb_code_id                                    tomb_dimensions  \
# 108    G 5230 = L 40                            41.25×12.78+11.38×10.90
# 107    G 5230 = L 40                            41.25×12.78+11.38×10.90
# 173           G 5270                                 25.3×13.0+4.5×3.10
# 172           G 5270                                 25.3×13.0+4.5×3.10
# 70            G 6042                                  11.7×5.7+12.5×2.5
# 71            G 6042                                  11.7×5.7+12.5×2.5
# 75            G 8882                                 9.3×5.36+20.8×23.0
# 76            G 8882                                 9.3×5.36+20.8×23.0
# 64            G 8911                                    8.4×6.0+4.3×3.4
# 63            G 8911                                    8.4×6.0+4.3×3.4
# 197              M 8                                    3×3.2, 6.00×4.7
# 198              M 8                                    3×3.2, 6.00×4.7
# 217             QC 1                                1.93×1.56+7.40×4.00
# 218             QC 1                                1.93×1.56+7.40×4.00
# 200           tomb 1  forecourt 3.5×2.1+chapel+4.20×3.15, 6.25×0.95+...
# 199           tomb 1  forecourt 3.5×2.1+chapel+4.20×3.15, 6.25×0.95+...
# 345  tomb of Iyenher                        3.6×2.25+2.35×082+2.58×1.29
# 346  tomb of Iyenher                        3.6×2.25+2.35×082+2.58×1.29
# 344  tomb of Iyenher                        3.6×2.25+2.35×082+2.58×1.29
# 235   tomb of Mereri                                8.14×5.61+2.81×2.52
# 234   tomb of Mereri                                8.14×5.61+2.81×2.52
#
#     tomb_dimension_certainty  tomb_area length  width
# 108                      NaN     651.22  11.38   10.9
# 107                      NaN     651.22  41.25  12.78
# 173                       ca     342.85    4.5    3.1
# 172                       ca     342.85   25.3   13.0
# 70                       NaN      97.94   11.7    5.7
# 71                       NaN      97.94   12.5    2.5
# 75                        ca     528.25    9.3   5.36
# 76                        ca     528.25   20.8   23.0
# 64                       NaN      65.02    4.3    3.4
# 63                       NaN      65.02    8.4    6.0
# 197                      NaN     125.43    3.0    3.2
# 198                      NaN     125.43    6.0    4.7
# 217                      NaN      32.69   1.93   1.56
# 218                      NaN      32.69    7.4    4.0
# 200                       ca     107.81   6.25    NaN
# 199                       ca     107.81    NaN    NaN
# 345                      NaN      13.36   2.35   82.0
# 346                      NaN      13.36   2.58   1.29
# 344                      NaN      13.36    3.6   2.25
# 235                      NaN      52.76   2.81   2.52
# 234                      NaN      52.76   8.14   5.61

# %%
count_of_all_rooms_ids = df_tomb_dim.loc[df_tomb_dim['tomb_dimensions']=='count of all rooms', 'tomb_code_id'].to_list()
df_tomb_dim[df_tomb_dim['tomb_code_id'].isin(count_of_all_rooms_ids)]
# Out:
#            tomb_code_id     tomb_dimensions tomb_dimension_certainty  \
# 88        G 8154 = L 89  count of all rooms                       ca
# 98        G 8172 = L 86  count of all rooms                       ca
# 99               G 8130  count of all rooms                      NaN
# 100      G 8090 = LG 90  count of all rooms                      NaN
# 102              G 8460  count of all rooms                       ca
# 106       G 8080 = L 92  count of all rooms                       ca
# 342  tomb of Akhethotep  count of all rooms                      NaN
#
#      tomb_area length width
# 88       50.16    NaN   NaN
# 98       58.78    NaN   NaN
# 99         NaN    NaN   NaN
# 100        NaN    NaN   NaN
# 102      54.85    NaN   NaN
# 106      66.22    NaN   NaN
# 342      22.88    NaN   NaN

# %% [markdown]
# #### removing invalid rows from df_tomb_dim

# %%
# invalid values
invalid_values = [np.nan, 'unknown', '×', 'nn', 'no superstructure', 'unobservable', 'unexcavated', 'undetectable', 'destroyed', 'undetectable                      ', '', 'incomplete excavation']
# invalid tomb recors
tomb_code_id_to_omit = ['tomb of Merefnebef', 'No. 65 = D 17', 'D 17']

# %%
df_tomb_dim[df_tomb_dim['tomb_code_id'].isin(tomb_code_id_to_omit)]
# Out:
#            tomb_code_id tomb_dimensions tomb_dimension_certainty  tomb_area  \
# 41   tomb of Merefnebef           7.80×                      NaN       54.6
# 305       No. 65 = D 17          52.20×                      NaN        NaN
# 306                D 17          52.20×                      NaN        NaN
#
#     length width
# 41     7.8   NaN
# 305   52.2   NaN
# 306   52.2   NaN

# %%
# get all columns except tomb_code_id
columns = [col for col in df_tomb_dim if col != 'tomb_code_id']

# remove rows where all values are in invalid_values
mask = df_tomb_dim[columns].isin(invalid_values) | df_tomb_dim[columns].isna()
mask = mask.all(axis=1) 
df_tomb_dim_v2 = df_tomb_dim[~mask]

# remove insufficiently described tombs
mask2 = df_tomb_dim_v2['tomb_code_id'].isin(tomb_code_id_to_omit)
df_tomb_dim_v2 = df_tomb_dim_v2[~mask2]

# remove rows with 'tomb_dimensions'=='count of all rooms'
# later put it back
df_tomb_dim_v2 = df_tomb_dim_v2[df_tomb_dim_v2['tomb_dimensions']!='count of all rooms']

df_tomb_dim_v2.shape
# Out:
# (258, 6)

# %%
df_tomb_dim_v2[50:100]
# Out:
#           tomb_code_id          tomb_dimensions tomb_dimension_certainty  \
# 59              G 8954                 14.5×8.3                      NaN
# 60              G 8912                  8.4×6.1                      NaN
# 61              G 8910                 15.7×7.5                      NaN
# 62              G 8926               11.80×8.30                      NaN
# 63              G 8911          8.4×6.0+4.3×3.4                      NaN
# 64              G 8911          8.4×6.0+4.3×3.4                      NaN
# 65              G 8990                5.45×3.45                      NaN
# 66              G 8980               13.20×7.58                      NaN
# 67              G 8976                 13.2×8.5                       ca
# 68              G 8983                  8.3×3.4                      NaN
# 69              G 6030              99.69×39.18                      NaN
# 70              G 6042        11.7×5.7+12.5×2.5                      NaN
# 71              G 6042        11.7×5.7+12.5×2.5                      NaN
# 72              G 7152              16.92×11.75                      NaN
# 73      No. 63 = D 19               41.20×13.80                      NaN
# 74         D 70 = L 15              59.21×32.61                      NaN
# 75              G 8882       9.3×5.36+20.8×23.0                       ca
# 76              G 8882       9.3×5.36+20.8×23.0                       ca
# 77               AS 39              21.90×11.50                      NaN
# 78   mastaba of Inumin              11.50×12.00                      NaN
# 79              G 5470               15.60×7.00                      NaN
# 80               AC 26              21.00×15.85                       ca
# 81              G 5170              24.00×12.60                      NaN
# 82              G 4650                  21×8.40                      NaN
# 83              G 4840              23.60×11.00                      NaN
# 84       G 2378 = L 26              23.00×12.00                      NaN
# 85        No. 48 = C 1              37.75×20.20                      NaN
# 87              G 8900               11.80×7.75                      NaN
# 89                D 37                10.7×10.0                      NaN
# 90              G 4520                 22.8×9.9                      NaN
# 91               D 203                  9.7×4.0                      NaN
# 92               D 208                  8.5×5.4                       ca
# 93               D 207                  7.7×7.5                       ca
# 95              G 8975                  9.3×7.5                      NaN
# 96              G 8974                 20.5×3.5                       ca
# 97              G 8960               23.50×13.5                      NaN
# 101             G 8934              19.00×13.00                      NaN
# 107      G 5230 = L 40  41.25×12.78+11.38×10.90                      NaN
# 108      G 5230 = L 40  41.25×12.78+11.38×10.90                      NaN
# 109      G 8158 = L 87               12.00×6.00                       ca
# 110               D 62              19.60×19.20                      NaN
# 112             G 7391                 11.4×7.0                      NaN
# 113              AC 30              16.12×10.70                      NaN
# 114      No. 60 = D 22              40.40×33.50                      NaN
# 115             AS 76b                8.00×5.65                      NaN
# 116               D 64              26.00×24.00                      NaN
# 117               D 63              27.40×22.20                      NaN
# 119      No. 62 = D 20              37.15×18.40                      NaN
# 121             G 2370              22.80×20.90                      NaN
# 123     G 5340 = LG 37               32.5×14.00                      NaN
#
#      tomb_area length  width
# 59      120.35   14.5    8.3
# 60       51.24    8.4    6.1
# 61      117.75   15.7    7.5
# 62       97.94   11.8    8.3
# 63       65.02    8.4    6.0
# 64       65.02    4.3    3.4
# 65       18.80   5.45   3.45
# 66      100.06   13.2   7.58
# 67      112.20   13.2    8.5
# 68       28.22    8.3    3.4
# 69      138.87  99.69  39.18
# 70       97.94   11.7    5.7
# 71       97.94   12.5    2.5
# 72      198.81  16.92  11.75
# 73      568.56   41.2   13.8
# 74     1930.84  59.21  32.61
# 75      528.25    9.3   5.36
# 76      528.25   20.8   23.0
# 77      251.85   21.9   11.5
# 78      138.00   11.5   12.0
# 79      109.20   15.6    7.0
# 80      332.96   21.0  15.85
# 81      302.40   24.0   12.6
# 82      176.40   21.0    8.4
# 83      259.60   23.6   11.0
# 84      276.00   23.0   12.0
# 85      762.55  37.75   20.2
# 87      101.00   11.8   7.75
# 89      107.00   10.7   10.0
# 90      225.72   22.8    9.9
# 91       38.80    9.7    4.0
# 92       45.90    8.5    5.4
# 93       57.75    7.7    7.5
# 95       69.75    9.3    7.5
# 96       71.75   20.5    3.5
# 97      317.25   23.5   13.5
# 101     247.00   19.0   13.0
# 107     651.22  41.25  12.78
# 108     651.22  11.38   10.9
# 109      72.00   12.0    6.0
# 110     376.32   19.6   19.2
# 112      79.80   11.4    7.0
# 113     172.48  16.12   10.7
# 114    1125.70   40.4   33.5
# 115      45.20    8.0   5.65
# 116     624.00   26.0   24.0
# 117     608.28   27.4   22.2
# 119     683.56  37.15   18.4
# 121     476.52   22.8   20.9
# 123     455.00   32.5   14.0

# %% [markdown]
# #### recalculate area

# %%
df_tomb_dim_v2.head()
# Out:
#   tomb_code_id tomb_dimensions tomb_dimension_certainty  tomb_area length  \
# 1        AC 17        11.7×7.4                      NaN      86.58   11.7
# 3         AC 5         16×18.3                      NaN     292.80   16.0
# 4         AC 8    42.24×56.24                       NaN    2375.60  42.24
# 5         AC 9     23.10×16.30                      NaN     376.53   23.1
# 8        AC 18        15.8×9.1                      NaN     143.80   15.8
#
#    width
# 1    7.4
# 3   18.3
# 4  56.24
# 5   16.3
# 8    9.1

# %%
df_tomb_dim_v2 = df_tomb_dim_v2[['tomb_code_id', 'length', 'width']]
# recalculate area
df_tomb_dim_v2['tomb_area_total'] = df_tomb_dim_v2.apply(lambda x: round(x['length']*x['width'], 2), axis=1)
# calculate sum of area for aech tomb
df_tomb_dim_v2['tomb_area_total_sum'] = df_tomb_dim_v2.groupby('tomb_code_id')['tomb_area_total'].transform('sum')
# calculate number of chaper per tomb
df_tomb_dim_v2['n_tomb'] = df_tomb_dim_v2.groupby('tomb_code_id')['tomb_area_total'].transform('size')
df_tomb_dim_v2.shape
# Out:
# (258, 6)

# %%
df_tomb_dim_v2.head()
# Out:
#   tomb_code_id length  width  tomb_area_total  tomb_area_total_sum  n_tomb
# 1        AC 17   11.7    7.4            86.58                86.58       1
# 3         AC 5   16.0   18.3           292.80               292.80       1
# 4         AC 8  42.24  56.24          2375.58              2375.58       1
# 5         AC 9   23.1   16.3           376.53               376.53       1
# 8        AC 18   15.8    9.1           143.78               143.78       1

# %%
print(f'shape={df_tomb_dim_v2.shape}, df_tomb_dim_v2 shape')
df1 = df_tomb_dim.loc[df_tomb_dim['tomb_dimensions']=='count of all rooms', ['tomb_code_id', 'length', 'width', 'tomb_area']]
df1.rename(columns={'tomb_area': 'tomb_area_total'}, inplace=True)
df_tomb_dim_v3 = pd.concat([df_tomb_dim_v2, df1])
print(f'shape={df_tomb_dim_v3.shape}, df_tomb_dim_v3 shape')
# Out:
# shape=(258, 6), df_tomb_dim_v2 shape
# shape=(265, 6), df_tomb_dim_v3 shape

# %% [markdown]
# #### add prefix and columns convert to list

# %%
# add prefix
prefix = merge_get_prefix(df_tomb_dim)
df_tomb_dim_v3 = merge_add_prefix(df_tomb_dim_v3, prefix)

# %%
df_tomb_dim_v3[df_tomb_dim_v3.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [tomb_code_id, 06_length, 06_width, 06_tomb_area_total, 06_tomb_area_total_sum, 06_n_tomb]
# Index: []

# %%
df_tomb_dim_v3[df_tomb_dim_v3['06_n_tomb']>1]
# Out:
#         tomb_code_id 06_length 06_width  06_tomb_area_total  \
# 63            G 8911       8.4      6.0               50.40
# 64            G 8911       4.3      3.4               14.62
# 70            G 6042      11.7      5.7               66.69
# 71            G 6042      12.5      2.5               31.25
# 75            G 8882       9.3     5.36               49.85
# 76            G 8882      20.8     23.0              478.40
# 107    G 5230 = L 40     41.25    12.78              527.17
# 108    G 5230 = L 40     11.38     10.9              124.04
# 172           G 5270      25.3     13.0              328.90
# 173           G 5270       4.5      3.1               13.95
# 197              M 8       3.0      3.2                9.60
# 198              M 8       6.0      4.7               28.20
# 199           tomb 1       NaN      NaN                 NaN
# 200           tomb 1      6.25      NaN                 NaN
# 217             QC 1      1.93     1.56                3.01
# 218             QC 1       7.4      4.0               29.60
# 234   tomb of Mereri      8.14     5.61               45.67
# 235   tomb of Mereri      2.81     2.52                7.08
# 344  tomb of Iyenher       3.6     2.25                8.10
# 345  tomb of Iyenher      2.35     82.0              192.70
# 346  tomb of Iyenher      2.58     1.29                3.33
#
#      06_tomb_area_total_sum  06_n_tomb
# 63                    65.02        2.0
# 64                    65.02        2.0
# 70                    97.94        2.0
# 71                    97.94        2.0
# 75                   528.25        2.0
# 76                   528.25        2.0
# 107                  651.21        2.0
# 108                  651.21        2.0
# 172                  342.85        2.0
# 173                  342.85        2.0
# 197                   37.80        2.0
# 198                   37.80        2.0
# 199                    0.00        2.0
# 200                    0.00        2.0
# 217                   32.61        2.0
# 218                   32.61        2.0
# 234                   52.75        2.0
# 235                   52.75        2.0
# 344                  204.13        3.0
# 345                  204.13        3.0
# 346                  204.13        3.0

# %%
print(f'shape={df_tomb_dim_v3.shape}, df_tomb_dim_v3 shape')
# group attributes and possitions into list
df_tomb_dim_all = group_to_list(df_tomb_dim_v3, ['tomb_code_id'])
print(f'shape={df_tomb_dim_all.shape}, group into list according to tomb_code_id')
df_tomb_dim_all.head()
# Out:
# shape=(265, 6), df_tomb_dim_v3 shape
# shape=(254, 6), group into list according to tomb_code_id
#   tomb_code_id 06_length_list 06_width_list 06_tomb_area_total_list  \
# 0        AC 10        [32.04]       [16.44]                [526.74]
# 1        AC 15         [18.7]       [10.42]                [194.85]
# 2        AC 16         [12.3]         [9.1]                [111.93]
# 3        AC 17         [11.7]         [7.4]                 [86.58]
# 4        AC 18         [15.8]         [9.1]                [143.78]
#
#   06_tomb_area_total_sum_list 06_n_tomb_list
# 0                    [526.74]          [1.0]
# 1                    [194.85]          [1.0]
# 2                    [111.93]          [1.0]
# 3                     [86.58]          [1.0]
# 4                    [143.78]          [1.0]

# %% [markdown]
# ### preparing df_tomb_king_name for merge

# %%
df_general = dfs[0]
id_officials = df_tomb_king_name['ID_official'].to_list()
id_officials = list(set(id_officials))
df_general[df_general['ID_official'].isin(id_officials)]
# Out:
#        buried complete_to_date           dynasty find_number  ID_official  \
# 3         NaN              NaN  late 5 – early 6         NaN            4
# 15        NaN              NaN       late 5 or 6         NaN           16
# 43        NaN              NaN            late 5         NaN           44
# 44        NaN              NaN             mid 5         NaN           45
# 56        NaN              NaN             mid 5         NaN           57
# ...       ...              ...               ...         ...          ...
# 5370      NaN              NaN            late 5         NaN         5453
# 5374      NaN              NaN            late 5         NaN         5457
# 5378      NaN              NaN            late 5         NaN         5461
# 5411  certain              NaN            late 5         NaN         5494
# 5418  certain       09.10.2024             mid 5         NaN         5501
#
#       ID_person             king                              locality  \
# 3           325              NaN                        Central Abusir
# 15          336              NaN                        Central Abusir
# 43          358        Djedkare?                        Central Abusir
# 44          359         Nyuserre                        Central Abusir
# 56          371         Nyuserre                        Central Abusir
# ...         ...              ...                                   ...
# 5370        315  Djedkare – Unis  North Saqqara, north of Step Pyramid
# 5374        315  Djedkare – Unis  North Saqqara, north of Step Pyramid
# 5378        317              NaN                      Western Cemetery
# 5411       4964             Unis                         Gisr el-Mudir
# 5418       4967         Nyuserre                      Western Cemetery
#
#      mentioned  nome  owner shaft_main     site uncertain  \
# 3          NaN  1 LE    NaN        NaN   Abusir       NaN
# 15         NaN  1 LE    NaN        NaN   Abusir       NaN
# 43         NaN  1 LE    NaN        NaN   Abusir       NaN
# 44         yes  1 LE    NaN        NaN   Abusir       NaN
# 56         yes  1 LE    NaN        NaN   Abusir       NaN
# ...        ...   ...    ...        ...      ...       ...
# 5370       NaN  1 LE  owner        NaN  Saqqara       NaN
# 5374       NaN  1 LE  owner        NaN  Saqqara       NaN
# 5378       yes  1 LE    NaN        NaN     Giza       NaN
# 5411       NaN  1 LE    NaN         no  Saqqara       NaN
# 5418       NaN  1 LE    NaN         no     Giza       NaN
#
#                 tomb_code_id  name_id
# 3                       AC 3        2
# 15                      AC 2       11
# 43                      AC 3       31
# 44                      AC 8       32
# 56                      AC 8       41
# ...                      ...      ...
# 5370           No. 14 = D 43     2415
# 5374           No. 14 = D 43     2415
# 5378                  G 4761       61
# 5411  mastaba of Ptahshepses      562
# 5418                   D 208      562
#
# [424 rows x 16 columns]

# %%
df_tomb_king_name.shape
# Out:
# (685, 4)

# %%
df_tomb_king_name[df_tomb_king_name['ID_official'].duplicated(keep=False)]
# Out:
#      ID_official     tomb_code_id                                   source  \
# 22           118             AS 4                            personal name
# 24           142            AC 17                       title – sun temple
# 30           205             AC 5                    priestly title – king
# 31           238             AC 8                            personal name
# 32           238             AC 8                            personal name
# ..           ...              ...                                      ...
# 680         5091         G 2100-I                            personal name
# 681         5320             D 51                                  epithet
# 682         5444  tomb of Hermeru                                  epithet
# 683         3813           G 7101  title – affiliation to pyramid complex
# 684         5320             D 51                    priestly title – king
#
#     dynasty
# 22      V.8
# 24      V.3
# 30      V.2
# 31     IV.6
# 32      V.2
# ..      ...
# 680    IV.2
# 681     V.1
# 682     V.9
# 683    VI.2
# 684     V.1
#
# [413 rows x 4 columns]

# %%
df = pd.merge(df_general, df_tomb, on='tomb_code_id', suffixes=('_00', '_01'))
df = pd.merge(df, df_tomb_king_name, on='tomb_code_id', suffixes=('_01', '_02'))
df = df[['ID_official_01', 'ID_official_02', 'tomb_code_id']]
df[100:150]
# Out:
#      ID_official_01  ID_official_02 tomb_code_id
# 100              38             299         AC 8
# 101              38             300         AC 8
# 102              38             348         AC 8
# 103              38             356         AC 8
# 104              38             385         AC 8
# 105              38             447         AC 8
# 106              38             448         AC 8
# 107              38             507         AC 8
# 108              38            3612         AC 8
# 109              38            5051         AC 8
# 110              41              45         AC 8
# 111              41              57         AC 8
# 112              41             103         AC 8
# 113              41             104         AC 8
# 114              41             169         AC 8
# 115              41             238         AC 8
# 116              41             238         AC 8
# 117              41             238         AC 8
# 118              41             238         AC 8
# 119              41             263         AC 8
# 120              41             264         AC 8
# 121              41             298         AC 8
# 122              41             299         AC 8
# 123              41             300         AC 8
# 124              41             348         AC 8
# 125              41             356         AC 8
# 126              41             385         AC 8
# 127              41             447         AC 8
# 128              41             448         AC 8
# 129              41             507         AC 8
# 130              41            3612         AC 8
# 131              41            5051         AC 8
# 132              45              45         AC 8
# 133              45              57         AC 8
# 134              45             103         AC 8
# 135              45             104         AC 8
# 136              45             169         AC 8
# 137              45             238         AC 8
# 138              45             238         AC 8
# 139              45             238         AC 8
# 140              45             238         AC 8
# 141              45             263         AC 8
# 142              45             264         AC 8
# 143              45             298         AC 8
# 144              45             299         AC 8
# 145              45             300         AC 8
# 146              45             348         AC 8
# 147              45             356         AC 8
# 148              45             385         AC 8
# 149              45             447         AC 8

# %% [markdown]
# ### merge tomb

# %%
df_tomb['tomb_code_id'].duplicated().sum()
# Out:
# 0

# %%
df_tomb_chapel.duplicated().sum()
# Out:
# 0

# %%
df_tomb_chapel_all
df_tomb_osiris_all
df_tomb_statue_material_all
df_tomb_dim_all
# Out:
#                tomb_code_id 06_length_list 06_width_list  \
# 0                     AC 10        [32.04]       [16.44]
# 1                     AC 15         [18.7]       [10.42]
# 2                     AC 16         [12.3]         [9.1]
# 3                     AC 17         [11.7]         [7.4]
# 4                     AC 18         [15.8]         [9.1]
# ..                      ...            ...           ...
# 249  tomb of Neferherenptah         [16.0]        [10.2]
# 250         tomb of Semdent          [6.6]        [5.35]
# 251         tomb of Tjetetu         [5.55]        [6.45]
# 252          tomb of Tjetji          [7.2]         [4.9]
# 253            unnumbered 1        [545.0]       [278.0]
#
#     06_tomb_area_total_list 06_tomb_area_total_sum_list 06_n_tomb_list
# 0                  [526.74]                    [526.74]          [1.0]
# 1                  [194.85]                    [194.85]          [1.0]
# 2                  [111.93]                    [111.93]          [1.0]
# 3                   [86.58]                     [86.58]          [1.0]
# 4                  [143.78]                    [143.78]          [1.0]
# ..                      ...                         ...            ...
# 249                 [163.2]                     [163.2]          [1.0]
# 250                 [35.31]                     [35.31]          [1.0]
# 251                  [35.8]                      [35.8]          [1.0]
# 252                 [35.28]                     [35.28]          [1.0]
# 253              [151510.0]                  [151510.0]          [1.0]
#
# [254 rows x 6 columns]

# %%
print(f'shape={df_tomb.shape}, df_tomb shape')
# merge df_tomb and df_tomb_chapel_all
df_tomb_all = merge(df_tomb, df_tomb_chapel_all, on='tomb_code_id')
print(f'shape={df_tomb_all.shape}, merge df_tomb and df_tomb_chapel_all')
# merge df_tomb_all and df_tomb_chapel_v2
df_tomb_all = merge(df_tomb_all, df_tomb_osiris_all, on='tomb_code_id')
print(f'shape={df_tomb_all.shape}, merge df_tomb_all and df_tomb_osiris_all')
# merge df_tomb_all and df_tomb_statue_material_all
df_tomb_all = merge(df_tomb_all, df_tomb_statue_material_all, on='tomb_code_id')
print(f'shape={df_tomb_all.shape}, merge df_tomb_all and df_tomb_statue_material_all')
# merge df_tomb_all and df_tomb_statue_material_all
df_tomb_all = merge(df_tomb_all, df_tomb_dim_all, on='tomb_code_id')
print(f'shape={df_tomb_all.shape}, merge df_tomb_all and df_tomb_dim_all')
df_tomb_all.columns.to_list()
# Out:
# shape=(903, 19), df_tomb shape
# shape=(903, 24), merge df_tomb and df_tomb_chapel_all
# shape=(903, 25), merge df_tomb_all and df_tomb_osiris_all
# shape=(903, 26), merge df_tomb_all and df_tomb_statue_material_all
# shape=(903, 31), merge df_tomb_all and df_tomb_dim_all
# ['01_tomb_code',
#  '01_tomb_type',
#  '01_provenance',
#  '01_excavator',
#  '01_excavation_year',
#  '01_spacial_distribution',
#  '01_number_of_shafts',
#  '01_label_of_shaft',
#  '01_type_of_decoration',
#  '01_ch_workmanship',
#  '01_ch_false_door',
#  '01_presence_of_wife',
#  '01_embracing',
#  '01_statues',
#  '01_curiosity',
#  '01_servant_statues',
#  '01_A40_great_god',
#  'tomb_code_id',
#  '01_catalogized',
#  '03_length_list',
#  '03_width_list',
#  '03_chapel_area_total_list',
#  '03_chapel_area_total_sum_list',
#  '03_n_tomb_chapel_list',
#  '04_Osiris_list',
#  '05_statue_material_list',
#  '06_length_list',
#  '06_width_list',
#  '06_tomb_area_total_list',
#  '06_tomb_area_total_sum_list',
#  '06_n_tomb_list']

# %%
df_tomb_all.head()
# Out:
#   01_tomb_code     01_tomb_type                   01_provenance  \
# 0         AC 3  pyramid complex    Raneferef's papyrus archive
# 1        AC 14  pyramid complex   papyrus archive of Khentkaus
# 2           nn          unknown                   tomb of Nefer
# 3         AS 4    stone mastaba  tomb of Rahotep and Izeziseneb
# 4        AS 10    stone mastaba                     tomb of Iti
#
#      01_excavator 01_excavation_year 01_spacial_distribution  \
# 0             NaN                NaN                     NaN
# 1             NaN                NaN                     NaN
# 2             NaN                NaN                     NaN
# 3  Miroslav Bárta                NaN                     NaN
# 4  Miroslav Bárta                NaN                     NaN
#
#   01_number_of_shafts 01_label_of_shaft 01_type_of_decoration  \
# 0                 NaN               NaN                   NaN
# 1                 NaN               NaN                   NaN
# 2                 NaN               NaN                   NaN
# 3                 NaN               NaN                   NaN
# 4                 NaN               NaN                   NaN
#
#   01_ch_workmanship  ... 03_chapel_area_total_list  \
# 0               NaN  ...                       NaN
# 1               NaN  ...                       NaN
# 2               NaN  ...                       NaN
# 3               NaN  ...                       NaN
# 4               NaN  ...                       NaN
#
#   03_chapel_area_total_sum_list 03_n_tomb_chapel_list  04_Osiris_list  \
# 0                           NaN                   NaN             NaN
# 1                           NaN                   NaN             NaN
# 2                           NaN                   NaN             NaN
# 3                           NaN                   NaN             NaN
# 4                           NaN                   NaN             NaN
#
#   05_statue_material_list 06_length_list 06_width_list  \
# 0                     NaN            NaN           NaN
# 1                     NaN            NaN           NaN
# 2                     NaN            NaN           NaN
# 3                     NaN            NaN           NaN
# 4                     NaN            NaN           NaN
#
#   06_tomb_area_total_list  06_tomb_area_total_sum_list 06_n_tomb_list
# 0                     NaN                          NaN            NaN
# 1                     NaN                          NaN            NaN
# 2                     NaN                          NaN            NaN
# 3                     NaN                          NaN            NaN
# 4                     NaN                          NaN            NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### save result

# %%
f_name = r'df_tomb_all'
save_df(df_tomb_all, f_name)
make_excel_analysis(df_tomb_all, f_name)
# Out:
# Dataframe saved into C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\df_tomb_all.csv
# continuous_names={'01_statues'}
# Excel analysis save into C:\Users\Stoja\OneDrive\Documents\diplomka\scr\excel_dfs_description\df_tomb_all.xlsx
