# %% [markdown]
# # Encoding title to clusters

# %% [markdown]
# **Motivation:** Encode 35_title column into clusters

# %%
import os
import numpy as np
import pandas as pd
import set_path
import supp.support_load as sl
from supp.support_load import read_csv, read_excel
from supp.support_merge import merge, group_to_list
from supp.support_save import save_df
from supp.support_analyzer import make_excel_analysis
from supp.support_get_mapping import get_category_aggregation

# %%
dfs, dfs_name, dfs_export_date = sl.load_pickle()
iton, ntoi = sl.get_name_dicts(dfs_name)
dfs_export_date
# Out:
# Pickle database loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\dfs_complete.pickle
# Applied preprocessing: merge_on_jones
# Applied preprocessing: remove_jones_duplicates
# '2024-10-11'

# %% [markdown]
# ### Load title map

# %%
map_title = read_csv('map_title')
print(f'{map_title.shape}\tmap_title shape')
map_title.head()
# Out:
# CSV file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\data_map\map_title.csv
# (2219, 6)	map_title shape
#    ID_title          title                    translation_of_title  \
# 0         1  ... iry cA-pr                                     NaN
# 1         2  ... n Hwt-wrt  ... of the great court/Hall of Justice
# 2         3       ... nb.f                                     NaN
# 3         4       ... ncwt                                     NaN
# 4         5      ... pr-aA                  ... of the Great House
#
#                                    type              category    sub_category
# 0                                   NaN                   NaN  no subcategory
# 1  administrative title – legal matters  administrative title   legal matters
# 2                               epithet               epithet  no subcategory
# 3                                   NaN                   NaN  no subcategory
# 4                                   NaN                   NaN  no subcategory

# %%
map_title[map_title['title'].duplicated(keep=False)]
# Out:
#       ID_title         title                             translation_of_title  \
# 388        460  imy-rA gc(w)  overseer of a gang/side (phyle/gang of workers)
# 2157      2293  imy-rA gc(w)                      overseer of leather-workers
#
#                                                type category    sub_category
# 388   administrative title – organization of labour      NaN  no subcategory
# 2157                                            NaN      NaN             NaN

# %%
# title to category
category_dict = map_title.set_index('title')['category'].to_dict()
len(category_dict)
# Out:
# 2218

# %%
# title category to cluster
cluster_dict = get_category_aggregation()
cluster_dict[np.nan] = ''
len(cluster_dict)
cluster_dict
# Out:
# {'priestly title': 'priest',
#  'administrative title': 'administration',
#  'epithet': 'epithet',
#  'rank title': 'rank',
#  'family relation': 'family',
#  'privy to the secret': 'privy',
#  'honorific title': 'rank',
#  'royal affiliation': 'rank',
#  'privacy of king': 'privy',
#  'craft': 'worker',
#  'body care': 'worker',
#  'household management': 'worker',
#  'entertainment': 'worker',
#  'physician': 'worker',
#  'privacy of great house': 'privy',
#  'religious title': 'priest',
#  'epithet of queen': 'epithet',
#  'municipal administration': 'administration',
#  'education': 'worker',
#  'privacy of palace': 'privy',
#  'legal matters': 'administration',
#  'farming': 'worker',
#  'uncertain': 'uncertain',
#  'foreign land': 'administration',
#  nan: ''}

# %%
# encode tile to cluster
ttoc = {title: cluster_dict[category_dict[title]] for title in map_title['title']}
print(len(ttoc))
# Out:
# 2218

# %% [markdown]
# ### Make pivot table

# %%
map_title['cluster'] = map_title['category'].map(cluster_dict)
# show result map
map_title.head()
# Out:
#    ID_title          title                    translation_of_title  \
# 0         1  ... iry cA-pr                                     NaN
# 1         2  ... n Hwt-wrt  ... of the great court/Hall of Justice
# 2         3       ... nb.f                                     NaN
# 3         4       ... ncwt                                     NaN
# 4         5      ... pr-aA                  ... of the Great House
#
#                                    type              category    sub_category  \
# 0                                   NaN                   NaN  no subcategory
# 1  administrative title – legal matters  administrative title   legal matters
# 2                               epithet               epithet  no subcategory
# 3                                   NaN                   NaN  no subcategory
# 4                                   NaN                   NaN  no subcategory
#
#           cluster
# 0
# 1  administration
# 2         epithet
# 3
# 4

# %%
# inspect uncertain
map_title[map_title['cluster']=='uncertain']
# Out:
#       ID_title           title           translation_of_title  \
# 9           10           ...tT                            NaN
# 10          15         [Hm]t.f                       his wife
# 2066      2193  imy-rA Hwt mHa  overseer of the house of flax
#
#                  type   category    sub_category    cluster
# 9           uncertain  uncertain  no subcategory  uncertain
# 10    family relation  uncertain  no subcategory  uncertain
# 2066              NaN  uncertain  no subcategory  uncertain

# %%
# cluster "family relation" as "family" 
map_title.loc[map_title['type']=='family relation', 'cluster'] = 'family'

# %%
# drop uncertain type
map_title.loc[map_title['cluster']=='uncertain', 'cluster'] = np.nan

# %%
# checl that all uncertain were renamed
map_title[map_title['cluster']=='uncertain']
# Out:
# Empty DataFrame
# Columns: [ID_title, title, translation_of_title, type, category, sub_category, cluster]
# Index: []

# %%
map_title['cluster'].value_counts().sum()
# Out:
# 2217

# %%
map_title['cluster'].value_counts()
# Out:
# cluster
#                   654
# administration    427
# priest            348
# epithet           289
# family            163
# worker            125
# privy             117
# rank               94
# Name: count, dtype: int64

# %%
# load df_person_title
df_person_title = dfs[ntoi['df_person_title']]
print(f'{df_person_title.shape} original shape')
df_person_title.drop_duplicates(keep='first', inplace=True)
print(f'{df_person_title.shape} shape after dropped duplicates')
df_person_title.head()
# Out:
# (14182, 3) original shape
# (14119, 3) shape after dropped duplicates
#    ID_official  ID_title  ID_person
# 0          748     290.0        888
# 1            1     247.0        322
# 2            2     316.0        323
# 3            2     283.0        323
# 4            4     316.0        325

# %%
# print shape of df_person_title map 
print(f'shape={df_person_title.shape}, df_person_title shape')
print(f'shape={df_person_title["ID_person"].unique().shape}, uniques persons shape')
print(f'shape={df_person_title["ID_title"].unique().shape}, uniques titles shape')
# remove duplicates
df_titles_all = df_person_title[['ID_person', 'ID_title']]
df_titles_all.head()
# Out:
# shape=(14119, 3), df_person_title shape
# shape=(3998,), uniques persons shape
# shape=(2184,), uniques titles shape
#    ID_person  ID_title
# 0        888     290.0
# 1        322     247.0
# 2        323     316.0
# 3        323     283.0
# 4        325     316.0

# %%
data = df_titles_all.merge(map_title, on='ID_title', how='left')
data['cluster'] = data['cluster'].replace('', 'none')
print(data.shape)
data.head()
# Out:
# (14119, 8)
#    ID_person  ID_title        title  \
# 0        888     290.0   Smcw pr-aA
# 1        322     247.0  iry xt ncwt
# 2        323     316.0       xnty-S
# 3        323     283.0     pr(y)-aA
# 4        325     316.0       xnty-S
#
#                                 translation_of_title        type  \
# 0                        follower of the Great House         NaN
# 1                     property custodian of the king  rank title
# 2  land-tenant/tenant-landholder, xnty-S official...         NaN
# 3                       Belonging to the Great Court         NaN
# 4  land-tenant/tenant-landholder, xnty-S official...         NaN
#
#                category    sub_category         cluster
# 0                   NaN  no subcategory            none
# 1  administrative title   legal matters  administration
# 2                   NaN  no subcategory            none
# 3            rank title  no subcategory            rank
# 4                   NaN  no subcategory            none

# %%
encoding_to = 'cluster'
data_job = data[['ID_person', encoding_to]].copy()
pivot_table_counts = data_job.pivot_table(index='ID_person', columns=encoding_to, aggfunc='size', fill_value=0)
# save pivot_table_counts
save_df(pivot_table_counts, f'person_title_{encoding_to}_pivot_v2', save_index=True)

data_job.drop_duplicates(inplace=True)
pivot_table = data_job.pivot_table(index='ID_person', columns=encoding_to, aggfunc='size', fill_value=0)
# save pivot_table_counts
save_df(pivot_table_counts, f'person_title_{encoding_to}_ohe_v2', save_index=True)
# Out:
# Dataframe saved into C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\person_title_cluster_pivot_v2.csv
# Dataframe saved into C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\person_title_cluster_ohe_v2.csv

# %%
print(pivot_table_counts.shape)
pivot_table_counts.head()
# Out:
# (3977, 8)
# cluster    administration  epithet  family  none  priest  privy  rank  worker
# ID_person
# 1                      16       12       4    20      24     11     7       6
# 2                       0        3       4     4       3      0     2       0
# 4                       8        4       0     7       3      0     2       0
# 5                       6        4       0     4       0      0     2       0
# 6                       1        4       5    11       3      0     0       1

# %%
pivot_table.head()
# Out:
# cluster    administration  epithet  family  none  priest  privy  rank  worker
# ID_person
# 1                       1        1       1     1       1      1     1       1
# 2                       0        1       1     1       1      0     1       0
# 4                       1        1       0     1       1      0     1       0
# 5                       1        1       0     1       0      0     1       0
# 6                       1        1       1     1       1      0     0       1

# %% [markdown]
# ### merge vizier to pivot_table_counts

# %%
vizier = read_csv('vizier')
print(vizier.shape)
vizier.head()
# Out:
# CSV file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\unpacked\df_person_all\vizier.csv
# (4962, 2)
#    ID_person  vizier
# 0        322       0
# 1        323       0
# 2        324       0
# 3        325       0
# 4        326       0

# %%
vizier_pivot_table_counts = pd.merge(vizier, pivot_table_counts.reset_index(), on='ID_person')
vizier_pivot_table_counts
# Out:
#       ID_person  vizier  administration  epithet  family  none  priest  privy  \
# 0           322       0               1        0       0     0       0      0
# 1           323       0               0        0       0     1       0      0
# 2           325       0               0        0       0     1       0      0
# 3           326       0               0        0       0     1       0      0
# 4           327       0               0        0       0     0       1      0
# ...         ...     ...             ...      ...     ...   ...     ...    ...
# 3972       4959       0               0        0       0     0       1      0
# 3973       4960       0               3        0       0     0       0      0
# 3974       4961       0               1        1       0     1       0      0
# 3975       4962       0               2        0       0     8       0      2
# 3976        319       0               3        1       0     3       0      1
#
#       rank  worker
# 0        0       0
# 1        1       0
# 2        0       0
# 3        0       0
# 4        0       0
# ...    ...     ...
# 3972     0       0
# 3973     0       0
# 3974     1       1
# 3975     2       0
# 3976     0       2
#
# [3977 rows x 10 columns]

# %%
workers = vizier_pivot_table_counts[vizier_pivot_table_counts['worker']>0]
print(workers.shape)
workers[workers['vizier']==1]
# Out:
# (387, 10)
#       ID_person  vizier  administration  epithet  family  none  priest  privy  \
# 117           1       1              16       12       4    20      24     11
# 123          56       1               0        2       0     5       0      2
# 705        1242       1               5       11       2     9       7      1
# 880         117       1               6        6       2     5       6      4
# 1116       1686       1              12        6       5    12      11      6
# 1152        240       1               4        5       0     7       3      1
# 1252         29       1               4        6       1     7       0      3
# 1359       1926       1               4        0       0     5       7      1
# 1586       2183       1              11        4       2     7       3      6
# 1615         70       1               8        6       1    10       5      5
# 1616       2216       1               7        0       0     5       2      2
# 1641       2254       1              11        8       1     8       8      3
# 1833         62       1              10        4       3     6       2      4
# 1858        199       1               1        0       1     3       4      1
# 1859       2506       1               4        6       0     4       4      2
# 1937        124       1               6        5       2    10       5      2
# 2337         31       1               3        6       1     9       2      3
# 2342        200       1               2        3       1     4       1      1
# 2476       3229       1              16        4       0    16       8      4
# 2549       3307       1              23       16       3    21      18      7
# 2565       3326       1              11        5       3    15       7      4
# 2640       3415       1              10       10       1     9       7      2
# 2664       3442       1               6        3       0     9       4      0
# 2780       3564       1               7        0       0     2       1      3
# 2795       3584       1               7        3       0     6       1      4
# 2797        215       1               7        4       0     7       2      3
# 2798       3586       1               3        2       0     3       1      3
# 2799       3587       1               7        2       0     5       2      3
# 2800        292       1               6        0       1     5       1      1
# 2802       3589       1               8        3       0     7       4      2
# 2803       3590       1               6        3       0     5       4      0
# 2807       3594       1               5        6       0     6       4      3
# 2817       3603       1               1        4       0     5       2      0
# 2818       3604       1               4        8       1     6       5      1
# 2821       3607       1               4        3       1     3       3      2
# 2825       3612       1               9       14       2    18       6      5
# 2829       3616       1              15       10       7    13       8      4
# 2846       3635       1              10        8       2    10       9      3
# 2894       3689       1               6        9       1    12       7      3
# 2895       3690       1              13        8       2     9      11      4
# 2898       3692       1               5        6       1     8       2      4
# 2899       3693       1               3        0       0     5       3      2
# 2900       3694       1               0        4       0    10       1      2
# 2901       3695       1               4        4       0     7       6      2
# 2902       3696       1              11        8       1    11       4      5
# 2903       3697       1              13       15       1    14       8      5
# 3571        274       1              11        2       2     4       1      4
#
#       rank  worker
# 117      7       6
# 123      0       1
# 705      6       2
# 880      3       1
# 1116     2       2
# 1152     3       2
# 1252     0       2
# 1359     2       2
# 1586     5       2
# 1615     3       2
# 1616     0       2
# 1641     2       1
# 1833     1       1
# 1858     0       1
# 1859     0       1
# 1937     2       2
# 2337     2       3
# 2342     1       1
# 2476     2       5
# 2549     7       6
# 2565     4       4
# 2640     2       3
# 2664     2       2
# 2780     0       1
# 2795     1       1
# 2797     0       3
# 2798     1       2
# 2799     2       1
# 2800     1       1
# 2802     1       1
# 2803     2       2
# 2807     0       1
# 2817     2       1
# 2818     3       1
# 2821     1       1
# 2825     5       2
# 2829     3       3
# 2846     6       1
# 2894     4       4
# 2895     1       6
# 2898     2       1
# 2899     1       1
# 2900     1       1
# 2901     2       1
# 2902     4       1
# 2903     5       3
# 3571     1       1

# %%
workers[workers['vizier']==0]
# Out:
#       ID_person  vizier  administration  epithet  family  none  priest  privy  \
# 60          419       0               0        0       0     0       0      0
# 61          420       0               0        0       0     1       0      0
# 66          430       0               0        0       0     0       0      0
# 67          431       0               0        0       0     1       0      0
# 74          441       0               0        0       0     0       0      0
# ...         ...     ...             ...      ...     ...   ...     ...    ...
# 3943       4926       0               0        0       1     0       0      0
# 3946        315       0               5        0       0    11       2      2
# 3950       4932       0               0        0       0     2       0      0
# 3974       4961       0               1        1       0     1       0      0
# 3976        319       0               3        1       0     3       0      1
#
#       rank  worker
# 60       0       1
# 61       0       1
# 66       1       1
# 67       0       1
# 74       0       1
# ...    ...     ...
# 3943     0       1
# 3946     0       1
# 3950     1       1
# 3974     1       1
# 3976     0       2
#
# [340 rows x 10 columns]

# %%
print(f'{vizier.shape}\tshape of vizier')
print(f'{workers.shape}\tshape of workers')
# Out:
# (4962, 2)	shape of vizier
# (387, 10)	shape of workers

# %%
workers.describe()
# Out:
#          ID_person      vizier  administration     epithet      family  \
# count   387.000000  387.000000      387.000000  387.000000  387.000000
# mean   2210.713178    0.121447        2.914729    1.754522    0.617571
# std    1576.418104    0.327069        3.395435    2.572110    1.004395
# min       1.000000    0.000000        0.000000    0.000000    0.000000
# 25%     520.500000    0.000000        0.000000    0.000000    0.000000
# 50%    2284.000000    0.000000        2.000000    1.000000    0.000000
# 75%    3605.500000    0.000000        5.000000    2.000000    1.000000
# max    4961.000000    1.000000       23.000000   16.000000    7.000000
#
#              none      priest       privy        rank      worker
# count  387.000000  387.000000  387.000000  387.000000  387.000000
# mean     2.997416    1.669251    0.852713    1.198966    1.390181
# std      3.588625    2.604134    1.445562    1.439343    0.863903
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      0.000000    0.000000    0.000000    0.000000    1.000000
# 50%      2.000000    1.000000    0.000000    1.000000    1.000000
# 75%      4.000000    2.000000    1.000000    2.000000    1.000000
# max     21.000000   24.000000   11.000000    7.000000    6.000000
