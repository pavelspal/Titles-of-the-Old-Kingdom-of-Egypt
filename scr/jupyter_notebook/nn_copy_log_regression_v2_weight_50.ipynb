# %% [markdown]
# # NN network for corresponding

# %% [markdown]
# **Motivation:** This scripts aims to model a neural network model with same input parameters as logistic regression model (step, Lasso, ridge)
# The architecture is chose as

# %%
final_model_dict = {}

# %% [markdown]
# ### Load

# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

## NN
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from torch.optim.lr_scheduler import StepLR
import shap

# local
import set_path
import supp.support_load as sl
import supp.support_get_mapping as gm
from supp.support_analyze_model import GraphPlotter, plot_cdf, plot_roc, reliability_plot
from supp.support_save import save_df
from supp.support_model_nn import BinaryClassifier, save_nn_info
from supp.support_model_glm import get_model_coef_df, get_model_coef_dict
from supp.support_model_stats import find_viziers_above_overlap, find_non_viziers_in_overlap, find_viziers_in_overlap, find_persons_in_overlap

# %% [markdown]
# #### Load train, validation adn test set

# %%
# Load train, validation and test set
data_train = sl.read_csv('df_vizier_train_v2_2')
data_val = sl.read_csv('df_vizier_val_v2_2')
# set 'ID_person' as index
data_train.set_index('ID_person', inplace=True)
data_val.set_index('ID_person', inplace=True)

# Set response
response = 'vizier'
features_all = [col for col in data_train.columns if col != response]

# conver X to numpy
X_train0 = data_train[features_all].to_numpy()
X_val0 = data_val[features_all].to_numpy()
# conver y to numpy
y_train0 = data_train[response].to_numpy()
y_val0 = data_val[response].to_numpy()
# Out:
# CSV file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\df_vizier_train_v2_2.csv
# CSV file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\df_vizier_val_v2_2.csv

# %%
# Check loaded data shape
print(data_train.shape)
print(data_val.shape)
# Out:
# (2684, 55)
# (575, 55)

# %%
# Check features data shape
print(X_train0.shape)
print(X_val0.shape)
# Out:
# (2684, 54)
# (575, 54)

# %%
# Check response data shape
print(y_train0.shape)
print(y_val0.shape)
# Out:
# (2684,)
# (575,)

# %%
# Check count of viziers
print(y_train0.sum())
print(y_val0.sum())
# Out:
# 52
# 11

# %% [markdown]
# #### Get feature names from GLM models

# %%
# Get dataframe with all GLM coefficients
df_coef = get_model_coef_df(version='_v2')
df_coef
# Out:
# Excel file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\summary_model_coefficients_v0_v2.xlsx
# Variable   wr 5 (m) pr 9Hwty  zA ncwt n Xt.f cmcw  \
# step_glm             6.57170              5.83860
# lasso_glm            4.31950              3.89970
# ridge_glm            1.84356              1.69397
#
# Variable   imy-rA zS(w) a(w) (nw) ncwt  Xry-Hbt Hry-tp  imy-rA prwy-HD  \
# step_glm                       4.81280         4.19800         2.19740
# lasso_glm                      4.05830         2.00050         1.12640
# ridge_glm                      1.47964         0.81088         0.77202
#
# Variable   imy-rA kAt nbt (nt) ncwt  (Intercept)  zA ncwt n Xt.f  aD-mr 8p  \
# step_glm                    2.17000      -6.1196             NaN       NaN
# lasso_glm                   1.55000      -5.8054         1.61470   1.41980
# ridge_glm                   0.89035      -5.0703         1.08609   0.72488
#
# Variable   xrp SnDt nbt  ...    imA-a  Xry-Hbt  Hry-cStA  wt(y) Inpw  \
# step_glm            NaN  ...      NaN      NaN       NaN         NaN
# lasso_glm       0.95090  ...      NaN      NaN       NaN         NaN
# ridge_glm       0.73613  ...  0.20339  0.18624   0.13108     0.12045
#
# Variable   [imAxw xr] nTr aA  Hry-tp Nxb    imAxw  father_was_vizier      PC2  \
# step_glm                 NaN         NaN      NaN                NaN      NaN
# lasso_glm                NaN         NaN      NaN                NaN      NaN
# ridge_glm            0.09388     0.05368  0.03041            0.02368 -0.01093
#
# Variable   dynasty_1
# step_glm         NaN
# lasso_glm        NaN
# ridge_glm   -0.01539
#
# [3 rows x 43 columns]

# %%
# Get feature names for each GLM model
coef_step = get_model_coef_dict('step_glm', df=df_coef)
coef_lasso = get_model_coef_dict('lasso_glm', df=df_coef)
coef_ridge = get_model_coef_dict('ridge_glm', df=df_coef)

# %%
# Define set of features for each model
omit_features = ['(Intercept)']
features_step = [key for key in coef_step.keys() if key not in omit_features]
features_lasso = [key for key in coef_lasso.keys() if key not in omit_features]
features_ridge = [key for key in coef_ridge.keys() if key not in omit_features]

# %%
required_features = ['father_was_vizier', 'PC2', 'dynasty_1']
features_step += [el for el in required_features if el not in features_step]
features_lasso += [el for el in required_features if el not in features_lasso]
features_ridge += [el for el in required_features if el not in features_ridge]

# %%
# Check features len
print(len(features_all))
print(len(features_step))
print(len(features_lasso))
print(len(features_ridge))
# Out:
# 54
# 9
# 21
# 42

# %%
print(list(coef_step.keys()))
print(list(coef_lasso.keys()))
print(list(coef_ridge.keys()))
# Out:
# ['wr 5 (m) pr 9Hwty', 'zA ncwt n Xt.f cmcw', 'imy-rA zS(w) a(w) (nw) ncwt', 'Xry-Hbt Hry-tp', 'imy-rA prwy-HD', 'imy-rA kAt nbt (nt) ncwt', '(Intercept)']
# ['wr 5 (m) pr 9Hwty', 'zA ncwt n Xt.f cmcw', 'imy-rA zS(w) a(w) (nw) ncwt', 'Xry-Hbt Hry-tp', 'imy-rA prwy-HD', 'imy-rA kAt nbt (nt) ncwt', '(Intercept)', 'zA ncwt n Xt.f', 'aD-mr 8p', 'xrp SnDt nbt', 'xtm(ty)-bity', 'imy-rA izwy (n) Xkr(w) ncwt', 'iwn knmwt', 'cmr waty', 'mDH ncwt qd(w) m prwy', 'aA 8wAw', 'imy-rA 5maw', 'imy-rA Snwty', 'Hry-cStA n wD(t)-mdw nbt nt ncwt']
# ['wr 5 (m) pr 9Hwty', 'zA ncwt n Xt.f cmcw', 'imy-rA zS(w) a(w) (nw) ncwt', 'Xry-Hbt Hry-tp', 'imy-rA prwy-HD', 'imy-rA kAt nbt (nt) ncwt', '(Intercept)', 'zA ncwt n Xt.f', 'aD-mr 8p', 'xrp SnDt nbt', 'xtm(ty)-bity', 'imy-rA izwy (n) Xkr(w) ncwt', 'iwn knmwt', 'cmr waty', 'mDH ncwt qd(w) m prwy', 'aA 8wAw', 'imy-rA 5maw', 'imy-rA Snwty', 'Hry-cStA n wD(t)-mdw nbt nt ncwt', 'imy-rA gc-pr', 'mDH zS(w) ncwt', 'imy iz Nxn', 'zS mDAt-nTr', 'xrp iAwt nbwt nTrwt', 'zA ncwt', 'xrp aH', 'Hry-cStA n pr-dwAt', 'imy-rA prwy-nbw', 'imy iz', 'r P nb', 'imAxw xr Wcir', 'aD-mr (n) zAb', 'Xry-tp ncwt', 'imA-a', 'Xry-Hbt', 'Hry-cStA', 'wt(y) Inpw', '[imAxw xr] nTr aA', 'Hry-tp Nxb', 'imAxw', 'father_was_vizier', 'PC2', 'dynasty_1']

# %%
# this title was removed in GLM because of high VIF
set(features_all) - set(features_ridge)
# Out:
# {'HAty-a',
#  'Htc(?) Inpw',
#  'PC1',
#  'cm / ctm',
#  'cmcw cnwt',
#  'dynasty_0',
#  'dynasty_2',
#  'imy-rA wabty',
#  'iry-pat',
#  'mdw rxyt',
#  'mniw Nxn / zAw Nxn',
#  'xrp (i)m(yw) nTrw'}

# %% [markdown]
# ### Train function

# %%
# define hidden_size
# (can be overwriten later)
hidden_size = [2]

# %%
# Define the weight of positive examples
sum_vizier = y_train0.sum() 
sum_non_vizier = y_train0.shape[0] - sum_vizier
pos_weight = sum_non_vizier / sum_vizier
#pos_weight = 1
pos_weight = torch.tensor([pos_weight], dtype=torch.float32)
# Set criterion
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)  # Using BCEWithLogitsLoss

pos_weight
# Out:
# tensor([50.6154])

# %%
def train_nn(params):
    """
    This funtion serves as main method for training NN model
        - defines model
        - defines optimizer
        - carry the training process
        - choose the best model via early stopping
        - calc train and vall loss
        - plot evolution of loss
        - saves final model
        
    Parameters:
        params (dict): hyperparameters of the NN model
    """
    print(f'===================================')
    print(f' S T A R T I N G   M O D E L')
    print(f'===================================\n')
    current_time = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')
    
    # Set params
    typ = params['typ']
    batch_size = params['batch_size']
    hidden_size = params['hidden_size']
    activation_name = params['activation_name']
    dropout_prob = params['dropout_prob']
    optimizer_name = params['optimizer_name']
    epochs = params['epochs']
    learning_rate = params['learning_rate']
    patience = params['patience']
    weight_decay_value = params['l2_lambda']

    # Set features space
    features = {'step': features_step,
                'lasso': features_lasso,
                'ridge': features_ridge
               }[typ]
    X_train = data_train[features].to_numpy()
    X_val = data_val[features].to_numpy()
    
    # Converting data to PyTorch tensors
    X_train = torch.tensor(X_train, dtype=torch.float32)
    X_val = torch.tensor(X_val, dtype=torch.float32)
    y_train = torch.tensor(y_train0, dtype=torch.float32).unsqueeze(1)
    y_val = torch.tensor(y_val0, dtype=torch.float32).unsqueeze(1)
    
    # Prepare datasets
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    
    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize the model
    input_size = X_train.shape[1]
    # Define model, loss function and optimizer
    model = BinaryClassifier(input_size, hidden_size, activation_name, dropout_prob=dropout_prob)
    
    if optimizer_name == "adam":
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay_value)
    elif optimizer_name == "sgd":
        optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    elif optimizer_name == "rmsprop":
        optimizer = optim.RMSprop(model.parameters(), lr=learning_rate)
    elif optimizer_name == "nadam":
        optimizer = optim.NAdam(model.parameters(), lr=learning_rate)
    else:
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    #scheduler = StepLR(optimizer, step_size=100, gamma=0.5)
    print(f'Defined BinaryClassifier with {criterion=}')
    print(f'Defined BinaryClassifier with {optimizer=}')

    # Print model architecture
    print(f'\n===================================')
    print(f'MODEL ARCHITECTURE:\n{model}')
    print(f'===================================\n')

    # Print total number of parameters
    total_params = sum(p.numel() for p in model.parameters())
    print(f'\n===================================')
    print(f'NUMBER OF PARAMETERS: {total_params}')
    print(f'===================================\n')


    # Declare losses
    train_losses = []
    val_losses = []
    pio_list = []     # persons in overlap
    # Early stopping parameters
    best_val_loss = float('inf')
    patience_counter = 0

    # Flag for learning rate reduce
    lr_reduced_1 = False 
    lr_reduced_2 = False 
    # Train the model
    for epoch in range(epochs):

        # Training step
        model.train()
        train_loss = 0.0
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * batch_X.size(0)
        # Compute average train loss
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        # Validation step
        model.eval()
        val_loss = 0.0
        y_true = []
        y_hat = []
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                outputs = model(batch_X)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item() * batch_X.size(0)
                # Get y_true and y_hat batch
                y_true.extend([el.item() for el in batch_y])
                probabilities = torch.sigmoid(outputs)
                y_hat.extend([el.item() for el in probabilities])
        # Compute average validation loss
        val_loss /= len(val_loader.dataset)
        val_losses.append(val_loss)
        # Compute persons in overlap
        col = 'probs'
        df_probs= pd.DataFrame({'vizier': y_true, col: y_hat})
        pio = find_persons_in_overlap(df_probs, col)
        pio_list.append(pio)
    
        # Print current epoch performance
        print(
            f"Epoch {epoch+1}/{epochs},\t"
            f"Train Loss: {train_loss:.4f},\t"
            f"Validation Loss: {val_loss:.4f},\t"
            #f"LR: {scheduler.get_last_lr()[0]:.6f}"
        )
    
        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            # Save the best model
            torch.save(model.state_dict(), rf'nn_models\best_mlp_{typ}_v2.pth')
        else:
            patience_counter += 1
            print(f"\tEarly stopping patience counter: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("\tEarly stopping triggered. Stopping training.")
                break
        
        # Update learing rate
        if val_loss < 0.1 and not lr_reduced_1:
            for param_group in optimizer.param_groups:
                param_group['lr'] = param_group['lr'] / 10
            print(f"Learning rate reduced to: {param_group['lr']}")
            lr_reduced_1 = True
        # if val_loss < 0.061 and not lr_reduced_2:
        #     for param_group in optimizer.param_groups:
        #         param_group['lr'] = param_group['lr'] / 10
        #     print(f"Learning rate reduced to: {param_group['lr']}")
        #     lr_reduced_2 = True

        # Update learing rate
        #scheduler.step()
    
    # Load the best model after early stopping
    model.load_state_dict(torch.load(rf'nn_models\best_mlp_{typ}_v2.pth'))
    
    # Plot training and validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(train_losses)+1), train_losses, label='Train Loss')
    plt.plot(range(1, len(val_losses)+1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid()
    plt.show()
    # Plot evolutio of persons in overlap
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(val_losses)+1), pio_list, label='Persons in overlap')
    plt.xlabel('Epochs')
    plt.ylabel('Persons in overlap')
    plt.title('Evolution of Persons in Overlap')
    plt.legend()
    plt.grid()
    plt.show()
    
    # Save the model
    path_save = rf'nn_models\mlp_{typ}_{current_time}.pth'
    torch.save(model.state_dict(), path_save)
    save_nn_info(input_size, hidden_size, activation_name, features, path_save)


    # print model lacation
    print(f'\n\n===================================')
    print(f' M O D E L   L O C A T I O N :')
    print(f'{path_save}')
    print(f'===================================\n')
    final_model_dict[typ] = path_save

    # print model lacation
    print(f'\n\n===================================')
    print(f' persons_in_overlap: {pio_list[-1]}')
    print(f'===================================\n')

    model.eval()
    return model, val_loader

# %%
def plot_shaps(model, features_set, output_path=None):
    # Prepare data
    X_df = data_train[features_set]
    X_df = X_df.sample(frac=1, random_state=42).reset_index(drop=True)
    X_explain = torch.tensor(X_df.values, dtype=torch.float32)
    X_sample = X_explain[:150]
    
    # Choose Explainer
    model.eval()
    explainer = shap.GradientExplainer(model, X_sample)
    # Calculate SHAP values
    shap_values_step = explainer.shap_values(X_explain)
    # Remove the last dimension
    shap_values_step = shap_values_step.squeeze(-1)
    
    # Plot and save SHAP 
    plt.figure()
    shap.summary_plot(shap_values_step, X_explain.numpy(), feature_names=features_set, show=False)
    plt.tight_layout()
    if output_path is not None:
        plt.savefig(f'{output_path}.png', dpi=300, bbox_inches='tight')
        plt.savefig(f'{output_path}.pdf', bbox_inches='tight')
    plt.show()

# %%
def print_stats(model, val_loader, params):
    # Validation step
    model.eval()
    val_loss = 0.0
    y_true = []
    y_hat = []
    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            val_loss += loss.item() * batch_X.size(0)
            # Get y_true and y_hat batch
            y_true.extend([el.item() for el in batch_y])
            probabilities = torch.sigmoid(outputs)
            y_hat.extend([el.item() for el in probabilities])
    # Compute average validation loss
    val_loss /= len(val_loader.dataset)
    # Compute persons in overlap
    col = 'probs'
    df_probs= pd.DataFrame({'vizier': y_true, col: y_hat})
    pio_val = find_persons_in_overlap(df_probs, col)
    mean_vizier = df_probs.loc[df_probs['vizier']==1, col].mean()
    mean_non_vizier = df_probs.loc[df_probs['vizier']==0, col].mean()
    bottom_3_vizier = df_probs.loc[df_probs['vizier']==1, col].sort_values().to_list()[3]
    top_3_non_vizier = df_probs.loc[df_probs['vizier']==0, col].sort_values().to_list()[-3]
    
    print(params)
    print(f"Validation Loss:\t{val_loss:.4f}")
    print(f"Mean vizier:\t\t{mean_vizier:.4f}")
    print(f"Mean non-vizier:\t{mean_non_vizier:.4f}")
    print(f"bottom_3_vizier:\t{bottom_3_vizier:.4f}")
    print(f"top_3_non_vizier:\t{top_3_non_vizier:.4f}")
    print(f"PiO Validation:\t\t{pio_val}")

# %% [markdown]
# ### Step NN

# %%
params = {'typ': 'step',
          'batch_size': 512,
          'hidden_size': [4,2],
          'dropout_prob': 0.2,
          'activation_name': 'relu',
          'optimizer_name': 'adam',
          'epochs': 1000,
          'learning_rate': 0.002,
          'patience': 40,
          'l2_lambda': 0
         }
model_step, val_loader_step = train_nn(params)
# Out:
# ===================================
#  S T A R T I N G   M O D E L
# ===================================
#
# Defined BinaryClassifier with criterion=BCEWithLogitsLoss()
# Defined BinaryClassifier with optimizer=Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.002
#     maximize: False
#     weight_decay: 0
# )
#
# ===================================
# MODEL ARCHITECTURE:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=9, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=4, out_features=2, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=2, out_features=1, bias=True)
#   )
# )
# ===================================
#
#
# ===================================
# NUMBER OF PARAMETERS: 53
# ===================================
#
# Epoch 1/1000,	Train Loss: 1.3424,	Validation Loss: 1.3001,
# Epoch 2/1000,	Train Loss: 1.3415,	Validation Loss: 1.2945,
# Epoch 3/1000,	Train Loss: 1.3312,	Validation Loss: 1.2881,
# Epoch 4/1000,	Train Loss: 1.3176,	Validation Loss: 1.2810,
# Epoch 5/1000,	Train Loss: 1.3253,	Validation Loss: 1.2732,
# Epoch 6/1000,	Train Loss: 1.3325,	Validation Loss: 1.2656,
# Epoch 7/1000,	Train Loss: 1.3170,	Validation Loss: 1.2566,
# Epoch 8/1000,	Train Loss: 1.3095,	Validation Loss: 1.2462,
# Epoch 9/1000,	Train Loss: 1.2819,	Validation Loss: 1.2329,
# Epoch 10/1000,	Train Loss: 1.2679,	Validation Loss: 1.2174,
# Epoch 11/1000,	Train Loss: 1.2514,	Validation Loss: 1.2005,
# Epoch 12/1000,	Train Loss: 1.2378,	Validation Loss: 1.1810,
# Epoch 13/1000,	Train Loss: 1.2173,	Validation Loss: 1.1611,
# Epoch 14/1000,	Train Loss: 1.1972,	Validation Loss: 1.1397,
# Epoch 15/1000,	Train Loss: 1.2104,	Validation Loss: 1.1171,
# Epoch 16/1000,	Train Loss: 1.1968,	Validation Loss: 1.0958,
# Epoch 17/1000,	Train Loss: 1.1440,	Validation Loss: 1.0723,
# Epoch 18/1000,	Train Loss: 1.1836,	Validation Loss: 1.0480,
# Epoch 19/1000,	Train Loss: 1.1371,	Validation Loss: 1.0260,
# Epoch 20/1000,	Train Loss: 1.0834,	Validation Loss: 1.0024,
# Epoch 21/1000,	Train Loss: 1.0316,	Validation Loss: 0.9761,
# Epoch 22/1000,	Train Loss: 1.0977,	Validation Loss: 0.9522,
# Epoch 23/1000,	Train Loss: 1.0204,	Validation Loss: 0.9291,
# Epoch 24/1000,	Train Loss: 1.0284,	Validation Loss: 0.9068,
# Epoch 25/1000,	Train Loss: 0.9775,	Validation Loss: 0.8852,
# Epoch 26/1000,	Train Loss: 1.0173,	Validation Loss: 0.8655,
# Epoch 27/1000,	Train Loss: 0.9452,	Validation Loss: 0.8468,
# Epoch 28/1000,	Train Loss: 0.9338,	Validation Loss: 0.8288,
# Epoch 29/1000,	Train Loss: 0.9020,	Validation Loss: 0.8121,
# Epoch 30/1000,	Train Loss: 0.9453,	Validation Loss: 0.7971,
# Epoch 31/1000,	Train Loss: 0.9113,	Validation Loss: 0.7829,
# Epoch 32/1000,	Train Loss: 0.8566,	Validation Loss: 0.7691,
# Epoch 33/1000,	Train Loss: 0.9115,	Validation Loss: 0.7560,
# Epoch 34/1000,	Train Loss: 0.8734,	Validation Loss: 0.7447,
# Epoch 35/1000,	Train Loss: 0.8310,	Validation Loss: 0.7343,
# Epoch 36/1000,	Train Loss: 0.8729,	Validation Loss: 0.7235,
# Epoch 37/1000,	Train Loss: 0.8817,	Validation Loss: 0.7143,
# Epoch 38/1000,	Train Loss: 0.8898,	Validation Loss: 0.7059,
# Epoch 39/1000,	Train Loss: 0.7973,	Validation Loss: 0.6972,
# Epoch 40/1000,	Train Loss: 0.7983,	Validation Loss: 0.6887,
# Epoch 41/1000,	Train Loss: 0.7938,	Validation Loss: 0.6804,
# Epoch 42/1000,	Train Loss: 0.8505,	Validation Loss: 0.6724,
# Epoch 43/1000,	Train Loss: 0.7922,	Validation Loss: 0.6649,
# Epoch 44/1000,	Train Loss: 0.8267,	Validation Loss: 0.6579,
# Epoch 45/1000,	Train Loss: 0.7930,	Validation Loss: 0.6509,
# Epoch 46/1000,	Train Loss: 0.7833,	Validation Loss: 0.6444,
# Epoch 47/1000,	Train Loss: 0.8078,	Validation Loss: 0.6381,
# Epoch 48/1000,	Train Loss: 0.7611,	Validation Loss: 0.6323,
# Epoch 49/1000,	Train Loss: 0.7028,	Validation Loss: 0.6262,
# Epoch 50/1000,	Train Loss: 0.7611,	Validation Loss: 0.6204,
# Epoch 51/1000,	Train Loss: 0.6833,	Validation Loss: 0.6147,
# Epoch 52/1000,	Train Loss: 0.7535,	Validation Loss: 0.6091,
# Epoch 53/1000,	Train Loss: 0.7374,	Validation Loss: 0.6039,
# Epoch 54/1000,	Train Loss: 0.7354,	Validation Loss: 0.5990,
# Epoch 55/1000,	Train Loss: 0.6562,	Validation Loss: 0.5940,
# Epoch 56/1000,	Train Loss: 0.6915,	Validation Loss: 0.5890,
# Epoch 57/1000,	Train Loss: 0.6951,	Validation Loss: 0.5843,
# Epoch 58/1000,	Train Loss: 0.6979,	Validation Loss: 0.5796,
# Epoch 59/1000,	Train Loss: 0.6555,	Validation Loss: 0.5752,
# Epoch 60/1000,	Train Loss: 0.6884,	Validation Loss: 0.5712,
# Epoch 61/1000,	Train Loss: 0.7417,	Validation Loss: 0.5674,
# Epoch 62/1000,	Train Loss: 0.6580,	Validation Loss: 0.5639,
# Epoch 63/1000,	Train Loss: 0.6763,	Validation Loss: 0.5602,
# Epoch 64/1000,	Train Loss: 0.6694,	Validation Loss: 0.5566,
# Epoch 65/1000,	Train Loss: 0.7258,	Validation Loss: 0.5533,
# Epoch 66/1000,	Train Loss: 0.7164,	Validation Loss: 0.5500,
# Epoch 67/1000,	Train Loss: 0.6646,	Validation Loss: 0.5471,
# Epoch 68/1000,	Train Loss: 0.6269,	Validation Loss: 0.5440,
# Epoch 69/1000,	Train Loss: 0.6022,	Validation Loss: 0.5407,
# Epoch 70/1000,	Train Loss: 0.6491,	Validation Loss: 0.5374,
# Epoch 71/1000,	Train Loss: 0.6604,	Validation Loss: 0.5343,
# Epoch 72/1000,	Train Loss: 0.6342,	Validation Loss: 0.5313,
# Epoch 73/1000,	Train Loss: 0.6462,	Validation Loss: 0.5286,
# Epoch 74/1000,	Train Loss: 0.6630,	Validation Loss: 0.5262,
# Epoch 75/1000,	Train Loss: 0.6327,	Validation Loss: 0.5237,
# Epoch 76/1000,	Train Loss: 0.6312,	Validation Loss: 0.5210,
# Epoch 77/1000,	Train Loss: 0.6146,	Validation Loss: 0.5184,
# Epoch 78/1000,	Train Loss: 0.6058,	Validation Loss: 0.5156,
# Epoch 79/1000,	Train Loss: 0.5700,	Validation Loss: 0.5129,
# Epoch 80/1000,	Train Loss: 0.6652,	Validation Loss: 0.5105,
# Epoch 81/1000,	Train Loss: 0.6563,	Validation Loss: 0.5080,
# Epoch 82/1000,	Train Loss: 0.6269,	Validation Loss: 0.5058,
# Epoch 83/1000,	Train Loss: 0.5930,	Validation Loss: 0.5034,
# Epoch 84/1000,	Train Loss: 0.6201,	Validation Loss: 0.5011,
# Epoch 85/1000,	Train Loss: 0.6022,	Validation Loss: 0.4989,
# Epoch 86/1000,	Train Loss: 0.5738,	Validation Loss: 0.4963,
# Epoch 87/1000,	Train Loss: 0.6025,	Validation Loss: 0.4942,
# Epoch 88/1000,	Train Loss: 0.6109,	Validation Loss: 0.4922,
# Epoch 89/1000,	Train Loss: 0.5930,	Validation Loss: 0.4900,
# Epoch 90/1000,	Train Loss: 0.6124,	Validation Loss: 0.4878,
# Epoch 91/1000,	Train Loss: 0.5433,	Validation Loss: 0.4857,
# Epoch 92/1000,	Train Loss: 0.5588,	Validation Loss: 0.4834,
# Epoch 93/1000,	Train Loss: 0.5879,	Validation Loss: 0.4814,
# Epoch 94/1000,	Train Loss: 0.6149,	Validation Loss: 0.4798,
# Epoch 95/1000,	Train Loss: 0.6229,	Validation Loss: 0.4783,
# Epoch 96/1000,	Train Loss: 0.5716,	Validation Loss: 0.4765,
# Epoch 97/1000,	Train Loss: 0.5888,	Validation Loss: 0.4748,
# Epoch 98/1000,	Train Loss: 0.6210,	Validation Loss: 0.4731,
# Epoch 99/1000,	Train Loss: 0.6137,	Validation Loss: 0.4721,
# Epoch 100/1000,	Train Loss: 0.5487,	Validation Loss: 0.4701,
# Epoch 101/1000,	Train Loss: 0.5774,	Validation Loss: 0.4685,
# Epoch 102/1000,	Train Loss: 0.5478,	Validation Loss: 0.4672,
# Epoch 103/1000,	Train Loss: 0.5603,	Validation Loss: 0.4660,
# Epoch 104/1000,	Train Loss: 0.5982,	Validation Loss: 0.4646,
# Epoch 105/1000,	Train Loss: 0.5374,	Validation Loss: 0.4632,
# Epoch 106/1000,	Train Loss: 0.5099,	Validation Loss: 0.4616,
# Epoch 107/1000,	Train Loss: 0.5598,	Validation Loss: 0.4599,
# Epoch 108/1000,	Train Loss: 0.5982,	Validation Loss: 0.4584,
# Epoch 109/1000,	Train Loss: 0.5325,	Validation Loss: 0.4571,
# Epoch 110/1000,	Train Loss: 0.5746,	Validation Loss: 0.4557,
# Epoch 111/1000,	Train Loss: 0.5886,	Validation Loss: 0.4544,
# Epoch 112/1000,	Train Loss: 0.5969,	Validation Loss: 0.4532,
# Epoch 113/1000,	Train Loss: 0.5529,	Validation Loss: 0.4518,
# Epoch 114/1000,	Train Loss: 0.5511,	Validation Loss: 0.4502,
# Epoch 115/1000,	Train Loss: 0.5554,	Validation Loss: 0.4489,
# Epoch 116/1000,	Train Loss: 0.4864,	Validation Loss: 0.4475,
# Epoch 117/1000,	Train Loss: 0.5302,	Validation Loss: 0.4459,
# Epoch 118/1000,	Train Loss: 0.5295,	Validation Loss: 0.4445,
# Epoch 119/1000,	Train Loss: 0.5499,	Validation Loss: 0.4432,
# Epoch 120/1000,	Train Loss: 0.5868,	Validation Loss: 0.4419,
# Epoch 121/1000,	Train Loss: 0.5860,	Validation Loss: 0.4407,
# Epoch 122/1000,	Train Loss: 0.6380,	Validation Loss: 0.4395,
# Epoch 123/1000,	Train Loss: 0.5401,	Validation Loss: 0.4388,
# Epoch 124/1000,	Train Loss: 0.5663,	Validation Loss: 0.4380,
# Epoch 125/1000,	Train Loss: 0.5615,	Validation Loss: 0.4371,
# Epoch 126/1000,	Train Loss: 0.5269,	Validation Loss: 0.4363,
# Epoch 127/1000,	Train Loss: 0.5742,	Validation Loss: 0.4353,
# Epoch 128/1000,	Train Loss: 0.5375,	Validation Loss: 0.4343,
# Epoch 129/1000,	Train Loss: 0.5393,	Validation Loss: 0.4335,
# Epoch 130/1000,	Train Loss: 0.5291,	Validation Loss: 0.4325,
# Epoch 131/1000,	Train Loss: 0.5646,	Validation Loss: 0.4316,
# Epoch 132/1000,	Train Loss: 0.5335,	Validation Loss: 0.4310,
# Epoch 133/1000,	Train Loss: 0.6197,	Validation Loss: 0.4305,
# Epoch 134/1000,	Train Loss: 0.4992,	Validation Loss: 0.4300,
# Epoch 135/1000,	Train Loss: 0.5173,	Validation Loss: 0.4292,
# Epoch 136/1000,	Train Loss: 0.5942,	Validation Loss: 0.4284,
# Epoch 137/1000,	Train Loss: 0.5610,	Validation Loss: 0.4277,
# Epoch 138/1000,	Train Loss: 0.5552,	Validation Loss: 0.4267,
# Epoch 139/1000,	Train Loss: 0.5421,	Validation Loss: 0.4257,
# Epoch 140/1000,	Train Loss: 0.5200,	Validation Loss: 0.4248,
# Epoch 141/1000,	Train Loss: 0.5867,	Validation Loss: 0.4241,
# Epoch 142/1000,	Train Loss: 0.5549,	Validation Loss: 0.4233,
# Epoch 143/1000,	Train Loss: 0.5184,	Validation Loss: 0.4223,
# Epoch 144/1000,	Train Loss: 0.5045,	Validation Loss: 0.4213,
# Epoch 145/1000,	Train Loss: 0.6467,	Validation Loss: 0.4205,
# Epoch 146/1000,	Train Loss: 0.5205,	Validation Loss: 0.4197,
# Epoch 147/1000,	Train Loss: 0.5425,	Validation Loss: 0.4188,
# Epoch 148/1000,	Train Loss: 0.5445,	Validation Loss: 0.4182,
# Epoch 149/1000,	Train Loss: 0.5133,	Validation Loss: 0.4176,
# Epoch 150/1000,	Train Loss: 0.5306,	Validation Loss: 0.4174,
# Epoch 151/1000,	Train Loss: 0.5661,	Validation Loss: 0.4175,
# 	Early stopping patience counter: 1/40
# Epoch 152/1000,	Train Loss: 0.5114,	Validation Loss: 0.4175,
# 	Early stopping patience counter: 2/40
# Epoch 153/1000,	Train Loss: 0.5088,	Validation Loss: 0.4170,
# Epoch 154/1000,	Train Loss: 0.5599,	Validation Loss: 0.4163,
# Epoch 155/1000,	Train Loss: 0.5088,	Validation Loss: 0.4156,
# Epoch 156/1000,	Train Loss: 0.5026,	Validation Loss: 0.4147,
# Epoch 157/1000,	Train Loss: 0.4991,	Validation Loss: 0.4139,
# Epoch 158/1000,	Train Loss: 0.4674,	Validation Loss: 0.4131,
# Epoch 159/1000,	Train Loss: 0.5583,	Validation Loss: 0.4124,
# Epoch 160/1000,	Train Loss: 0.4490,	Validation Loss: 0.4120,
# Epoch 161/1000,	Train Loss: 0.4774,	Validation Loss: 0.4115,
# Epoch 162/1000,	Train Loss: 0.5660,	Validation Loss: 0.4110,
# Epoch 163/1000,	Train Loss: 0.5418,	Validation Loss: 0.4106,
# Epoch 164/1000,	Train Loss: 0.5017,	Validation Loss: 0.4100,
# Epoch 165/1000,	Train Loss: 0.5782,	Validation Loss: 0.4095,
# Epoch 166/1000,	Train Loss: 0.5247,	Validation Loss: 0.4090,
# Epoch 167/1000,	Train Loss: 0.6071,	Validation Loss: 0.4086,
# Epoch 168/1000,	Train Loss: 0.4957,	Validation Loss: 0.4083,
# Epoch 169/1000,	Train Loss: 0.4636,	Validation Loss: 0.4080,
# Epoch 170/1000,	Train Loss: 0.4757,	Validation Loss: 0.4076,
# Epoch 171/1000,	Train Loss: 0.4838,	Validation Loss: 0.4072,
# Epoch 172/1000,	Train Loss: 0.4669,	Validation Loss: 0.4068,
# Epoch 173/1000,	Train Loss: 0.5243,	Validation Loss: 0.4063,
# Epoch 174/1000,	Train Loss: 0.5802,	Validation Loss: 0.4058,
# Epoch 175/1000,	Train Loss: 0.5084,	Validation Loss: 0.4051,
# Epoch 176/1000,	Train Loss: 0.5242,	Validation Loss: 0.4048,
# Epoch 177/1000,	Train Loss: 0.5599,	Validation Loss: 0.4045,
# Epoch 178/1000,	Train Loss: 0.4620,	Validation Loss: 0.4041,
# Epoch 179/1000,	Train Loss: 0.5143,	Validation Loss: 0.4037,
# Epoch 180/1000,	Train Loss: 0.5409,	Validation Loss: 0.4034,
# Epoch 181/1000,	Train Loss: 0.5238,	Validation Loss: 0.4032,
# Epoch 182/1000,	Train Loss: 0.5592,	Validation Loss: 0.4027,
# Epoch 183/1000,	Train Loss: 0.4767,	Validation Loss: 0.4025,
# Epoch 184/1000,	Train Loss: 0.4779,	Validation Loss: 0.4022,
# Epoch 185/1000,	Train Loss: 0.5333,	Validation Loss: 0.4015,
# Epoch 186/1000,	Train Loss: 0.4837,	Validation Loss: 0.4009,
# Epoch 187/1000,	Train Loss: 0.5403,	Validation Loss: 0.4004,
# Epoch 188/1000,	Train Loss: 0.4863,	Validation Loss: 0.3999,
# Epoch 189/1000,	Train Loss: 0.4938,	Validation Loss: 0.3993,
# Epoch 190/1000,	Train Loss: 0.5630,	Validation Loss: 0.3990,
# Epoch 191/1000,	Train Loss: 0.5018,	Validation Loss: 0.3988,
# Epoch 192/1000,	Train Loss: 0.4477,	Validation Loss: 0.3984,
# Epoch 193/1000,	Train Loss: 0.5329,	Validation Loss: 0.3980,
# Epoch 194/1000,	Train Loss: 0.4780,	Validation Loss: 0.3972,
# Epoch 195/1000,	Train Loss: 0.4787,	Validation Loss: 0.3960,
# Epoch 196/1000,	Train Loss: 0.4472,	Validation Loss: 0.3948,
# Epoch 197/1000,	Train Loss: 0.4294,	Validation Loss: 0.3949,
# 	Early stopping patience counter: 1/40
# Epoch 198/1000,	Train Loss: 0.5666,	Validation Loss: 0.3946,
# Epoch 199/1000,	Train Loss: 0.5431,	Validation Loss: 0.3943,
# Epoch 200/1000,	Train Loss: 0.5487,	Validation Loss: 0.3936,
# Epoch 201/1000,	Train Loss: 0.5105,	Validation Loss: 0.3932,
# Epoch 202/1000,	Train Loss: 0.4597,	Validation Loss: 0.3929,
# Epoch 203/1000,	Train Loss: 0.5009,	Validation Loss: 0.3923,
# Epoch 204/1000,	Train Loss: 0.5087,	Validation Loss: 0.3921,
# Epoch 205/1000,	Train Loss: 0.5391,	Validation Loss: 0.3918,
# Epoch 206/1000,	Train Loss: 0.4998,	Validation Loss: 0.3917,
# Epoch 207/1000,	Train Loss: 0.5267,	Validation Loss: 0.3917,
# 	Early stopping patience counter: 1/40
# Epoch 208/1000,	Train Loss: 0.5307,	Validation Loss: 0.3917,
# Epoch 209/1000,	Train Loss: 0.4509,	Validation Loss: 0.3917,
# 	Early stopping patience counter: 1/40
# Epoch 210/1000,	Train Loss: 0.4638,	Validation Loss: 0.3916,
# Epoch 211/1000,	Train Loss: 0.4910,	Validation Loss: 0.3914,
# Epoch 212/1000,	Train Loss: 0.4372,	Validation Loss: 0.3912,
# Epoch 213/1000,	Train Loss: 0.4931,	Validation Loss: 0.3906,
# Epoch 214/1000,	Train Loss: 0.4800,	Validation Loss: 0.3901,
# Epoch 215/1000,	Train Loss: 0.5174,	Validation Loss: 0.3902,
# 	Early stopping patience counter: 1/40
# Epoch 216/1000,	Train Loss: 0.4498,	Validation Loss: 0.3899,
# Epoch 217/1000,	Train Loss: 0.4689,	Validation Loss: 0.3898,
# Epoch 218/1000,	Train Loss: 0.5122,	Validation Loss: 0.3896,
# Epoch 219/1000,	Train Loss: 0.4826,	Validation Loss: 0.3893,
# Epoch 220/1000,	Train Loss: 0.5151,	Validation Loss: 0.3890,
# Epoch 221/1000,	Train Loss: 0.4576,	Validation Loss: 0.3890,
# Epoch 222/1000,	Train Loss: 0.5374,	Validation Loss: 0.3891,
# 	Early stopping patience counter: 1/40
# Epoch 223/1000,	Train Loss: 0.4823,	Validation Loss: 0.3891,
# 	Early stopping patience counter: 2/40
# Epoch 224/1000,	Train Loss: 0.5661,	Validation Loss: 0.3889,
# Epoch 225/1000,	Train Loss: 0.4891,	Validation Loss: 0.3885,
# Epoch 226/1000,	Train Loss: 0.5442,	Validation Loss: 0.3883,
# Epoch 227/1000,	Train Loss: 0.4751,	Validation Loss: 0.3882,
# Epoch 228/1000,	Train Loss: 0.4612,	Validation Loss: 0.3880,
# Epoch 229/1000,	Train Loss: 0.5559,	Validation Loss: 0.3876,
# Epoch 230/1000,	Train Loss: 0.5162,	Validation Loss: 0.3870,
# Epoch 231/1000,	Train Loss: 0.4444,	Validation Loss: 0.3867,
# Epoch 232/1000,	Train Loss: 0.4273,	Validation Loss: 0.3864,
# Epoch 233/1000,	Train Loss: 0.6135,	Validation Loss: 0.3865,
# 	Early stopping patience counter: 1/40
# Epoch 234/1000,	Train Loss: 0.4589,	Validation Loss: 0.3866,
# 	Early stopping patience counter: 2/40
# Epoch 235/1000,	Train Loss: 0.4260,	Validation Loss: 0.3864,
# 	Early stopping patience counter: 3/40
# Epoch 236/1000,	Train Loss: 0.4708,	Validation Loss: 0.3863,
# Epoch 237/1000,	Train Loss: 0.4018,	Validation Loss: 0.3863,
# Epoch 238/1000,	Train Loss: 0.4960,	Validation Loss: 0.3856,
# Epoch 239/1000,	Train Loss: 0.4650,	Validation Loss: 0.3849,
# Epoch 240/1000,	Train Loss: 0.5225,	Validation Loss: 0.3845,
# Epoch 241/1000,	Train Loss: 0.5213,	Validation Loss: 0.3841,
# Epoch 242/1000,	Train Loss: 0.5379,	Validation Loss: 0.3838,
# Epoch 243/1000,	Train Loss: 0.5132,	Validation Loss: 0.3833,
# Epoch 244/1000,	Train Loss: 0.4360,	Validation Loss: 0.3830,
# Epoch 245/1000,	Train Loss: 0.5541,	Validation Loss: 0.3828,
# Epoch 246/1000,	Train Loss: 0.5141,	Validation Loss: 0.3821,
# Epoch 247/1000,	Train Loss: 0.5205,	Validation Loss: 0.3817,
# Epoch 248/1000,	Train Loss: 0.4644,	Validation Loss: 0.3815,
# Epoch 249/1000,	Train Loss: 0.4888,	Validation Loss: 0.3814,
# Epoch 250/1000,	Train Loss: 0.4530,	Validation Loss: 0.3813,
# Epoch 251/1000,	Train Loss: 0.4605,	Validation Loss: 0.3810,
# Epoch 252/1000,	Train Loss: 0.4688,	Validation Loss: 0.3807,
# Epoch 253/1000,	Train Loss: 0.6276,	Validation Loss: 0.3806,
# Epoch 254/1000,	Train Loss: 0.4592,	Validation Loss: 0.3805,
# Epoch 255/1000,	Train Loss: 0.4420,	Validation Loss: 0.3803,
# Epoch 256/1000,	Train Loss: 0.4872,	Validation Loss: 0.3799,
# Epoch 257/1000,	Train Loss: 0.5229,	Validation Loss: 0.3794,
# Epoch 258/1000,	Train Loss: 0.4311,	Validation Loss: 0.3789,
# Epoch 259/1000,	Train Loss: 0.4501,	Validation Loss: 0.3788,
# Epoch 260/1000,	Train Loss: 0.4750,	Validation Loss: 0.3788,
# Epoch 261/1000,	Train Loss: 0.4351,	Validation Loss: 0.3785,
# Epoch 262/1000,	Train Loss: 0.4719,	Validation Loss: 0.3782,
# Epoch 263/1000,	Train Loss: 0.4310,	Validation Loss: 0.3775,
# Epoch 264/1000,	Train Loss: 0.5071,	Validation Loss: 0.3770,
# Epoch 265/1000,	Train Loss: 0.4902,	Validation Loss: 0.3768,
# Epoch 266/1000,	Train Loss: 0.4508,	Validation Loss: 0.3767,
# Epoch 267/1000,	Train Loss: 0.4574,	Validation Loss: 0.3766,
# Epoch 268/1000,	Train Loss: 0.4355,	Validation Loss: 0.3765,
# Epoch 269/1000,	Train Loss: 0.4260,	Validation Loss: 0.3761,
# Epoch 270/1000,	Train Loss: 0.4058,	Validation Loss: 0.3759,
# Epoch 271/1000,	Train Loss: 0.4216,	Validation Loss: 0.3755,
# Epoch 272/1000,	Train Loss: 0.5039,	Validation Loss: 0.3752,
# Epoch 273/1000,	Train Loss: 0.4807,	Validation Loss: 0.3750,
# Epoch 274/1000,	Train Loss: 0.4620,	Validation Loss: 0.3749,
# Epoch 275/1000,	Train Loss: 0.5621,	Validation Loss: 0.3748,
# Epoch 276/1000,	Train Loss: 0.4590,	Validation Loss: 0.3746,
# Epoch 277/1000,	Train Loss: 0.5405,	Validation Loss: 0.3745,
# Epoch 278/1000,	Train Loss: 0.5127,	Validation Loss: 0.3744,
# Epoch 279/1000,	Train Loss: 0.5565,	Validation Loss: 0.3745,
# 	Early stopping patience counter: 1/40
# Epoch 280/1000,	Train Loss: 0.5480,	Validation Loss: 0.3749,
# 	Early stopping patience counter: 2/40
# Epoch 281/1000,	Train Loss: 0.5236,	Validation Loss: 0.3754,
# 	Early stopping patience counter: 3/40
# Epoch 282/1000,	Train Loss: 0.5179,	Validation Loss: 0.3761,
# 	Early stopping patience counter: 4/40
# Epoch 283/1000,	Train Loss: 0.5150,	Validation Loss: 0.3767,
# 	Early stopping patience counter: 5/40
# Epoch 284/1000,	Train Loss: 0.4506,	Validation Loss: 0.3772,
# 	Early stopping patience counter: 6/40
# Epoch 285/1000,	Train Loss: 0.4782,	Validation Loss: 0.3780,
# 	Early stopping patience counter: 7/40
# Epoch 286/1000,	Train Loss: 0.5246,	Validation Loss: 0.3773,
# 	Early stopping patience counter: 8/40
# Epoch 287/1000,	Train Loss: 0.4966,	Validation Loss: 0.3768,
# 	Early stopping patience counter: 9/40
# Epoch 288/1000,	Train Loss: 0.4398,	Validation Loss: 0.3765,
# 	Early stopping patience counter: 10/40
# Epoch 289/1000,	Train Loss: 0.4328,	Validation Loss: 0.3765,
# 	Early stopping patience counter: 11/40
# Epoch 290/1000,	Train Loss: 0.5047,	Validation Loss: 0.3763,
# 	Early stopping patience counter: 12/40
# Epoch 291/1000,	Train Loss: 0.5758,	Validation Loss: 0.3758,
# 	Early stopping patience counter: 13/40
# Epoch 292/1000,	Train Loss: 0.4354,	Validation Loss: 0.3757,
# 	Early stopping patience counter: 14/40
# Epoch 293/1000,	Train Loss: 0.4010,	Validation Loss: 0.3757,
# 	Early stopping patience counter: 15/40
# Epoch 294/1000,	Train Loss: 0.5301,	Validation Loss: 0.3756,
# 	Early stopping patience counter: 16/40
# Epoch 295/1000,	Train Loss: 0.4262,	Validation Loss: 0.3755,
# 	Early stopping patience counter: 17/40
# Epoch 296/1000,	Train Loss: 0.5298,	Validation Loss: 0.3756,
# 	Early stopping patience counter: 18/40
# Epoch 297/1000,	Train Loss: 0.5133,	Validation Loss: 0.3759,
# 	Early stopping patience counter: 19/40
# Epoch 298/1000,	Train Loss: 0.4848,	Validation Loss: 0.3758,
# 	Early stopping patience counter: 20/40
# Epoch 299/1000,	Train Loss: 0.5187,	Validation Loss: 0.3760,
# 	Early stopping patience counter: 21/40
# Epoch 300/1000,	Train Loss: 0.4182,	Validation Loss: 0.3764,
# 	Early stopping patience counter: 22/40
# Epoch 301/1000,	Train Loss: 0.5452,	Validation Loss: 0.3772,
# 	Early stopping patience counter: 23/40
# Epoch 302/1000,	Train Loss: 0.5334,	Validation Loss: 0.3775,
# 	Early stopping patience counter: 24/40
# Epoch 303/1000,	Train Loss: 0.4615,	Validation Loss: 0.3779,
# 	Early stopping patience counter: 25/40
# Epoch 304/1000,	Train Loss: 0.4447,	Validation Loss: 0.3783,
# 	Early stopping patience counter: 26/40
# Epoch 305/1000,	Train Loss: 0.4479,	Validation Loss: 0.3783,
# 	Early stopping patience counter: 27/40
# Epoch 306/1000,	Train Loss: 0.5873,	Validation Loss: 0.3768,
# 	Early stopping patience counter: 28/40
# Epoch 307/1000,	Train Loss: 0.4460,	Validation Loss: 0.3762,
# 	Early stopping patience counter: 29/40
# Epoch 308/1000,	Train Loss: 0.4612,	Validation Loss: 0.3759,
# 	Early stopping patience counter: 30/40
# Epoch 309/1000,	Train Loss: 0.4974,	Validation Loss: 0.3757,
# 	Early stopping patience counter: 31/40
# Epoch 310/1000,	Train Loss: 0.5321,	Validation Loss: 0.3760,
# 	Early stopping patience counter: 32/40
# Epoch 311/1000,	Train Loss: 0.4697,	Validation Loss: 0.3764,
# 	Early stopping patience counter: 33/40
# Epoch 312/1000,	Train Loss: 0.4475,	Validation Loss: 0.3769,
# 	Early stopping patience counter: 34/40
# Epoch 313/1000,	Train Loss: 0.4376,	Validation Loss: 0.3769,
# 	Early stopping patience counter: 35/40
# Epoch 314/1000,	Train Loss: 0.4969,	Validation Loss: 0.3770,
# 	Early stopping patience counter: 36/40
# Epoch 315/1000,	Train Loss: 0.4739,	Validation Loss: 0.3772,
# 	Early stopping patience counter: 37/40
# Epoch 316/1000,	Train Loss: 0.4814,	Validation Loss: 0.3772,
# 	Early stopping patience counter: 38/40
# Epoch 317/1000,	Train Loss: 0.4983,	Validation Loss: 0.3771,
# 	Early stopping patience counter: 39/40
# Epoch 318/1000,	Train Loss: 0.5187,	Validation Loss: 0.3770,
# 	Early stopping patience counter: 40/40
# 	Early stopping triggered. Stopping training.
# ===================================
#  M O D E L   L O C A T I O N :
# nn_models\mlp_step_2025-05-14-00-16-15.pth
# ===================================
#
#
#
# ===================================
#  persons_in_overlap: 35
# ===================================

# %%
plot_shaps(model_step, features_step)

# %%
print_stats(model_step, val_loader_step, params)
# Out:
# {'typ': 'step', 'batch_size': 512, 'hidden_size': [4, 2], 'dropout_prob': 0.2, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40, 'l2_lambda': 0}
# Validation Loss:	0.3744
# Mean vizier:		0.9083
# Mean non-vizier:	0.1561
# bottom_3_vizier:	0.9998
# top_3_non_vizier:	0.9776
# PiO Validation:		18

# %% [raw]
# {'typ': 'step', 'batch_size': 512, 'hidden_size': [4], 'activation_name': 'leaky_relu', 'optimizer_name': 'adam', 'dropout_prob': 0.1, 'epochs': 1500, 'learning_rate': 0.005, 'patience': 40}
# Validation Loss:	0.0539
# Mean vizier:		0.9973
# Mean non-vizier:	0.0322
# bottom_3_vizier:	0.9971
# top_3_non_vizier:	0.8346
# PiO Validation:		4
#
# {'typ': 'step', 'batch_size': 512, 'hidden_size': [4], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0.1, 'epochs': 1500, 'learning_rate': 0.005, 'patience': 40, 'l2_lambda': 0}
# Validation Loss:	0.0428
# Mean vizier:		0.9899
# Mean non-vizier:	0.0169
# bottom_3_vizier:	0.9857
# top_3_non_vizier:	0.8296
# PiO Validation:		3

# %% [markdown]
# ### Lasso NN

# %% [raw]
# params = {'typ': 'lasso',
#           'batch_size': 512,
#           'hidden_size': [12, 8],
#           'dropout_prob': 0.5,
#           'activation_name': 'relu',
#           'optimizer_name': 'adam',
#           'epochs': 1000,
#           'learning_rate': 0.002,
#           'patience': 40,
#           'l2_lambda': 0.02
#          }
# model_lasso, val_loader_lasso = train_nn(params)

# %%
params = {'typ': 'lasso',
          'batch_size': 512,
          'hidden_size': [12, 8],
          'dropout_prob': 0.5,
          'activation_name': 'relu',
          'optimizer_name': 'adam',
          'epochs': 1000,
          'learning_rate': 0.0005,
          'patience': 40,
          'l2_lambda': 0.07
         }
model_lasso, val_loader_lasso = train_nn(params)
# Out:
# ===================================
#  S T A R T I N G   M O D E L
# ===================================
#
# Defined BinaryClassifier with criterion=BCEWithLogitsLoss()
# Defined BinaryClassifier with optimizer=Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0.07
# )
#
# ===================================
# MODEL ARCHITECTURE:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=21, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=12, out_features=8, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=8, out_features=1, bias=True)
#   )
# )
# ===================================
#
#
# ===================================
# NUMBER OF PARAMETERS: 377
# ===================================
#
# Epoch 1/1000,	Train Loss: 1.3580,	Validation Loss: 1.3298,
# Epoch 2/1000,	Train Loss: 1.3501,	Validation Loss: 1.3284,
# Epoch 3/1000,	Train Loss: 1.3538,	Validation Loss: 1.3271,
# Epoch 4/1000,	Train Loss: 1.3413,	Validation Loss: 1.3258,
# Epoch 5/1000,	Train Loss: 1.3515,	Validation Loss: 1.3244,
# Epoch 6/1000,	Train Loss: 1.3545,	Validation Loss: 1.3230,
# Epoch 7/1000,	Train Loss: 1.3448,	Validation Loss: 1.3218,
# Epoch 8/1000,	Train Loss: 1.3466,	Validation Loss: 1.3204,
# Epoch 9/1000,	Train Loss: 1.3389,	Validation Loss: 1.3189,
# Epoch 10/1000,	Train Loss: 1.3342,	Validation Loss: 1.3174,
# Epoch 11/1000,	Train Loss: 1.3356,	Validation Loss: 1.3156,
# Epoch 12/1000,	Train Loss: 1.3457,	Validation Loss: 1.3138,
# Epoch 13/1000,	Train Loss: 1.3440,	Validation Loss: 1.3121,
# Epoch 14/1000,	Train Loss: 1.3441,	Validation Loss: 1.3107,
# Epoch 15/1000,	Train Loss: 1.3230,	Validation Loss: 1.3090,
# Epoch 16/1000,	Train Loss: 1.3348,	Validation Loss: 1.3072,
# Epoch 17/1000,	Train Loss: 1.3216,	Validation Loss: 1.3049,
# Epoch 18/1000,	Train Loss: 1.3538,	Validation Loss: 1.3028,
# Epoch 19/1000,	Train Loss: 1.3104,	Validation Loss: 1.3009,
# Epoch 20/1000,	Train Loss: 1.3255,	Validation Loss: 1.2989,
# Epoch 21/1000,	Train Loss: 1.3268,	Validation Loss: 1.2972,
# Epoch 22/1000,	Train Loss: 1.2985,	Validation Loss: 1.2951,
# Epoch 23/1000,	Train Loss: 1.3136,	Validation Loss: 1.2925,
# Epoch 24/1000,	Train Loss: 1.3072,	Validation Loss: 1.2893,
# Epoch 25/1000,	Train Loss: 1.3146,	Validation Loss: 1.2865,
# Epoch 26/1000,	Train Loss: 1.2961,	Validation Loss: 1.2834,
# Epoch 27/1000,	Train Loss: 1.3176,	Validation Loss: 1.2807,
# Epoch 28/1000,	Train Loss: 1.3108,	Validation Loss: 1.2780,
# Epoch 29/1000,	Train Loss: 1.2970,	Validation Loss: 1.2750,
# Epoch 30/1000,	Train Loss: 1.3060,	Validation Loss: 1.2719,
# Epoch 31/1000,	Train Loss: 1.3040,	Validation Loss: 1.2685,
# Epoch 32/1000,	Train Loss: 1.3103,	Validation Loss: 1.2655,
# Epoch 33/1000,	Train Loss: 1.2840,	Validation Loss: 1.2622,
# Epoch 34/1000,	Train Loss: 1.2882,	Validation Loss: 1.2584,
# Epoch 35/1000,	Train Loss: 1.2927,	Validation Loss: 1.2544,
# Epoch 36/1000,	Train Loss: 1.2782,	Validation Loss: 1.2502,
# Epoch 37/1000,	Train Loss: 1.2716,	Validation Loss: 1.2458,
# Epoch 38/1000,	Train Loss: 1.2843,	Validation Loss: 1.2418,
# Epoch 39/1000,	Train Loss: 1.2731,	Validation Loss: 1.2374,
# Epoch 40/1000,	Train Loss: 1.2308,	Validation Loss: 1.2323,
# Epoch 41/1000,	Train Loss: 1.2324,	Validation Loss: 1.2265,
# Epoch 42/1000,	Train Loss: 1.2705,	Validation Loss: 1.2213,
# Epoch 43/1000,	Train Loss: 1.2604,	Validation Loss: 1.2162,
# Epoch 44/1000,	Train Loss: 1.2369,	Validation Loss: 1.2107,
# Epoch 45/1000,	Train Loss: 1.2606,	Validation Loss: 1.2051,
# Epoch 46/1000,	Train Loss: 1.2401,	Validation Loss: 1.1995,
# Epoch 47/1000,	Train Loss: 1.2546,	Validation Loss: 1.1944,
# Epoch 48/1000,	Train Loss: 1.2425,	Validation Loss: 1.1887,
# Epoch 49/1000,	Train Loss: 1.1993,	Validation Loss: 1.1827,
# Epoch 50/1000,	Train Loss: 1.2355,	Validation Loss: 1.1767,
# Epoch 51/1000,	Train Loss: 1.1875,	Validation Loss: 1.1703,
# Epoch 52/1000,	Train Loss: 1.2078,	Validation Loss: 1.1639,
# Epoch 53/1000,	Train Loss: 1.1953,	Validation Loss: 1.1572,
# Epoch 54/1000,	Train Loss: 1.2012,	Validation Loss: 1.1501,
# Epoch 55/1000,	Train Loss: 1.1936,	Validation Loss: 1.1422,
# Epoch 56/1000,	Train Loss: 1.2106,	Validation Loss: 1.1345,
# Epoch 57/1000,	Train Loss: 1.1900,	Validation Loss: 1.1270,
# Epoch 58/1000,	Train Loss: 1.1685,	Validation Loss: 1.1192,
# Epoch 59/1000,	Train Loss: 1.1903,	Validation Loss: 1.1121,
# Epoch 60/1000,	Train Loss: 1.1773,	Validation Loss: 1.1041,
# Epoch 61/1000,	Train Loss: 1.1549,	Validation Loss: 1.0963,
# Epoch 62/1000,	Train Loss: 1.1555,	Validation Loss: 1.0883,
# Epoch 63/1000,	Train Loss: 1.1753,	Validation Loss: 1.0807,
# Epoch 64/1000,	Train Loss: 1.1315,	Validation Loss: 1.0733,
# Epoch 65/1000,	Train Loss: 1.1479,	Validation Loss: 1.0648,
# Epoch 66/1000,	Train Loss: 1.1730,	Validation Loss: 1.0565,
# Epoch 67/1000,	Train Loss: 1.1303,	Validation Loss: 1.0476,
# Epoch 68/1000,	Train Loss: 1.1029,	Validation Loss: 1.0375,
# Epoch 69/1000,	Train Loss: 1.1641,	Validation Loss: 1.0282,
# Epoch 70/1000,	Train Loss: 1.0916,	Validation Loss: 1.0193,
# Epoch 71/1000,	Train Loss: 1.0692,	Validation Loss: 1.0101,
# Epoch 72/1000,	Train Loss: 1.0518,	Validation Loss: 1.0007,
# Epoch 73/1000,	Train Loss: 1.1055,	Validation Loss: 0.9917,
# Epoch 74/1000,	Train Loss: 1.0389,	Validation Loss: 0.9817,
# Epoch 75/1000,	Train Loss: 1.0672,	Validation Loss: 0.9718,
# Epoch 76/1000,	Train Loss: 1.0667,	Validation Loss: 0.9625,
# Epoch 77/1000,	Train Loss: 1.1029,	Validation Loss: 0.9523,
# Epoch 78/1000,	Train Loss: 1.0507,	Validation Loss: 0.9428,
# Epoch 79/1000,	Train Loss: 1.0226,	Validation Loss: 0.9324,
# Epoch 80/1000,	Train Loss: 1.0647,	Validation Loss: 0.9218,
# Epoch 81/1000,	Train Loss: 1.0656,	Validation Loss: 0.9117,
# Epoch 82/1000,	Train Loss: 0.9957,	Validation Loss: 0.9011,
# Epoch 83/1000,	Train Loss: 1.0172,	Validation Loss: 0.8915,
# Epoch 84/1000,	Train Loss: 1.0078,	Validation Loss: 0.8825,
# Epoch 85/1000,	Train Loss: 0.9394,	Validation Loss: 0.8721,
# Epoch 86/1000,	Train Loss: 1.0272,	Validation Loss: 0.8632,
# Epoch 87/1000,	Train Loss: 0.9994,	Validation Loss: 0.8535,
# Epoch 88/1000,	Train Loss: 0.9488,	Validation Loss: 0.8436,
# Epoch 89/1000,	Train Loss: 1.0021,	Validation Loss: 0.8340,
# Epoch 90/1000,	Train Loss: 0.9901,	Validation Loss: 0.8244,
# Epoch 91/1000,	Train Loss: 0.9614,	Validation Loss: 0.8147,
# Epoch 92/1000,	Train Loss: 0.9519,	Validation Loss: 0.8059,
# Epoch 93/1000,	Train Loss: 0.9645,	Validation Loss: 0.7970,
# Epoch 94/1000,	Train Loss: 0.9223,	Validation Loss: 0.7872,
# Epoch 95/1000,	Train Loss: 0.9474,	Validation Loss: 0.7752,
# Epoch 96/1000,	Train Loss: 0.8706,	Validation Loss: 0.7638,
# Epoch 97/1000,	Train Loss: 0.9001,	Validation Loss: 0.7541,
# Epoch 98/1000,	Train Loss: 0.8644,	Validation Loss: 0.7456,
# Epoch 99/1000,	Train Loss: 0.9173,	Validation Loss: 0.7370,
# Epoch 100/1000,	Train Loss: 0.8614,	Validation Loss: 0.7282,
# Epoch 101/1000,	Train Loss: 0.9112,	Validation Loss: 0.7197,
# Epoch 102/1000,	Train Loss: 0.8951,	Validation Loss: 0.7108,
# Epoch 103/1000,	Train Loss: 0.8731,	Validation Loss: 0.7015,
# Epoch 104/1000,	Train Loss: 0.9230,	Validation Loss: 0.6917,
# Epoch 105/1000,	Train Loss: 0.8505,	Validation Loss: 0.6826,
# Epoch 106/1000,	Train Loss: 0.8143,	Validation Loss: 0.6735,
# Epoch 107/1000,	Train Loss: 0.9021,	Validation Loss: 0.6648,
# Epoch 108/1000,	Train Loss: 0.8511,	Validation Loss: 0.6559,
# Epoch 109/1000,	Train Loss: 0.8033,	Validation Loss: 0.6473,
# Epoch 110/1000,	Train Loss: 0.7494,	Validation Loss: 0.6379,
# Epoch 111/1000,	Train Loss: 0.8330,	Validation Loss: 0.6293,
# Epoch 112/1000,	Train Loss: 0.8527,	Validation Loss: 0.6218,
# Epoch 113/1000,	Train Loss: 0.8306,	Validation Loss: 0.6150,
# Epoch 114/1000,	Train Loss: 0.8470,	Validation Loss: 0.6077,
# Epoch 115/1000,	Train Loss: 0.7861,	Validation Loss: 0.5991,
# Epoch 116/1000,	Train Loss: 0.8309,	Validation Loss: 0.5921,
# Epoch 117/1000,	Train Loss: 0.7713,	Validation Loss: 0.5853,
# Epoch 118/1000,	Train Loss: 0.7618,	Validation Loss: 0.5791,
# Epoch 119/1000,	Train Loss: 0.7770,	Validation Loss: 0.5728,
# Epoch 120/1000,	Train Loss: 0.8088,	Validation Loss: 0.5661,
# Epoch 121/1000,	Train Loss: 0.7406,	Validation Loss: 0.5595,
# Epoch 122/1000,	Train Loss: 0.7338,	Validation Loss: 0.5523,
# Epoch 123/1000,	Train Loss: 0.7420,	Validation Loss: 0.5447,
# Epoch 124/1000,	Train Loss: 0.7126,	Validation Loss: 0.5376,
# Epoch 125/1000,	Train Loss: 0.7015,	Validation Loss: 0.5305,
# Epoch 126/1000,	Train Loss: 0.8234,	Validation Loss: 0.5238,
# Epoch 127/1000,	Train Loss: 0.7757,	Validation Loss: 0.5183,
# Epoch 128/1000,	Train Loss: 0.7391,	Validation Loss: 0.5130,
# Epoch 129/1000,	Train Loss: 0.7379,	Validation Loss: 0.5077,
# Epoch 130/1000,	Train Loss: 0.7524,	Validation Loss: 0.5019,
# Epoch 131/1000,	Train Loss: 0.7426,	Validation Loss: 0.4968,
# Epoch 132/1000,	Train Loss: 0.7455,	Validation Loss: 0.4937,
# Epoch 133/1000,	Train Loss: 0.8030,	Validation Loss: 0.4891,
# Epoch 134/1000,	Train Loss: 0.6924,	Validation Loss: 0.4843,
# Epoch 135/1000,	Train Loss: 0.7068,	Validation Loss: 0.4790,
# Epoch 136/1000,	Train Loss: 0.7375,	Validation Loss: 0.4737,
# Epoch 137/1000,	Train Loss: 0.7354,	Validation Loss: 0.4692,
# Epoch 138/1000,	Train Loss: 0.6604,	Validation Loss: 0.4639,
# Epoch 139/1000,	Train Loss: 0.6756,	Validation Loss: 0.4589,
# Epoch 140/1000,	Train Loss: 0.6619,	Validation Loss: 0.4550,
# Epoch 141/1000,	Train Loss: 0.7279,	Validation Loss: 0.4516,
# Epoch 142/1000,	Train Loss: 0.6278,	Validation Loss: 0.4478,
# Epoch 143/1000,	Train Loss: 0.6479,	Validation Loss: 0.4433,
# Epoch 144/1000,	Train Loss: 0.7394,	Validation Loss: 0.4395,
# Epoch 145/1000,	Train Loss: 0.6600,	Validation Loss: 0.4375,
# Epoch 146/1000,	Train Loss: 0.6328,	Validation Loss: 0.4345,
# Epoch 147/1000,	Train Loss: 0.6551,	Validation Loss: 0.4311,
# Epoch 148/1000,	Train Loss: 0.6170,	Validation Loss: 0.4283,
# Epoch 149/1000,	Train Loss: 0.6661,	Validation Loss: 0.4247,
# Epoch 150/1000,	Train Loss: 0.6618,	Validation Loss: 0.4216,
# Epoch 151/1000,	Train Loss: 0.6681,	Validation Loss: 0.4190,
# Epoch 152/1000,	Train Loss: 0.6718,	Validation Loss: 0.4170,
# Epoch 153/1000,	Train Loss: 0.6435,	Validation Loss: 0.4146,
# Epoch 154/1000,	Train Loss: 0.6499,	Validation Loss: 0.4122,
# Epoch 155/1000,	Train Loss: 0.6496,	Validation Loss: 0.4092,
# Epoch 156/1000,	Train Loss: 0.6663,	Validation Loss: 0.4084,
# Epoch 157/1000,	Train Loss: 0.6302,	Validation Loss: 0.4074,
# Epoch 158/1000,	Train Loss: 0.6869,	Validation Loss: 0.4058,
# Epoch 159/1000,	Train Loss: 0.6453,	Validation Loss: 0.4038,
# Epoch 160/1000,	Train Loss: 0.6627,	Validation Loss: 0.4012,
# Epoch 161/1000,	Train Loss: 0.6607,	Validation Loss: 0.3990,
# Epoch 162/1000,	Train Loss: 0.7032,	Validation Loss: 0.3972,
# Epoch 163/1000,	Train Loss: 0.6852,	Validation Loss: 0.3946,
# Epoch 164/1000,	Train Loss: 0.7168,	Validation Loss: 0.3931,
# Epoch 165/1000,	Train Loss: 0.6143,	Validation Loss: 0.3927,
# Epoch 166/1000,	Train Loss: 0.6474,	Validation Loss: 0.3916,
# Epoch 167/1000,	Train Loss: 0.6513,	Validation Loss: 0.3901,
# Epoch 168/1000,	Train Loss: 0.5758,	Validation Loss: 0.3879,
# Epoch 169/1000,	Train Loss: 0.6396,	Validation Loss: 0.3850,
# Epoch 170/1000,	Train Loss: 0.6631,	Validation Loss: 0.3821,
# Epoch 171/1000,	Train Loss: 0.6317,	Validation Loss: 0.3792,
# Epoch 172/1000,	Train Loss: 0.7087,	Validation Loss: 0.3782,
# Epoch 173/1000,	Train Loss: 0.5961,	Validation Loss: 0.3763,
# Epoch 174/1000,	Train Loss: 0.6052,	Validation Loss: 0.3742,
# Epoch 175/1000,	Train Loss: 0.6749,	Validation Loss: 0.3744,
# 	Early stopping patience counter: 1/40
# Epoch 176/1000,	Train Loss: 0.5998,	Validation Loss: 0.3735,
# Epoch 177/1000,	Train Loss: 0.6245,	Validation Loss: 0.3724,
# Epoch 178/1000,	Train Loss: 0.6118,	Validation Loss: 0.3718,
# Epoch 179/1000,	Train Loss: 0.5818,	Validation Loss: 0.3698,
# Epoch 180/1000,	Train Loss: 0.6007,	Validation Loss: 0.3681,
# Epoch 181/1000,	Train Loss: 0.6083,	Validation Loss: 0.3661,
# Epoch 182/1000,	Train Loss: 0.5613,	Validation Loss: 0.3648,
# Epoch 183/1000,	Train Loss: 0.6350,	Validation Loss: 0.3633,
# Epoch 184/1000,	Train Loss: 0.5442,	Validation Loss: 0.3615,
# Epoch 185/1000,	Train Loss: 0.6115,	Validation Loss: 0.3604,
# Epoch 186/1000,	Train Loss: 0.7086,	Validation Loss: 0.3603,
# Epoch 187/1000,	Train Loss: 0.6311,	Validation Loss: 0.3595,
# Epoch 188/1000,	Train Loss: 0.5836,	Validation Loss: 0.3589,
# Epoch 189/1000,	Train Loss: 0.6119,	Validation Loss: 0.3592,
# 	Early stopping patience counter: 1/40
# Epoch 190/1000,	Train Loss: 0.6153,	Validation Loss: 0.3591,
# 	Early stopping patience counter: 2/40
# Epoch 191/1000,	Train Loss: 0.6362,	Validation Loss: 0.3588,
# Epoch 192/1000,	Train Loss: 0.5829,	Validation Loss: 0.3579,
# Epoch 193/1000,	Train Loss: 0.6446,	Validation Loss: 0.3576,
# Epoch 194/1000,	Train Loss: 0.6869,	Validation Loss: 0.3578,
# 	Early stopping patience counter: 1/40
# Epoch 195/1000,	Train Loss: 0.6225,	Validation Loss: 0.3582,
# 	Early stopping patience counter: 2/40
# Epoch 196/1000,	Train Loss: 0.6593,	Validation Loss: 0.3579,
# 	Early stopping patience counter: 3/40
# Epoch 197/1000,	Train Loss: 0.6495,	Validation Loss: 0.3582,
# 	Early stopping patience counter: 4/40
# Epoch 198/1000,	Train Loss: 0.5165,	Validation Loss: 0.3568,
# Epoch 199/1000,	Train Loss: 0.5366,	Validation Loss: 0.3552,
# Epoch 200/1000,	Train Loss: 0.5984,	Validation Loss: 0.3543,
# Epoch 201/1000,	Train Loss: 0.5534,	Validation Loss: 0.3533,
# Epoch 202/1000,	Train Loss: 0.6028,	Validation Loss: 0.3526,
# Epoch 203/1000,	Train Loss: 0.5447,	Validation Loss: 0.3517,
# Epoch 204/1000,	Train Loss: 0.5769,	Validation Loss: 0.3497,
# Epoch 205/1000,	Train Loss: 0.6441,	Validation Loss: 0.3497,
# 	Early stopping patience counter: 1/40
# Epoch 206/1000,	Train Loss: 0.6116,	Validation Loss: 0.3495,
# Epoch 207/1000,	Train Loss: 0.6720,	Validation Loss: 0.3488,
# Epoch 208/1000,	Train Loss: 0.5900,	Validation Loss: 0.3502,
# 	Early stopping patience counter: 1/40
# Epoch 209/1000,	Train Loss: 0.6089,	Validation Loss: 0.3505,
# 	Early stopping patience counter: 2/40
# Epoch 210/1000,	Train Loss: 0.5659,	Validation Loss: 0.3497,
# 	Early stopping patience counter: 3/40
# Epoch 211/1000,	Train Loss: 0.5836,	Validation Loss: 0.3484,
# Epoch 212/1000,	Train Loss: 0.5707,	Validation Loss: 0.3470,
# Epoch 213/1000,	Train Loss: 0.6142,	Validation Loss: 0.3457,
# Epoch 214/1000,	Train Loss: 0.6236,	Validation Loss: 0.3453,
# Epoch 215/1000,	Train Loss: 0.5933,	Validation Loss: 0.3461,
# 	Early stopping patience counter: 1/40
# Epoch 216/1000,	Train Loss: 0.6258,	Validation Loss: 0.3467,
# 	Early stopping patience counter: 2/40
# Epoch 217/1000,	Train Loss: 0.6184,	Validation Loss: 0.3470,
# 	Early stopping patience counter: 3/40
# Epoch 218/1000,	Train Loss: 0.5862,	Validation Loss: 0.3481,
# 	Early stopping patience counter: 4/40
# Epoch 219/1000,	Train Loss: 0.5585,	Validation Loss: 0.3480,
# 	Early stopping patience counter: 5/40
# Epoch 220/1000,	Train Loss: 0.5715,	Validation Loss: 0.3477,
# 	Early stopping patience counter: 6/40
# Epoch 221/1000,	Train Loss: 0.5026,	Validation Loss: 0.3464,
# 	Early stopping patience counter: 7/40
# Epoch 222/1000,	Train Loss: 0.5875,	Validation Loss: 0.3450,
# Epoch 223/1000,	Train Loss: 0.6636,	Validation Loss: 0.3440,
# Epoch 224/1000,	Train Loss: 0.5984,	Validation Loss: 0.3426,
# Epoch 225/1000,	Train Loss: 0.6106,	Validation Loss: 0.3413,
# Epoch 226/1000,	Train Loss: 0.5560,	Validation Loss: 0.3405,
# Epoch 227/1000,	Train Loss: 0.5716,	Validation Loss: 0.3396,
# Epoch 228/1000,	Train Loss: 0.5473,	Validation Loss: 0.3387,
# Epoch 229/1000,	Train Loss: 0.6026,	Validation Loss: 0.3382,
# Epoch 230/1000,	Train Loss: 0.6188,	Validation Loss: 0.3384,
# 	Early stopping patience counter: 1/40
# Epoch 231/1000,	Train Loss: 0.5955,	Validation Loss: 0.3377,
# Epoch 232/1000,	Train Loss: 0.5778,	Validation Loss: 0.3373,
# Epoch 233/1000,	Train Loss: 0.5782,	Validation Loss: 0.3377,
# 	Early stopping patience counter: 1/40
# Epoch 234/1000,	Train Loss: 0.5923,	Validation Loss: 0.3376,
# 	Early stopping patience counter: 2/40
# Epoch 235/1000,	Train Loss: 0.5936,	Validation Loss: 0.3368,
# Epoch 236/1000,	Train Loss: 0.5166,	Validation Loss: 0.3360,
# Epoch 237/1000,	Train Loss: 0.5557,	Validation Loss: 0.3358,
# Epoch 238/1000,	Train Loss: 0.5924,	Validation Loss: 0.3358,
# Epoch 239/1000,	Train Loss: 0.5084,	Validation Loss: 0.3352,
# Epoch 240/1000,	Train Loss: 0.5444,	Validation Loss: 0.3341,
# Epoch 241/1000,	Train Loss: 0.5559,	Validation Loss: 0.3331,
# Epoch 242/1000,	Train Loss: 0.5485,	Validation Loss: 0.3320,
# Epoch 243/1000,	Train Loss: 0.5731,	Validation Loss: 0.3313,
# Epoch 244/1000,	Train Loss: 0.6224,	Validation Loss: 0.3311,
# Epoch 245/1000,	Train Loss: 0.5635,	Validation Loss: 0.3303,
# Epoch 246/1000,	Train Loss: 0.6168,	Validation Loss: 0.3298,
# Epoch 247/1000,	Train Loss: 0.5920,	Validation Loss: 0.3290,
# Epoch 248/1000,	Train Loss: 0.5115,	Validation Loss: 0.3286,
# Epoch 249/1000,	Train Loss: 0.5650,	Validation Loss: 0.3283,
# Epoch 250/1000,	Train Loss: 0.6122,	Validation Loss: 0.3282,
# Epoch 251/1000,	Train Loss: 0.5673,	Validation Loss: 0.3280,
# Epoch 252/1000,	Train Loss: 0.6468,	Validation Loss: 0.3283,
# 	Early stopping patience counter: 1/40
# Epoch 253/1000,	Train Loss: 0.5774,	Validation Loss: 0.3281,
# 	Early stopping patience counter: 2/40
# Epoch 254/1000,	Train Loss: 0.5528,	Validation Loss: 0.3276,
# Epoch 255/1000,	Train Loss: 0.6855,	Validation Loss: 0.3272,
# Epoch 256/1000,	Train Loss: 0.5680,	Validation Loss: 0.3270,
# Epoch 257/1000,	Train Loss: 0.5925,	Validation Loss: 0.3274,
# 	Early stopping patience counter: 1/40
# Epoch 258/1000,	Train Loss: 0.5923,	Validation Loss: 0.3293,
# 	Early stopping patience counter: 2/40
# Epoch 259/1000,	Train Loss: 0.6193,	Validation Loss: 0.3298,
# 	Early stopping patience counter: 3/40
# Epoch 260/1000,	Train Loss: 0.5461,	Validation Loss: 0.3289,
# 	Early stopping patience counter: 4/40
# Epoch 261/1000,	Train Loss: 0.6077,	Validation Loss: 0.3279,
# 	Early stopping patience counter: 5/40
# Epoch 262/1000,	Train Loss: 0.5351,	Validation Loss: 0.3265,
# Epoch 263/1000,	Train Loss: 0.5901,	Validation Loss: 0.3252,
# Epoch 264/1000,	Train Loss: 0.6139,	Validation Loss: 0.3244,
# Epoch 265/1000,	Train Loss: 0.5682,	Validation Loss: 0.3242,
# Epoch 266/1000,	Train Loss: 0.5289,	Validation Loss: 0.3235,
# Epoch 267/1000,	Train Loss: 0.6016,	Validation Loss: 0.3236,
# 	Early stopping patience counter: 1/40
# Epoch 268/1000,	Train Loss: 0.5759,	Validation Loss: 0.3232,
# Epoch 269/1000,	Train Loss: 0.5579,	Validation Loss: 0.3233,
# 	Early stopping patience counter: 1/40
# Epoch 270/1000,	Train Loss: 0.5388,	Validation Loss: 0.3231,
# Epoch 271/1000,	Train Loss: 0.5926,	Validation Loss: 0.3227,
# Epoch 272/1000,	Train Loss: 0.5934,	Validation Loss: 0.3228,
# 	Early stopping patience counter: 1/40
# Epoch 273/1000,	Train Loss: 0.5755,	Validation Loss: 0.3219,
# Epoch 274/1000,	Train Loss: 0.5234,	Validation Loss: 0.3206,
# Epoch 275/1000,	Train Loss: 0.5313,	Validation Loss: 0.3202,
# Epoch 276/1000,	Train Loss: 0.5499,	Validation Loss: 0.3198,
# Epoch 277/1000,	Train Loss: 0.5733,	Validation Loss: 0.3206,
# 	Early stopping patience counter: 1/40
# Epoch 278/1000,	Train Loss: 0.5224,	Validation Loss: 0.3205,
# 	Early stopping patience counter: 2/40
# Epoch 279/1000,	Train Loss: 0.5141,	Validation Loss: 0.3194,
# Epoch 280/1000,	Train Loss: 0.5880,	Validation Loss: 0.3186,
# Epoch 281/1000,	Train Loss: 0.6054,	Validation Loss: 0.3176,
# Epoch 282/1000,	Train Loss: 0.5108,	Validation Loss: 0.3166,
# Epoch 283/1000,	Train Loss: 0.5053,	Validation Loss: 0.3151,
# Epoch 284/1000,	Train Loss: 0.5675,	Validation Loss: 0.3149,
# Epoch 285/1000,	Train Loss: 0.5900,	Validation Loss: 0.3159,
# 	Early stopping patience counter: 1/40
# Epoch 286/1000,	Train Loss: 0.5389,	Validation Loss: 0.3160,
# 	Early stopping patience counter: 2/40
# Epoch 287/1000,	Train Loss: 0.5506,	Validation Loss: 0.3160,
# 	Early stopping patience counter: 3/40
# Epoch 288/1000,	Train Loss: 0.5133,	Validation Loss: 0.3153,
# 	Early stopping patience counter: 4/40
# Epoch 289/1000,	Train Loss: 0.5867,	Validation Loss: 0.3163,
# 	Early stopping patience counter: 5/40
# Epoch 290/1000,	Train Loss: 0.6006,	Validation Loss: 0.3166,
# 	Early stopping patience counter: 6/40
# Epoch 291/1000,	Train Loss: 0.6234,	Validation Loss: 0.3174,
# 	Early stopping patience counter: 7/40
# Epoch 292/1000,	Train Loss: 0.5674,	Validation Loss: 0.3170,
# 	Early stopping patience counter: 8/40
# Epoch 293/1000,	Train Loss: 0.4737,	Validation Loss: 0.3160,
# 	Early stopping patience counter: 9/40
# Epoch 294/1000,	Train Loss: 0.5489,	Validation Loss: 0.3151,
# 	Early stopping patience counter: 10/40
# Epoch 295/1000,	Train Loss: 0.5592,	Validation Loss: 0.3146,
# Epoch 296/1000,	Train Loss: 0.5270,	Validation Loss: 0.3141,
# Epoch 297/1000,	Train Loss: 0.4875,	Validation Loss: 0.3136,
# Epoch 298/1000,	Train Loss: 0.6436,	Validation Loss: 0.3137,
# 	Early stopping patience counter: 1/40
# Epoch 299/1000,	Train Loss: 0.5160,	Validation Loss: 0.3146,
# 	Early stopping patience counter: 2/40
# Epoch 300/1000,	Train Loss: 0.5931,	Validation Loss: 0.3150,
# 	Early stopping patience counter: 3/40
# Epoch 301/1000,	Train Loss: 0.5842,	Validation Loss: 0.3151,
# 	Early stopping patience counter: 4/40
# Epoch 302/1000,	Train Loss: 0.5443,	Validation Loss: 0.3145,
# 	Early stopping patience counter: 5/40
# Epoch 303/1000,	Train Loss: 0.5445,	Validation Loss: 0.3142,
# 	Early stopping patience counter: 6/40
# Epoch 304/1000,	Train Loss: 0.5360,	Validation Loss: 0.3137,
# 	Early stopping patience counter: 7/40
# Epoch 305/1000,	Train Loss: 0.5619,	Validation Loss: 0.3132,
# Epoch 306/1000,	Train Loss: 0.6008,	Validation Loss: 0.3128,
# Epoch 307/1000,	Train Loss: 0.5722,	Validation Loss: 0.3118,
# Epoch 308/1000,	Train Loss: 0.5635,	Validation Loss: 0.3109,
# Epoch 309/1000,	Train Loss: 0.5698,	Validation Loss: 0.3098,
# Epoch 310/1000,	Train Loss: 0.5035,	Validation Loss: 0.3090,
# Epoch 311/1000,	Train Loss: 0.5711,	Validation Loss: 0.3080,
# Epoch 312/1000,	Train Loss: 0.5810,	Validation Loss: 0.3072,
# Epoch 313/1000,	Train Loss: 0.5359,	Validation Loss: 0.3066,
# Epoch 314/1000,	Train Loss: 0.6000,	Validation Loss: 0.3057,
# Epoch 315/1000,	Train Loss: 0.6033,	Validation Loss: 0.3076,
# 	Early stopping patience counter: 1/40
# Epoch 316/1000,	Train Loss: 0.5426,	Validation Loss: 0.3097,
# 	Early stopping patience counter: 2/40
# Epoch 317/1000,	Train Loss: 0.5472,	Validation Loss: 0.3102,
# 	Early stopping patience counter: 3/40
# Epoch 318/1000,	Train Loss: 0.5127,	Validation Loss: 0.3102,
# 	Early stopping patience counter: 4/40
# Epoch 319/1000,	Train Loss: 0.5732,	Validation Loss: 0.3105,
# 	Early stopping patience counter: 5/40
# Epoch 320/1000,	Train Loss: 0.5243,	Validation Loss: 0.3103,
# 	Early stopping patience counter: 6/40
# Epoch 321/1000,	Train Loss: 0.5838,	Validation Loss: 0.3102,
# 	Early stopping patience counter: 7/40
# Epoch 322/1000,	Train Loss: 0.5683,	Validation Loss: 0.3096,
# 	Early stopping patience counter: 8/40
# Epoch 323/1000,	Train Loss: 0.5196,	Validation Loss: 0.3093,
# 	Early stopping patience counter: 9/40
# Epoch 324/1000,	Train Loss: 0.5476,	Validation Loss: 0.3103,
# 	Early stopping patience counter: 10/40
# Epoch 325/1000,	Train Loss: 0.5838,	Validation Loss: 0.3118,
# 	Early stopping patience counter: 11/40
# Epoch 326/1000,	Train Loss: 0.5429,	Validation Loss: 0.3124,
# 	Early stopping patience counter: 12/40
# Epoch 327/1000,	Train Loss: 0.5865,	Validation Loss: 0.3127,
# 	Early stopping patience counter: 13/40
# Epoch 328/1000,	Train Loss: 0.5480,	Validation Loss: 0.3123,
# 	Early stopping patience counter: 14/40
# Epoch 329/1000,	Train Loss: 0.5202,	Validation Loss: 0.3118,
# 	Early stopping patience counter: 15/40
# Epoch 330/1000,	Train Loss: 0.5469,	Validation Loss: 0.3117,
# 	Early stopping patience counter: 16/40
# Epoch 331/1000,	Train Loss: 0.5714,	Validation Loss: 0.3116,
# 	Early stopping patience counter: 17/40
# Epoch 332/1000,	Train Loss: 0.5415,	Validation Loss: 0.3116,
# 	Early stopping patience counter: 18/40
# Epoch 333/1000,	Train Loss: 0.5215,	Validation Loss: 0.3108,
# 	Early stopping patience counter: 19/40
# Epoch 334/1000,	Train Loss: 0.5604,	Validation Loss: 0.3106,
# 	Early stopping patience counter: 20/40
# Epoch 335/1000,	Train Loss: 0.5844,	Validation Loss: 0.3106,
# 	Early stopping patience counter: 21/40
# Epoch 336/1000,	Train Loss: 0.5928,	Validation Loss: 0.3108,
# 	Early stopping patience counter: 22/40
# Epoch 337/1000,	Train Loss: 0.5465,	Validation Loss: 0.3110,
# 	Early stopping patience counter: 23/40
# Epoch 338/1000,	Train Loss: 0.5945,	Validation Loss: 0.3110,
# 	Early stopping patience counter: 24/40
# Epoch 339/1000,	Train Loss: 0.5878,	Validation Loss: 0.3121,
# 	Early stopping patience counter: 25/40
# Epoch 340/1000,	Train Loss: 0.5940,	Validation Loss: 0.3127,
# 	Early stopping patience counter: 26/40
# Epoch 341/1000,	Train Loss: 0.5105,	Validation Loss: 0.3129,
# 	Early stopping patience counter: 27/40
# Epoch 342/1000,	Train Loss: 0.5631,	Validation Loss: 0.3130,
# 	Early stopping patience counter: 28/40
# Epoch 343/1000,	Train Loss: 0.5329,	Validation Loss: 0.3140,
# 	Early stopping patience counter: 29/40
# Epoch 344/1000,	Train Loss: 0.5680,	Validation Loss: 0.3150,
# 	Early stopping patience counter: 30/40
# Epoch 345/1000,	Train Loss: 0.4924,	Validation Loss: 0.3149,
# 	Early stopping patience counter: 31/40
# Epoch 346/1000,	Train Loss: 0.5552,	Validation Loss: 0.3146,
# 	Early stopping patience counter: 32/40
# Epoch 347/1000,	Train Loss: 0.5336,	Validation Loss: 0.3142,
# 	Early stopping patience counter: 33/40
# Epoch 348/1000,	Train Loss: 0.5081,	Validation Loss: 0.3134,
# 	Early stopping patience counter: 34/40
# Epoch 349/1000,	Train Loss: 0.5121,	Validation Loss: 0.3125,
# 	Early stopping patience counter: 35/40
# Epoch 350/1000,	Train Loss: 0.6230,	Validation Loss: 0.3132,
# 	Early stopping patience counter: 36/40
# Epoch 351/1000,	Train Loss: 0.5684,	Validation Loss: 0.3139,
# 	Early stopping patience counter: 37/40
# Epoch 352/1000,	Train Loss: 0.5180,	Validation Loss: 0.3150,
# 	Early stopping patience counter: 38/40
# Epoch 353/1000,	Train Loss: 0.5171,	Validation Loss: 0.3157,
# 	Early stopping patience counter: 39/40
# Epoch 354/1000,	Train Loss: 0.5553,	Validation Loss: 0.3174,
# 	Early stopping patience counter: 40/40
# 	Early stopping triggered. Stopping training.
# ===================================
#  M O D E L   L O C A T I O N :
# nn_models\mlp_lasso_2025-05-14-00-03-05.pth
# ===================================
#
#
#
# ===================================
#  persons_in_overlap: 7
# ===================================

# %%
plot_shaps(model_lasso, features_lasso)

# %%
print_stats(model_lasso, val_loader_lasso, params)
# Out:
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [12, 8], 'dropout_prob': 0.5, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.0005, 'patience': 40, 'l2_lambda': 0.07}
# Validation Loss:	0.3057
# Mean vizier:		0.9221
# Mean non-vizier:	0.1941
# bottom_3_vizier:	0.9406
# top_3_non_vizier:	0.7453
# PiO Validation:		6

# %% [raw]
# params = {'typ': 'lasso',
#           'batch_size': 512,
#           'hidden_size': [8, 2],
#           'activation_name': 'relu',
#           'optimizer_name': 'adam',
#           'dropout_prob': X,
#           'epochs': 1500,
#           'learning_rate': 0.005,
#           'patience': 40,
#           'l2_lambda': X
#          }
# +--------+---------+------------+------------+--------------------------------+
# |   l2   | dropout |  model v1  |  model v2  |         NOTE                   |
# | lambda |  prob.  | loss+issue*| loss+issue*|      AND CONCLUSION            |
# +--------+---------+------------+------------+--------------------------------+
# | 0.0000 | 0.0     | 0.0501  3  | 0.0412  3  |                                |
# | 0.0000 | 0.2     | 0.0615  1  | 0.0325  2  |                                |
# | 0.0000 | 0.5     | 0.0562  2  | 0.0407  2  |                                |
# | 0.0000 | 0.5     | 0.0548  0  | 0.0425  1  |  relu -> leaky_relu             |
# | 0.00XX | 0.2     |     |     |                                |
# | 0.00XX | 0.5     |     |     |                                |
# +--------+---------+------------+------------+--------------------------------+
# *issue: number of titles with negative SHAP

# %% [raw]
# params = {'typ': 'lasso',
#           'batch_size': 512,
#           'hidden_size': [8, 4],
#           'activation_name': 'relu',
#           'optimizer_name': 'adam',
#           'dropout_prob': X,
#           'epochs': 1500,
#           'learning_rate': 0.002,
#           'patience': 40,
#           'l2_lambda': X
#          }
# +--------+---------+------------+------------+--------------------------------+
# |   l2   | dropout |  model v1  |  model v2  |         NOTE                   |
# | lambda |  prob.  | loss+issue*| loss+issue*|      AND CONCLUSION            |
# +--------+---------+------------+------------+--------------------------------+
# | 0.0000 | 0.0     |            | 0.0521  1  |                                |
# | 0.0000 | 0.2     |            | 0.0562  1  |                                |
# | 0.0000 | 0.5     |            | 0.0475  1  |                                |
# +--------+---------+------------+------------+--------------------------------+
# *issue: number of titles with negative SHAP

# %% [raw]
# WITH DROPOUT
#
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [4, 2], 'activation_name': 'leaky_relu', 'optimizer_name': 'adam', 'dropout_prob': 0.5, 'epochs': 1500, 'learning_rate': 0.005, 'patience': 40}
# Validation Loss:	0.0597
# Mean vizier:		0.9732
# Mean non-vizier:	0.0168
# bottom_3_vizier:	0.9762
# top_3_non_vizier:	0.8499
# PiO Validation:		0

# %% [raw]
# WITHOUT DROPOUT
# BAD
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1500, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0637
# Mean vizier:		0.9957
# Mean non-vizier:	0.0435
# bottom_3_vizier:	0.9991
# top_3_non_vizier:	0.8853
# PiO Validation:		3
#
# 1 ISSUES
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1500, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0616
# Mean vizier:		0.9959
# Mean non-vizier:	0.0389
# bottom_3_vizier:	0.9976
# top_3_non_vizier:	0.9293
# PiO Validation:		2
#
# 1 ISSUE
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [4, 2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1500, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0594
# Mean vizier:		0.9966
# Mean non-vizier:	0.0349
# bottom_3_vizier:	0.9983
# top_3_non_vizier:	0.9563
# PiO Validation:		2
#
# 1 ISSUE
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [8, 4, 2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1500, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0609
# Mean vizier:		0.9955
# Mean non-vizier:	0.0304
# bottom_3_vizier:	0.9961
# top_3_non_vizier:	0.9598
# PiO Validation:		4

# %% [markdown]
# ### Ridge NN

# %%
params = {'typ': 'ridge',
          'batch_size': 512,
          'hidden_size': [12, 8],
          'dropout_prob': 0.5,
          'activation_name': 'relu',
          'optimizer_name': 'adam',
          'epochs': 1000,
          'learning_rate': 0.0005,
          'patience': 40,
          'l2_lambda': 0.07
         }
model_ridge, val_loader_ridge = train_nn(params)
# Out:
# ===================================
#  S T A R T I N G   M O D E L
# ===================================
#
# Defined BinaryClassifier with criterion=BCEWithLogitsLoss()
# Defined BinaryClassifier with optimizer=Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0.07
# )
#
# ===================================
# MODEL ARCHITECTURE:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=42, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=12, out_features=8, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=8, out_features=1, bias=True)
#   )
# )
# ===================================
#
#
# ===================================
# NUMBER OF PARAMETERS: 629
# ===================================
#
# Epoch 1/1000,	Train Loss: 1.3552,	Validation Loss: 1.3473,
# Epoch 2/1000,	Train Loss: 1.3567,	Validation Loss: 1.3463,
# Epoch 3/1000,	Train Loss: 1.3551,	Validation Loss: 1.3452,
# Epoch 4/1000,	Train Loss: 1.3541,	Validation Loss: 1.3439,
# Epoch 5/1000,	Train Loss: 1.3589,	Validation Loss: 1.3428,
# Epoch 6/1000,	Train Loss: 1.3533,	Validation Loss: 1.3418,
# Epoch 7/1000,	Train Loss: 1.3563,	Validation Loss: 1.3409,
# Epoch 8/1000,	Train Loss: 1.3528,	Validation Loss: 1.3395,
# Epoch 9/1000,	Train Loss: 1.3513,	Validation Loss: 1.3380,
# Epoch 10/1000,	Train Loss: 1.3498,	Validation Loss: 1.3361,
# Epoch 11/1000,	Train Loss: 1.3467,	Validation Loss: 1.3344,
# Epoch 12/1000,	Train Loss: 1.3474,	Validation Loss: 1.3326,
# Epoch 13/1000,	Train Loss: 1.3472,	Validation Loss: 1.3310,
# Epoch 14/1000,	Train Loss: 1.3466,	Validation Loss: 1.3292,
# Epoch 15/1000,	Train Loss: 1.3463,	Validation Loss: 1.3277,
# Epoch 16/1000,	Train Loss: 1.3386,	Validation Loss: 1.3253,
# Epoch 17/1000,	Train Loss: 1.3373,	Validation Loss: 1.3225,
# Epoch 18/1000,	Train Loss: 1.3328,	Validation Loss: 1.3190,
# Epoch 19/1000,	Train Loss: 1.3217,	Validation Loss: 1.3149,
# Epoch 20/1000,	Train Loss: 1.3275,	Validation Loss: 1.3103,
# Epoch 21/1000,	Train Loss: 1.3264,	Validation Loss: 1.3049,
# Epoch 22/1000,	Train Loss: 1.3220,	Validation Loss: 1.3001,
# Epoch 23/1000,	Train Loss: 1.3177,	Validation Loss: 1.2950,
# Epoch 24/1000,	Train Loss: 1.3171,	Validation Loss: 1.2900,
# Epoch 25/1000,	Train Loss: 1.3209,	Validation Loss: 1.2846,
# Epoch 26/1000,	Train Loss: 1.3020,	Validation Loss: 1.2791,
# Epoch 27/1000,	Train Loss: 1.2816,	Validation Loss: 1.2727,
# Epoch 28/1000,	Train Loss: 1.2977,	Validation Loss: 1.2659,
# Epoch 29/1000,	Train Loss: 1.2843,	Validation Loss: 1.2583,
# Epoch 30/1000,	Train Loss: 1.2717,	Validation Loss: 1.2503,
# Epoch 31/1000,	Train Loss: 1.2610,	Validation Loss: 1.2423,
# Epoch 32/1000,	Train Loss: 1.2801,	Validation Loss: 1.2338,
# Epoch 33/1000,	Train Loss: 1.2500,	Validation Loss: 1.2245,
# Epoch 34/1000,	Train Loss: 1.2568,	Validation Loss: 1.2151,
# Epoch 35/1000,	Train Loss: 1.2462,	Validation Loss: 1.2053,
# Epoch 36/1000,	Train Loss: 1.2490,	Validation Loss: 1.1952,
# Epoch 37/1000,	Train Loss: 1.2581,	Validation Loss: 1.1852,
# Epoch 38/1000,	Train Loss: 1.2310,	Validation Loss: 1.1751,
# Epoch 39/1000,	Train Loss: 1.2184,	Validation Loss: 1.1643,
# Epoch 40/1000,	Train Loss: 1.2349,	Validation Loss: 1.1547,
# Epoch 41/1000,	Train Loss: 1.1879,	Validation Loss: 1.1444,
# Epoch 42/1000,	Train Loss: 1.1971,	Validation Loss: 1.1337,
# Epoch 43/1000,	Train Loss: 1.2099,	Validation Loss: 1.1240,
# Epoch 44/1000,	Train Loss: 1.1665,	Validation Loss: 1.1132,
# Epoch 45/1000,	Train Loss: 1.1731,	Validation Loss: 1.1005,
# Epoch 46/1000,	Train Loss: 1.1454,	Validation Loss: 1.0882,
# Epoch 47/1000,	Train Loss: 1.1930,	Validation Loss: 1.0755,
# Epoch 48/1000,	Train Loss: 1.1373,	Validation Loss: 1.0633,
# Epoch 49/1000,	Train Loss: 1.1613,	Validation Loss: 1.0507,
# Epoch 50/1000,	Train Loss: 1.1236,	Validation Loss: 1.0384,
# Epoch 51/1000,	Train Loss: 1.1137,	Validation Loss: 1.0266,
# Epoch 52/1000,	Train Loss: 1.1236,	Validation Loss: 1.0149,
# Epoch 53/1000,	Train Loss: 1.0761,	Validation Loss: 1.0016,
# Epoch 54/1000,	Train Loss: 1.0976,	Validation Loss: 0.9896,
# Epoch 55/1000,	Train Loss: 1.0782,	Validation Loss: 0.9785,
# Epoch 56/1000,	Train Loss: 1.0766,	Validation Loss: 0.9682,
# Epoch 57/1000,	Train Loss: 1.0721,	Validation Loss: 0.9592,
# Epoch 58/1000,	Train Loss: 1.0935,	Validation Loss: 0.9503,
# Epoch 59/1000,	Train Loss: 1.0991,	Validation Loss: 0.9409,
# Epoch 60/1000,	Train Loss: 1.0612,	Validation Loss: 0.9310,
# Epoch 61/1000,	Train Loss: 1.0384,	Validation Loss: 0.9200,
# Epoch 62/1000,	Train Loss: 1.0593,	Validation Loss: 0.9088,
# Epoch 63/1000,	Train Loss: 0.9817,	Validation Loss: 0.8986,
# Epoch 64/1000,	Train Loss: 1.0437,	Validation Loss: 0.8885,
# Epoch 65/1000,	Train Loss: 1.0083,	Validation Loss: 0.8786,
# Epoch 66/1000,	Train Loss: 1.0568,	Validation Loss: 0.8687,
# Epoch 67/1000,	Train Loss: 0.9940,	Validation Loss: 0.8597,
# Epoch 68/1000,	Train Loss: 0.9760,	Validation Loss: 0.8504,
# Epoch 69/1000,	Train Loss: 0.9983,	Validation Loss: 0.8417,
# Epoch 70/1000,	Train Loss: 1.0219,	Validation Loss: 0.8340,
# Epoch 71/1000,	Train Loss: 0.9522,	Validation Loss: 0.8264,
# Epoch 72/1000,	Train Loss: 0.9908,	Validation Loss: 0.8183,
# Epoch 73/1000,	Train Loss: 0.9942,	Validation Loss: 0.8108,
# Epoch 74/1000,	Train Loss: 0.9710,	Validation Loss: 0.8033,
# Epoch 75/1000,	Train Loss: 0.9127,	Validation Loss: 0.7965,
# Epoch 76/1000,	Train Loss: 0.9516,	Validation Loss: 0.7883,
# Epoch 77/1000,	Train Loss: 0.9300,	Validation Loss: 0.7808,
# Epoch 78/1000,	Train Loss: 0.9106,	Validation Loss: 0.7737,
# Epoch 79/1000,	Train Loss: 0.9321,	Validation Loss: 0.7672,
# Epoch 80/1000,	Train Loss: 0.9068,	Validation Loss: 0.7609,
# Epoch 81/1000,	Train Loss: 0.9221,	Validation Loss: 0.7544,
# Epoch 82/1000,	Train Loss: 0.9126,	Validation Loss: 0.7475,
# Epoch 83/1000,	Train Loss: 0.8944,	Validation Loss: 0.7412,
# Epoch 84/1000,	Train Loss: 0.9399,	Validation Loss: 0.7335,
# Epoch 85/1000,	Train Loss: 0.8992,	Validation Loss: 0.7253,
# Epoch 86/1000,	Train Loss: 0.9117,	Validation Loss: 0.7177,
# Epoch 87/1000,	Train Loss: 0.8843,	Validation Loss: 0.7113,
# Epoch 88/1000,	Train Loss: 0.9002,	Validation Loss: 0.7044,
# Epoch 89/1000,	Train Loss: 0.8745,	Validation Loss: 0.6974,
# Epoch 90/1000,	Train Loss: 0.8604,	Validation Loss: 0.6916,
# Epoch 91/1000,	Train Loss: 0.8886,	Validation Loss: 0.6859,
# Epoch 92/1000,	Train Loss: 0.8284,	Validation Loss: 0.6803,
# Epoch 93/1000,	Train Loss: 0.8321,	Validation Loss: 0.6740,
# Epoch 94/1000,	Train Loss: 0.8464,	Validation Loss: 0.6674,
# Epoch 95/1000,	Train Loss: 0.8465,	Validation Loss: 0.6610,
# Epoch 96/1000,	Train Loss: 0.8051,	Validation Loss: 0.6541,
# Epoch 97/1000,	Train Loss: 0.8372,	Validation Loss: 0.6471,
# Epoch 98/1000,	Train Loss: 0.8209,	Validation Loss: 0.6396,
# Epoch 99/1000,	Train Loss: 0.9335,	Validation Loss: 0.6333,
# Epoch 100/1000,	Train Loss: 0.8380,	Validation Loss: 0.6276,
# Epoch 101/1000,	Train Loss: 0.8475,	Validation Loss: 0.6227,
# Epoch 102/1000,	Train Loss: 0.8052,	Validation Loss: 0.6180,
# Epoch 103/1000,	Train Loss: 0.7940,	Validation Loss: 0.6126,
# Epoch 104/1000,	Train Loss: 0.8027,	Validation Loss: 0.6079,
# Epoch 105/1000,	Train Loss: 0.8276,	Validation Loss: 0.6032,
# Epoch 106/1000,	Train Loss: 0.8295,	Validation Loss: 0.5980,
# Epoch 107/1000,	Train Loss: 0.7739,	Validation Loss: 0.5932,
# Epoch 108/1000,	Train Loss: 0.8223,	Validation Loss: 0.5888,
# Epoch 109/1000,	Train Loss: 0.7796,	Validation Loss: 0.5842,
# Epoch 110/1000,	Train Loss: 0.7953,	Validation Loss: 0.5790,
# Epoch 111/1000,	Train Loss: 0.7881,	Validation Loss: 0.5736,
# Epoch 112/1000,	Train Loss: 0.7596,	Validation Loss: 0.5679,
# Epoch 113/1000,	Train Loss: 0.7763,	Validation Loss: 0.5622,
# Epoch 114/1000,	Train Loss: 0.7096,	Validation Loss: 0.5569,
# Epoch 115/1000,	Train Loss: 0.6941,	Validation Loss: 0.5507,
# Epoch 116/1000,	Train Loss: 0.8045,	Validation Loss: 0.5443,
# Epoch 117/1000,	Train Loss: 0.7582,	Validation Loss: 0.5388,
# Epoch 118/1000,	Train Loss: 0.7500,	Validation Loss: 0.5337,
# Epoch 119/1000,	Train Loss: 0.7277,	Validation Loss: 0.5290,
# Epoch 120/1000,	Train Loss: 0.7690,	Validation Loss: 0.5246,
# Epoch 121/1000,	Train Loss: 0.7010,	Validation Loss: 0.5199,
# Epoch 122/1000,	Train Loss: 0.7482,	Validation Loss: 0.5145,
# Epoch 123/1000,	Train Loss: 0.7194,	Validation Loss: 0.5091,
# Epoch 124/1000,	Train Loss: 0.7195,	Validation Loss: 0.5045,
# Epoch 125/1000,	Train Loss: 0.7694,	Validation Loss: 0.5010,
# Epoch 126/1000,	Train Loss: 0.6825,	Validation Loss: 0.4971,
# Epoch 127/1000,	Train Loss: 0.6986,	Validation Loss: 0.4932,
# Epoch 128/1000,	Train Loss: 0.6930,	Validation Loss: 0.4888,
# Epoch 129/1000,	Train Loss: 0.7095,	Validation Loss: 0.4846,
# Epoch 130/1000,	Train Loss: 0.7045,	Validation Loss: 0.4832,
# Epoch 131/1000,	Train Loss: 0.7275,	Validation Loss: 0.4805,
# Epoch 132/1000,	Train Loss: 0.7041,	Validation Loss: 0.4775,
# Epoch 133/1000,	Train Loss: 0.7046,	Validation Loss: 0.4749,
# Epoch 134/1000,	Train Loss: 0.7106,	Validation Loss: 0.4736,
# Epoch 135/1000,	Train Loss: 0.6811,	Validation Loss: 0.4717,
# Epoch 136/1000,	Train Loss: 0.6840,	Validation Loss: 0.4688,
# Epoch 137/1000,	Train Loss: 0.6802,	Validation Loss: 0.4662,
# Epoch 138/1000,	Train Loss: 0.6744,	Validation Loss: 0.4639,
# Epoch 139/1000,	Train Loss: 0.6772,	Validation Loss: 0.4616,
# Epoch 140/1000,	Train Loss: 0.6713,	Validation Loss: 0.4611,
# Epoch 141/1000,	Train Loss: 0.6859,	Validation Loss: 0.4595,
# Epoch 142/1000,	Train Loss: 0.7023,	Validation Loss: 0.4569,
# Epoch 143/1000,	Train Loss: 0.6611,	Validation Loss: 0.4537,
# Epoch 144/1000,	Train Loss: 0.7148,	Validation Loss: 0.4510,
# Epoch 145/1000,	Train Loss: 0.6134,	Validation Loss: 0.4481,
# Epoch 146/1000,	Train Loss: 0.6968,	Validation Loss: 0.4455,
# Epoch 147/1000,	Train Loss: 0.6418,	Validation Loss: 0.4430,
# Epoch 148/1000,	Train Loss: 0.7069,	Validation Loss: 0.4404,
# Epoch 149/1000,	Train Loss: 0.6373,	Validation Loss: 0.4382,
# Epoch 150/1000,	Train Loss: 0.6724,	Validation Loss: 0.4361,
# Epoch 151/1000,	Train Loss: 0.6104,	Validation Loss: 0.4334,
# Epoch 152/1000,	Train Loss: 0.6196,	Validation Loss: 0.4302,
# Epoch 153/1000,	Train Loss: 0.6179,	Validation Loss: 0.4270,
# Epoch 154/1000,	Train Loss: 0.6140,	Validation Loss: 0.4244,
# Epoch 155/1000,	Train Loss: 0.6242,	Validation Loss: 0.4220,
# Epoch 156/1000,	Train Loss: 0.6906,	Validation Loss: 0.4198,
# Epoch 157/1000,	Train Loss: 0.6351,	Validation Loss: 0.4174,
# Epoch 158/1000,	Train Loss: 0.7238,	Validation Loss: 0.4154,
# Epoch 159/1000,	Train Loss: 0.6345,	Validation Loss: 0.4133,
# Epoch 160/1000,	Train Loss: 0.6866,	Validation Loss: 0.4121,
# Epoch 161/1000,	Train Loss: 0.5685,	Validation Loss: 0.4101,
# Epoch 162/1000,	Train Loss: 0.6466,	Validation Loss: 0.4089,
# Epoch 163/1000,	Train Loss: 0.6080,	Validation Loss: 0.4087,
# Epoch 164/1000,	Train Loss: 0.6127,	Validation Loss: 0.4067,
# Epoch 165/1000,	Train Loss: 0.5844,	Validation Loss: 0.4045,
# Epoch 166/1000,	Train Loss: 0.6544,	Validation Loss: 0.4030,
# Epoch 167/1000,	Train Loss: 0.5877,	Validation Loss: 0.4019,
# Epoch 168/1000,	Train Loss: 0.6873,	Validation Loss: 0.4011,
# Epoch 169/1000,	Train Loss: 0.5879,	Validation Loss: 0.3998,
# Epoch 170/1000,	Train Loss: 0.6414,	Validation Loss: 0.3988,
# Epoch 171/1000,	Train Loss: 0.6515,	Validation Loss: 0.3982,
# Epoch 172/1000,	Train Loss: 0.5895,	Validation Loss: 0.3970,
# Epoch 173/1000,	Train Loss: 0.5859,	Validation Loss: 0.3944,
# Epoch 174/1000,	Train Loss: 0.6232,	Validation Loss: 0.3926,
# Epoch 175/1000,	Train Loss: 0.6307,	Validation Loss: 0.3906,
# Epoch 176/1000,	Train Loss: 0.6246,	Validation Loss: 0.3894,
# Epoch 177/1000,	Train Loss: 0.6392,	Validation Loss: 0.3883,
# Epoch 178/1000,	Train Loss: 0.6184,	Validation Loss: 0.3872,
# Epoch 179/1000,	Train Loss: 0.5605,	Validation Loss: 0.3853,
# Epoch 180/1000,	Train Loss: 0.6429,	Validation Loss: 0.3841,
# Epoch 181/1000,	Train Loss: 0.6413,	Validation Loss: 0.3833,
# Epoch 182/1000,	Train Loss: 0.6282,	Validation Loss: 0.3822,
# Epoch 183/1000,	Train Loss: 0.6367,	Validation Loss: 0.3814,
# Epoch 184/1000,	Train Loss: 0.5796,	Validation Loss: 0.3801,
# Epoch 185/1000,	Train Loss: 0.6094,	Validation Loss: 0.3789,
# Epoch 186/1000,	Train Loss: 0.5614,	Validation Loss: 0.3771,
# Epoch 187/1000,	Train Loss: 0.6569,	Validation Loss: 0.3752,
# Epoch 188/1000,	Train Loss: 0.6137,	Validation Loss: 0.3752,
# Epoch 189/1000,	Train Loss: 0.5889,	Validation Loss: 0.3757,
# 	Early stopping patience counter: 1/40
# Epoch 190/1000,	Train Loss: 0.6025,	Validation Loss: 0.3755,
# 	Early stopping patience counter: 2/40
# Epoch 191/1000,	Train Loss: 0.6070,	Validation Loss: 0.3754,
# 	Early stopping patience counter: 3/40
# Epoch 192/1000,	Train Loss: 0.6556,	Validation Loss: 0.3753,
# 	Early stopping patience counter: 4/40
# Epoch 193/1000,	Train Loss: 0.6549,	Validation Loss: 0.3756,
# 	Early stopping patience counter: 5/40
# Epoch 194/1000,	Train Loss: 0.5860,	Validation Loss: 0.3755,
# 	Early stopping patience counter: 6/40
# Epoch 195/1000,	Train Loss: 0.6593,	Validation Loss: 0.3750,
# Epoch 196/1000,	Train Loss: 0.5955,	Validation Loss: 0.3749,
# Epoch 197/1000,	Train Loss: 0.5571,	Validation Loss: 0.3741,
# Epoch 198/1000,	Train Loss: 0.6517,	Validation Loss: 0.3734,
# Epoch 199/1000,	Train Loss: 0.6224,	Validation Loss: 0.3730,
# Epoch 200/1000,	Train Loss: 0.5412,	Validation Loss: 0.3716,
# Epoch 201/1000,	Train Loss: 0.6081,	Validation Loss: 0.3698,
# Epoch 202/1000,	Train Loss: 0.6681,	Validation Loss: 0.3686,
# Epoch 203/1000,	Train Loss: 0.6063,	Validation Loss: 0.3675,
# Epoch 204/1000,	Train Loss: 0.5786,	Validation Loss: 0.3659,
# Epoch 205/1000,	Train Loss: 0.5909,	Validation Loss: 0.3645,
# Epoch 206/1000,	Train Loss: 0.6266,	Validation Loss: 0.3636,
# Epoch 207/1000,	Train Loss: 0.6003,	Validation Loss: 0.3635,
# Epoch 208/1000,	Train Loss: 0.5657,	Validation Loss: 0.3627,
# Epoch 209/1000,	Train Loss: 0.5511,	Validation Loss: 0.3610,
# Epoch 210/1000,	Train Loss: 0.6036,	Validation Loss: 0.3599,
# Epoch 211/1000,	Train Loss: 0.6347,	Validation Loss: 0.3595,
# Epoch 212/1000,	Train Loss: 0.5875,	Validation Loss: 0.3585,
# Epoch 213/1000,	Train Loss: 0.5257,	Validation Loss: 0.3574,
# Epoch 214/1000,	Train Loss: 0.6285,	Validation Loss: 0.3568,
# Epoch 215/1000,	Train Loss: 0.5644,	Validation Loss: 0.3557,
# Epoch 216/1000,	Train Loss: 0.6500,	Validation Loss: 0.3546,
# Epoch 217/1000,	Train Loss: 0.5952,	Validation Loss: 0.3543,
# Epoch 218/1000,	Train Loss: 0.5361,	Validation Loss: 0.3538,
# Epoch 219/1000,	Train Loss: 0.5794,	Validation Loss: 0.3535,
# Epoch 220/1000,	Train Loss: 0.5668,	Validation Loss: 0.3535,
# Epoch 221/1000,	Train Loss: 0.5506,	Validation Loss: 0.3528,
# Epoch 222/1000,	Train Loss: 0.6202,	Validation Loss: 0.3520,
# Epoch 223/1000,	Train Loss: 0.5348,	Validation Loss: 0.3510,
# Epoch 224/1000,	Train Loss: 0.6081,	Validation Loss: 0.3503,
# Epoch 225/1000,	Train Loss: 0.5497,	Validation Loss: 0.3496,
# Epoch 226/1000,	Train Loss: 0.5976,	Validation Loss: 0.3496,
# Epoch 227/1000,	Train Loss: 0.5670,	Validation Loss: 0.3497,
# 	Early stopping patience counter: 1/40
# Epoch 228/1000,	Train Loss: 0.5917,	Validation Loss: 0.3492,
# Epoch 229/1000,	Train Loss: 0.5576,	Validation Loss: 0.3491,
# Epoch 230/1000,	Train Loss: 0.5996,	Validation Loss: 0.3491,
# 	Early stopping patience counter: 1/40
# Epoch 231/1000,	Train Loss: 0.6186,	Validation Loss: 0.3498,
# 	Early stopping patience counter: 2/40
# Epoch 232/1000,	Train Loss: 0.6112,	Validation Loss: 0.3498,
# 	Early stopping patience counter: 3/40
# Epoch 233/1000,	Train Loss: 0.5350,	Validation Loss: 0.3490,
# Epoch 234/1000,	Train Loss: 0.6273,	Validation Loss: 0.3495,
# 	Early stopping patience counter: 1/40
# Epoch 235/1000,	Train Loss: 0.6433,	Validation Loss: 0.3498,
# 	Early stopping patience counter: 2/40
# Epoch 236/1000,	Train Loss: 0.6177,	Validation Loss: 0.3501,
# 	Early stopping patience counter: 3/40
# Epoch 237/1000,	Train Loss: 0.5472,	Validation Loss: 0.3511,
# 	Early stopping patience counter: 4/40
# Epoch 238/1000,	Train Loss: 0.6197,	Validation Loss: 0.3517,
# 	Early stopping patience counter: 5/40
# Epoch 239/1000,	Train Loss: 0.5594,	Validation Loss: 0.3514,
# 	Early stopping patience counter: 6/40
# Epoch 240/1000,	Train Loss: 0.5124,	Validation Loss: 0.3508,
# 	Early stopping patience counter: 7/40
# Epoch 241/1000,	Train Loss: 0.5493,	Validation Loss: 0.3495,
# 	Early stopping patience counter: 8/40
# Epoch 242/1000,	Train Loss: 0.5372,	Validation Loss: 0.3477,
# Epoch 243/1000,	Train Loss: 0.5463,	Validation Loss: 0.3457,
# Epoch 244/1000,	Train Loss: 0.5568,	Validation Loss: 0.3444,
# Epoch 245/1000,	Train Loss: 0.5488,	Validation Loss: 0.3434,
# Epoch 246/1000,	Train Loss: 0.6102,	Validation Loss: 0.3429,
# Epoch 247/1000,	Train Loss: 0.5635,	Validation Loss: 0.3434,
# 	Early stopping patience counter: 1/40
# Epoch 248/1000,	Train Loss: 0.6280,	Validation Loss: 0.3434,
# 	Early stopping patience counter: 2/40
# Epoch 249/1000,	Train Loss: 0.6311,	Validation Loss: 0.3437,
# 	Early stopping patience counter: 3/40
# Epoch 250/1000,	Train Loss: 0.6585,	Validation Loss: 0.3448,
# 	Early stopping patience counter: 4/40
# Epoch 251/1000,	Train Loss: 0.6060,	Validation Loss: 0.3450,
# 	Early stopping patience counter: 5/40
# Epoch 252/1000,	Train Loss: 0.5484,	Validation Loss: 0.3447,
# 	Early stopping patience counter: 6/40
# Epoch 253/1000,	Train Loss: 0.5607,	Validation Loss: 0.3442,
# 	Early stopping patience counter: 7/40
# Epoch 254/1000,	Train Loss: 0.5945,	Validation Loss: 0.3437,
# 	Early stopping patience counter: 8/40
# Epoch 255/1000,	Train Loss: 0.5955,	Validation Loss: 0.3433,
# 	Early stopping patience counter: 9/40
# Epoch 256/1000,	Train Loss: 0.5399,	Validation Loss: 0.3429,
# Epoch 257/1000,	Train Loss: 0.5609,	Validation Loss: 0.3438,
# 	Early stopping patience counter: 1/40
# Epoch 258/1000,	Train Loss: 0.6243,	Validation Loss: 0.3443,
# 	Early stopping patience counter: 2/40
# Epoch 259/1000,	Train Loss: 0.5565,	Validation Loss: 0.3445,
# 	Early stopping patience counter: 3/40
# Epoch 260/1000,	Train Loss: 0.5903,	Validation Loss: 0.3455,
# 	Early stopping patience counter: 4/40
# Epoch 261/1000,	Train Loss: 0.5183,	Validation Loss: 0.3461,
# 	Early stopping patience counter: 5/40
# Epoch 262/1000,	Train Loss: 0.5811,	Validation Loss: 0.3454,
# 	Early stopping patience counter: 6/40
# Epoch 263/1000,	Train Loss: 0.5976,	Validation Loss: 0.3452,
# 	Early stopping patience counter: 7/40
# Epoch 264/1000,	Train Loss: 0.5309,	Validation Loss: 0.3448,
# 	Early stopping patience counter: 8/40
# Epoch 265/1000,	Train Loss: 0.6664,	Validation Loss: 0.3452,
# 	Early stopping patience counter: 9/40
# Epoch 266/1000,	Train Loss: 0.5396,	Validation Loss: 0.3453,
# 	Early stopping patience counter: 10/40
# Epoch 267/1000,	Train Loss: 0.5614,	Validation Loss: 0.3452,
# 	Early stopping patience counter: 11/40
# Epoch 268/1000,	Train Loss: 0.5641,	Validation Loss: 0.3455,
# 	Early stopping patience counter: 12/40
# Epoch 269/1000,	Train Loss: 0.6249,	Validation Loss: 0.3457,
# 	Early stopping patience counter: 13/40
# Epoch 270/1000,	Train Loss: 0.6121,	Validation Loss: 0.3459,
# 	Early stopping patience counter: 14/40
# Epoch 271/1000,	Train Loss: 0.6129,	Validation Loss: 0.3464,
# 	Early stopping patience counter: 15/40
# Epoch 272/1000,	Train Loss: 0.5673,	Validation Loss: 0.3470,
# 	Early stopping patience counter: 16/40
# Epoch 273/1000,	Train Loss: 0.5277,	Validation Loss: 0.3464,
# 	Early stopping patience counter: 17/40
# Epoch 274/1000,	Train Loss: 0.5908,	Validation Loss: 0.3457,
# 	Early stopping patience counter: 18/40
# Epoch 275/1000,	Train Loss: 0.5913,	Validation Loss: 0.3470,
# 	Early stopping patience counter: 19/40
# Epoch 276/1000,	Train Loss: 0.6325,	Validation Loss: 0.3480,
# 	Early stopping patience counter: 20/40
# Epoch 277/1000,	Train Loss: 0.5682,	Validation Loss: 0.3476,
# 	Early stopping patience counter: 21/40
# Epoch 278/1000,	Train Loss: 0.4979,	Validation Loss: 0.3463,
# 	Early stopping patience counter: 22/40
# Epoch 279/1000,	Train Loss: 0.5408,	Validation Loss: 0.3449,
# 	Early stopping patience counter: 23/40
# Epoch 280/1000,	Train Loss: 0.5643,	Validation Loss: 0.3441,
# 	Early stopping patience counter: 24/40
# Epoch 281/1000,	Train Loss: 0.5471,	Validation Loss: 0.3432,
# 	Early stopping patience counter: 25/40
# Epoch 282/1000,	Train Loss: 0.6577,	Validation Loss: 0.3428,
# Epoch 283/1000,	Train Loss: 0.4926,	Validation Loss: 0.3423,
# Epoch 284/1000,	Train Loss: 0.6318,	Validation Loss: 0.3421,
# Epoch 285/1000,	Train Loss: 0.6576,	Validation Loss: 0.3414,
# Epoch 286/1000,	Train Loss: 0.5345,	Validation Loss: 0.3403,
# Epoch 287/1000,	Train Loss: 0.5956,	Validation Loss: 0.3397,
# Epoch 288/1000,	Train Loss: 0.5178,	Validation Loss: 0.3400,
# 	Early stopping patience counter: 1/40
# Epoch 289/1000,	Train Loss: 0.5953,	Validation Loss: 0.3404,
# 	Early stopping patience counter: 2/40
# Epoch 290/1000,	Train Loss: 0.5356,	Validation Loss: 0.3406,
# 	Early stopping patience counter: 3/40
# Epoch 291/1000,	Train Loss: 0.5600,	Validation Loss: 0.3406,
# 	Early stopping patience counter: 4/40
# Epoch 292/1000,	Train Loss: 0.5813,	Validation Loss: 0.3404,
# 	Early stopping patience counter: 5/40
# Epoch 293/1000,	Train Loss: 0.5181,	Validation Loss: 0.3400,
# 	Early stopping patience counter: 6/40
# Epoch 294/1000,	Train Loss: 0.5807,	Validation Loss: 0.3400,
# 	Early stopping patience counter: 7/40
# Epoch 295/1000,	Train Loss: 0.5769,	Validation Loss: 0.3405,
# 	Early stopping patience counter: 8/40
# Epoch 296/1000,	Train Loss: 0.5607,	Validation Loss: 0.3419,
# 	Early stopping patience counter: 9/40
# Epoch 297/1000,	Train Loss: 0.6152,	Validation Loss: 0.3433,
# 	Early stopping patience counter: 10/40
# Epoch 298/1000,	Train Loss: 0.5695,	Validation Loss: 0.3436,
# 	Early stopping patience counter: 11/40
# Epoch 299/1000,	Train Loss: 0.5406,	Validation Loss: 0.3434,
# 	Early stopping patience counter: 12/40
# Epoch 300/1000,	Train Loss: 0.5922,	Validation Loss: 0.3437,
# 	Early stopping patience counter: 13/40
# Epoch 301/1000,	Train Loss: 0.5818,	Validation Loss: 0.3440,
# 	Early stopping patience counter: 14/40
# Epoch 302/1000,	Train Loss: 0.5552,	Validation Loss: 0.3440,
# 	Early stopping patience counter: 15/40
# Epoch 303/1000,	Train Loss: 0.5755,	Validation Loss: 0.3440,
# 	Early stopping patience counter: 16/40
# Epoch 304/1000,	Train Loss: 0.5107,	Validation Loss: 0.3435,
# 	Early stopping patience counter: 17/40
# Epoch 305/1000,	Train Loss: 0.6106,	Validation Loss: 0.3428,
# 	Early stopping patience counter: 18/40
# Epoch 306/1000,	Train Loss: 0.5166,	Validation Loss: 0.3422,
# 	Early stopping patience counter: 19/40
# Epoch 307/1000,	Train Loss: 0.5757,	Validation Loss: 0.3411,
# 	Early stopping patience counter: 20/40
# Epoch 308/1000,	Train Loss: 0.5995,	Validation Loss: 0.3398,
# 	Early stopping patience counter: 21/40
# Epoch 309/1000,	Train Loss: 0.5179,	Validation Loss: 0.3389,
# Epoch 310/1000,	Train Loss: 0.5410,	Validation Loss: 0.3378,
# Epoch 311/1000,	Train Loss: 0.5345,	Validation Loss: 0.3369,
# Epoch 312/1000,	Train Loss: 0.5769,	Validation Loss: 0.3370,
# 	Early stopping patience counter: 1/40
# Epoch 313/1000,	Train Loss: 0.5250,	Validation Loss: 0.3364,
# Epoch 314/1000,	Train Loss: 0.5785,	Validation Loss: 0.3358,
# Epoch 315/1000,	Train Loss: 0.5102,	Validation Loss: 0.3357,
# Epoch 316/1000,	Train Loss: 0.5618,	Validation Loss: 0.3354,
# Epoch 317/1000,	Train Loss: 0.5486,	Validation Loss: 0.3353,
# Epoch 318/1000,	Train Loss: 0.5273,	Validation Loss: 0.3364,
# 	Early stopping patience counter: 1/40
# Epoch 319/1000,	Train Loss: 0.6024,	Validation Loss: 0.3364,
# 	Early stopping patience counter: 2/40
# Epoch 320/1000,	Train Loss: 0.6086,	Validation Loss: 0.3362,
# 	Early stopping patience counter: 3/40
# Epoch 321/1000,	Train Loss: 0.5683,	Validation Loss: 0.3360,
# 	Early stopping patience counter: 4/40
# Epoch 322/1000,	Train Loss: 0.4985,	Validation Loss: 0.3351,
# Epoch 323/1000,	Train Loss: 0.5721,	Validation Loss: 0.3339,
# Epoch 324/1000,	Train Loss: 0.5818,	Validation Loss: 0.3332,
# Epoch 325/1000,	Train Loss: 0.4892,	Validation Loss: 0.3323,
# Epoch 326/1000,	Train Loss: 0.5314,	Validation Loss: 0.3306,
# Epoch 327/1000,	Train Loss: 0.5830,	Validation Loss: 0.3298,
# Epoch 328/1000,	Train Loss: 0.5693,	Validation Loss: 0.3294,
# Epoch 329/1000,	Train Loss: 0.5500,	Validation Loss: 0.3292,
# Epoch 330/1000,	Train Loss: 0.6073,	Validation Loss: 0.3290,
# Epoch 331/1000,	Train Loss: 0.5556,	Validation Loss: 0.3296,
# 	Early stopping patience counter: 1/40
# Epoch 332/1000,	Train Loss: 0.6664,	Validation Loss: 0.3304,
# 	Early stopping patience counter: 2/40
# Epoch 333/1000,	Train Loss: 0.5634,	Validation Loss: 0.3304,
# 	Early stopping patience counter: 3/40
# Epoch 334/1000,	Train Loss: 0.5507,	Validation Loss: 0.3298,
# 	Early stopping patience counter: 4/40
# Epoch 335/1000,	Train Loss: 0.6035,	Validation Loss: 0.3297,
# 	Early stopping patience counter: 5/40
# Epoch 336/1000,	Train Loss: 0.5083,	Validation Loss: 0.3294,
# 	Early stopping patience counter: 6/40
# Epoch 337/1000,	Train Loss: 0.5234,	Validation Loss: 0.3284,
# Epoch 338/1000,	Train Loss: 0.5531,	Validation Loss: 0.3280,
# Epoch 339/1000,	Train Loss: 0.5350,	Validation Loss: 0.3271,
# Epoch 340/1000,	Train Loss: 0.4944,	Validation Loss: 0.3261,
# Epoch 341/1000,	Train Loss: 0.5738,	Validation Loss: 0.3257,
# Epoch 342/1000,	Train Loss: 0.5264,	Validation Loss: 0.3252,
# Epoch 343/1000,	Train Loss: 0.5064,	Validation Loss: 0.3248,
# Epoch 344/1000,	Train Loss: 0.4846,	Validation Loss: 0.3245,
# Epoch 345/1000,	Train Loss: 0.5428,	Validation Loss: 0.3243,
# Epoch 346/1000,	Train Loss: 0.5172,	Validation Loss: 0.3255,
# 	Early stopping patience counter: 1/40
# Epoch 347/1000,	Train Loss: 0.5413,	Validation Loss: 0.3260,
# 	Early stopping patience counter: 2/40
# Epoch 348/1000,	Train Loss: 0.5473,	Validation Loss: 0.3271,
# 	Early stopping patience counter: 3/40
# Epoch 349/1000,	Train Loss: 0.5305,	Validation Loss: 0.3278,
# 	Early stopping patience counter: 4/40
# Epoch 350/1000,	Train Loss: 0.6010,	Validation Loss: 0.3282,
# 	Early stopping patience counter: 5/40
# Epoch 351/1000,	Train Loss: 0.4849,	Validation Loss: 0.3277,
# 	Early stopping patience counter: 6/40
# Epoch 352/1000,	Train Loss: 0.5191,	Validation Loss: 0.3270,
# 	Early stopping patience counter: 7/40
# Epoch 353/1000,	Train Loss: 0.5759,	Validation Loss: 0.3267,
# 	Early stopping patience counter: 8/40
# Epoch 354/1000,	Train Loss: 0.6063,	Validation Loss: 0.3270,
# 	Early stopping patience counter: 9/40
# Epoch 355/1000,	Train Loss: 0.5695,	Validation Loss: 0.3281,
# 	Early stopping patience counter: 10/40
# Epoch 356/1000,	Train Loss: 0.5053,	Validation Loss: 0.3281,
# 	Early stopping patience counter: 11/40
# Epoch 357/1000,	Train Loss: 0.5547,	Validation Loss: 0.3279,
# 	Early stopping patience counter: 12/40
# Epoch 358/1000,	Train Loss: 0.5470,	Validation Loss: 0.3292,
# 	Early stopping patience counter: 13/40
# Epoch 359/1000,	Train Loss: 0.5136,	Validation Loss: 0.3289,
# 	Early stopping patience counter: 14/40
# Epoch 360/1000,	Train Loss: 0.5719,	Validation Loss: 0.3286,
# 	Early stopping patience counter: 15/40
# Epoch 361/1000,	Train Loss: 0.5468,	Validation Loss: 0.3280,
# 	Early stopping patience counter: 16/40
# Epoch 362/1000,	Train Loss: 0.5215,	Validation Loss: 0.3268,
# 	Early stopping patience counter: 17/40
# Epoch 363/1000,	Train Loss: 0.5480,	Validation Loss: 0.3261,
# 	Early stopping patience counter: 18/40
# Epoch 364/1000,	Train Loss: 0.5014,	Validation Loss: 0.3259,
# 	Early stopping patience counter: 19/40
# Epoch 365/1000,	Train Loss: 0.5110,	Validation Loss: 0.3254,
# 	Early stopping patience counter: 20/40
# Epoch 366/1000,	Train Loss: 0.5970,	Validation Loss: 0.3250,
# 	Early stopping patience counter: 21/40
# Epoch 367/1000,	Train Loss: 0.5982,	Validation Loss: 0.3255,
# 	Early stopping patience counter: 22/40
# Epoch 368/1000,	Train Loss: 0.5196,	Validation Loss: 0.3255,
# 	Early stopping patience counter: 23/40
# Epoch 369/1000,	Train Loss: 0.5408,	Validation Loss: 0.3256,
# 	Early stopping patience counter: 24/40
# Epoch 370/1000,	Train Loss: 0.6226,	Validation Loss: 0.3258,
# 	Early stopping patience counter: 25/40
# Epoch 371/1000,	Train Loss: 0.5454,	Validation Loss: 0.3262,
# 	Early stopping patience counter: 26/40
# Epoch 372/1000,	Train Loss: 0.5545,	Validation Loss: 0.3260,
# 	Early stopping patience counter: 27/40
# Epoch 373/1000,	Train Loss: 0.6011,	Validation Loss: 0.3249,
# 	Early stopping patience counter: 28/40
# Epoch 374/1000,	Train Loss: 0.5227,	Validation Loss: 0.3242,
# Epoch 375/1000,	Train Loss: 0.5440,	Validation Loss: 0.3234,
# Epoch 376/1000,	Train Loss: 0.5740,	Validation Loss: 0.3228,
# Epoch 377/1000,	Train Loss: 0.5044,	Validation Loss: 0.3229,
# 	Early stopping patience counter: 1/40
# Epoch 378/1000,	Train Loss: 0.5182,	Validation Loss: 0.3232,
# 	Early stopping patience counter: 2/40
# Epoch 379/1000,	Train Loss: 0.5863,	Validation Loss: 0.3234,
# 	Early stopping patience counter: 3/40
# Epoch 380/1000,	Train Loss: 0.5479,	Validation Loss: 0.3238,
# 	Early stopping patience counter: 4/40
# Epoch 381/1000,	Train Loss: 0.6452,	Validation Loss: 0.3246,
# 	Early stopping patience counter: 5/40
# Epoch 382/1000,	Train Loss: 0.5407,	Validation Loss: 0.3252,
# 	Early stopping patience counter: 6/40
# Epoch 383/1000,	Train Loss: 0.5683,	Validation Loss: 0.3257,
# 	Early stopping patience counter: 7/40
# Epoch 384/1000,	Train Loss: 0.5261,	Validation Loss: 0.3257,
# 	Early stopping patience counter: 8/40
# Epoch 385/1000,	Train Loss: 0.4587,	Validation Loss: 0.3252,
# 	Early stopping patience counter: 9/40
# Epoch 386/1000,	Train Loss: 0.5675,	Validation Loss: 0.3250,
# 	Early stopping patience counter: 10/40
# Epoch 387/1000,	Train Loss: 0.5420,	Validation Loss: 0.3257,
# 	Early stopping patience counter: 11/40
# Epoch 388/1000,	Train Loss: 0.5623,	Validation Loss: 0.3263,
# 	Early stopping patience counter: 12/40
# Epoch 389/1000,	Train Loss: 0.5522,	Validation Loss: 0.3265,
# 	Early stopping patience counter: 13/40
# Epoch 390/1000,	Train Loss: 0.6277,	Validation Loss: 0.3270,
# 	Early stopping patience counter: 14/40
# Epoch 391/1000,	Train Loss: 0.5359,	Validation Loss: 0.3280,
# 	Early stopping patience counter: 15/40
# Epoch 392/1000,	Train Loss: 0.5485,	Validation Loss: 0.3285,
# 	Early stopping patience counter: 16/40
# Epoch 393/1000,	Train Loss: 0.5237,	Validation Loss: 0.3286,
# 	Early stopping patience counter: 17/40
# Epoch 394/1000,	Train Loss: 0.5157,	Validation Loss: 0.3282,
# 	Early stopping patience counter: 18/40
# Epoch 395/1000,	Train Loss: 0.6449,	Validation Loss: 0.3279,
# 	Early stopping patience counter: 19/40
# Epoch 396/1000,	Train Loss: 0.5949,	Validation Loss: 0.3275,
# 	Early stopping patience counter: 20/40
# Epoch 397/1000,	Train Loss: 0.6029,	Validation Loss: 0.3276,
# 	Early stopping patience counter: 21/40
# Epoch 398/1000,	Train Loss: 0.5857,	Validation Loss: 0.3284,
# 	Early stopping patience counter: 22/40
# Epoch 399/1000,	Train Loss: 0.5852,	Validation Loss: 0.3288,
# 	Early stopping patience counter: 23/40
# Epoch 400/1000,	Train Loss: 0.5866,	Validation Loss: 0.3291,
# 	Early stopping patience counter: 24/40
# Epoch 401/1000,	Train Loss: 0.6546,	Validation Loss: 0.3297,
# 	Early stopping patience counter: 25/40
# Epoch 402/1000,	Train Loss: 0.5490,	Validation Loss: 0.3295,
# 	Early stopping patience counter: 26/40
# Epoch 403/1000,	Train Loss: 0.5215,	Validation Loss: 0.3299,
# 	Early stopping patience counter: 27/40
# Epoch 404/1000,	Train Loss: 0.5494,	Validation Loss: 0.3298,
# 	Early stopping patience counter: 28/40
# Epoch 405/1000,	Train Loss: 0.5278,	Validation Loss: 0.3292,
# 	Early stopping patience counter: 29/40
# Epoch 406/1000,	Train Loss: 0.5194,	Validation Loss: 0.3284,
# 	Early stopping patience counter: 30/40
# Epoch 407/1000,	Train Loss: 0.5667,	Validation Loss: 0.3281,
# 	Early stopping patience counter: 31/40
# Epoch 408/1000,	Train Loss: 0.5755,	Validation Loss: 0.3278,
# 	Early stopping patience counter: 32/40
# Epoch 409/1000,	Train Loss: 0.5794,	Validation Loss: 0.3277,
# 	Early stopping patience counter: 33/40
# Epoch 410/1000,	Train Loss: 0.5484,	Validation Loss: 0.3274,
# 	Early stopping patience counter: 34/40
# Epoch 411/1000,	Train Loss: 0.5066,	Validation Loss: 0.3266,
# 	Early stopping patience counter: 35/40
# Epoch 412/1000,	Train Loss: 0.5288,	Validation Loss: 0.3256,
# 	Early stopping patience counter: 36/40
# Epoch 413/1000,	Train Loss: 0.5389,	Validation Loss: 0.3243,
# 	Early stopping patience counter: 37/40
# Epoch 414/1000,	Train Loss: 0.4803,	Validation Loss: 0.3243,
# 	Early stopping patience counter: 38/40
# Epoch 415/1000,	Train Loss: 0.5118,	Validation Loss: 0.3240,
# 	Early stopping patience counter: 39/40
# Epoch 416/1000,	Train Loss: 0.5431,	Validation Loss: 0.3237,
# 	Early stopping patience counter: 40/40
# 	Early stopping triggered. Stopping training.
# ===================================
#  M O D E L   L O C A T I O N :
# nn_models\mlp_ridge_2025-05-14-00-04-03.pth
# ===================================
#
#
#
# ===================================
#  persons_in_overlap: 9
# ===================================

# %%
plot_shaps(model_ridge, features_ridge)

# %%
print_stats(model_ridge, val_loader_ridge, params)
# Out:
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [12, 8], 'dropout_prob': 0.5, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.0005, 'patience': 40, 'l2_lambda': 0.07}
# Validation Loss:	0.3228
# Mean vizier:		0.9283
# Mean non-vizier:	0.2102
# bottom_3_vizier:	0.9598
# top_3_non_vizier:	0.8447
# PiO Validation:		9

# %% [raw]
# params = {'typ': 'ridge',
#           'batch_size': 512,
#           'hidden_size': [12, 8],
#           'dropout_prob': X,
#           'activation_name': 'relu',
#           'optimizer_name': 'adam',
#           'epochs': 1000,
#           'learning_rate': 0.001,
#           'patience': 40,
#           'l2_lambda': X
#          }
# +--------+---------+------------+------------+--------------------------------+
# |   l2   | dropout |  model v1  |  model v2  |         NOTE                   |
# | lambda |  prob.  | loss+issue*| loss+issue*|      AND CONCLUSION            |
# +--------+---------+------------+------------+--------------------------------+
# | 0.000  | 0.0     | 0.0306  6  | 0.0689  2  | high issues (overfitted)       |
# | 0.000  | 0.2     | 0.0253  3  | 0.0499  3  | high issues (overfitted)       |
# | 0.000  | 0.5     | 0.0329  2  | 0.0434  3  | high issues (overfitted)       |
# | 0.001  | 0.0     | 0.0282  3  | 0.0794  3  | high issues (overfitted)       |
# | 0.001  | 0.2     | 0.0377  3  | 0.0569  2  | high issues (overfitted)       |
# | 0.001  | 0.5     | 0.0308  2  | 0.0569  2  | high issues (overfitted)       |
# | 0.010  | 0.0     | 0.0395  2  | 0.0720  2  | high issues (overfitted)       |
# | 0.010  | 0.2     | 0.0416  1  | 0.0529  2  | high issues (overfitted)       |
# | 0.010  | 0.5     | 0.0530  1  | 0.0503  2  | high issues (overfitted)       |
# | 0.050  | 0.0     | 0.0942  0  | 0.1059  1  | low issues & BUT high loss     |
# | 0.050  | 0.2     | 0.0997  0  | 0.0994  1  | low issues & BUT high loss     |
# | 0.050  | 0.5     | 0.1063  0  | 0.1322  0  | perfect & BUT high loss        |
# | 0.002  | 0.0     | 0.0559  2  | 0.0852  2  | high issues                    |
# | 0.002  | 0.2     | 0.0589  1  | 0.0663  2  | high issues                    |
# | 0.0022 | 0.5     | 0.0594  1  | 0.0781  2  | high issues                    |
# | 0.0022 | 0.0     | 0.0591  1  | 0.0661  2  | high issues                    |
# | 0.0022 | 0.2     | 0.0643  1  | 0.0712  2  | high issues                    |
# | 0.0024 | 0.0     |            |            | high issues                    |
# | 0.0024 | 0.2     | 0.0697  1  | 0.0975  1  | high issues                    |
# | 0.0024 | 0.5     |            |            | high issues                    |
# | 0.0025 | 0.5     |            |            | high issues                    |
# | 0.0026 | 0.5     |            |            | high issues                    |
# | 0.0027 | 0.5     |            |            | high issues                    |
# | 0.0030 | 0.0     | 0.0655  1  | 0.0871  2  | high issues                    |
# | 0.0030 | 0.2     | 0.0735  1  | 0.0805  1  |                                |
# | 0.0030 | 0.3     | 0.0738  0  | 0.0746  2  |                                |
# | 0.0030 | 0.3     | 0.0650  1  | 0.0826  2  | relu -> leky_relu              |
# | 0.0030 | 0.5     |            |            | high issues                    |
# | 0.0035 | 0.0     | 0.0730  1  | 0.0955  2  |                                |
# | 0.0035 | 0.2     | 0.0720  1  | 0.0793  2  |                                |
# | 0.0035 | 0.3     | 0.0810  0  |         1  |                                |
# | 0.0035 | 0.4     |         0  |         1  |                                |
# | 0.0040 | 0.3     | 0.0850  0  | 0.0966  0  |                                |
# | 0.0043 | 0.3     | 0.0850  0  | 0.0966  0  |                                |
# |        |         |            |            |                                |
# | 0.00XX | 0.0     |            |            |                                |
# | 0.00XX | 0.2     |            |            |                                |
# | 0.00XX | 0.5     |            |            |                                |
# +--------+---------+------------+------------+--------------------------------+
# *issue: number of titles with negative SHAP

# %% [raw]
# DROPOUT = 0.5
# +-----------+--------+---------+------------+------------+--------------------------------+
# |  hidden   |   l2   | dropout |  model v1  |  model v2  |         NOTE                   |
# |   size    | lambda |  prob.  | loss+issue*| loss+issue*|      AND CONCLUSION            |
# +-----------+--------+---------+------------+------------+--------------------------------+
# | [2]       | 0.0000 | 0.5     |            |            |  Too high loss                 |
# | [4]       | 0.0000 | 0.5     |            |            |  Too high loss                 |
# | [8]       | 0.0000 | 0.5     | 0.0363  3  | 0.0599  3  |                                |
# | [16]      | 0.0000 | 0.5     | 0.0423  1  | 0.0558  3  |                                |
# | [4,2]     | 0.0000 | 0.5     |            |            |  Too high loss                 |
# | [8,4]     | 0.0000 | 0.5     | 0.0666  2  | 0.0537  3  |                                |
# | [16,8]    | 0.0000 | 0.5     | 0.0406  2  | 0.0365  3  |                                |
# | [8,4,2]   | 0.0000 | 0.5     |            |            |  Too high loss                 |
# | [16,8,4]  | 0.0000 | 0.5     | 0.0458  4  | 0.0694  2  |                                |
# | [16,4]    | 0.0000 | 0.5     | 0.0381  2  | 0.0659  4  |                                |
# |           | 0.0000 | 0.5     |     |     |                                |
# +-----------+--------+---------+------------+------------+--------------------------------+
# *issue: number of titles with negative SHAP

# %% [raw]
# DROPOUT = 0.2
# +-----------+--------+---------+------------+------------+--------------------------------+
# |  hidden   |   l2   | dropout |  model v1  |  model v2  |         NOTE                   |
# |   size    | lambda |  prob.  | loss+issue*| loss+issue*|      AND CONCLUSION            |
# +-----------+--------+---------+------------+------------+--------------------------------+
# | [2]       | 0.0000 | 0.2     | 0.0449  3  | 0.1061  4  |                                |
# | [4]       | 0.0000 | 0.2     | 0.0397  4  | 0.0845  3  |                                |
# | [8]       | 0.0000 | 0.2     | 0.0344  3  | 0.0593  2  |                                |
# | [16]      | 0.0000 | 0.2     | 0.0332  4  | 0.0693  3  |                                |
# | [4,2]     | 0.0000 | 0.2     |            |            |  Too high loss                 |
# | [8,4]     | 0.0000 | 0.2     | 0.0259  3  | 0.0509  2  |                                |
# | [16,8]    | 0.0000 | 0.2     | 0.0391  1  | 0.0500  3  |                                |
# | [8,4,2]   | 0.0000 | 0.2     | 0.0465  3  | 0.0660  3  |                                |
# | [16,8,4]  | 0.0000 | 0.2     | 0.0339  3  | 0.0481  3  |                                |
# | [16,4]    | 0.0000 | 0.2     | 0.0333  3  | 0.0364  3  |                                |
# |           | 0.0000 | 0.2     |     |     |                                |
# +-----------+--------+---------+------------+------------+--------------------------------+
# *issue: number of titles with negative SHAP

# %% [raw]
# NO DROUPOUT
# +-----------+--------+---------+------------+------------+--------------------------------+
# |  hidden   |   l2   | dropout |  model v1  |  model v2  |         NOTE                   |
# |   size    | lambda |  prob.  | loss+issue*| loss+issue*|      AND CONCLUSION            |
# +-----------+--------+---------+------------+------------+--------------------------------+
# | []        | 0.0000 | 0.0     | 0.0521  2  | 0.0809  2  |                                |
# | [2]       | 0.0000 | 0.0     | 0.0336  4  | 0.0809  4  |                                |
# | [4]       | 0.0000 | 0.0     | 0.0358  4  | 0.0538  3  |                                |
# | [8]       | 0.0000 | 0.0     | 0.0438  7  | 0.0640  3  |                                |
# | [16]      | 0.0000 | 0.0     | 0.0338  4  | 0.0757  2  |                                |
# | [4,2]     | 0.0000 | 0.0     | 0.0340  3  | 0.0763  3  |                                |
# | [8,4]     | 0.0000 | 0.0     | 0.0271  4  | 0.0603  4  |                                |
# | [16,8]    | 0.0000 | 0.0     | 0.0378  4  | 0.0521  4  |                                |
# | [8,4,2]   | 0.0000 | 0.0     | 0.0342  4  | 0.0657  4  |                                |
# | [16,8,4]  | 0.0000 | 0.0     | 0.0426  4  | 0.0591  4  |                                |
# | [16,4]    | 0.0000 | 0.2     | 0.0366  4  | 0.0590  3  |                                |
# |           | 0.0000 | 0.0     |     |     |                                |
# +-----------+--------+---------+------------+------------+--------------------------------+
# *issue: number of titles with negative SHAP

# %% [markdown]
# ### Models summary

# %%
# print final_model_list
final_model_dict
# Out:
# {'step': 'nn_models\\mlp_step_2025-05-14-00-02-23.pth',
#  'lasso': 'nn_models\\mlp_lasso_2025-05-14-00-03-05.pth',
#  'ridge': 'nn_models\\mlp_ridge_2025-05-14-00-04-03.pth'}

# %% [raw]
# {'step': 'nn_models\\mlp_step_2025-04-27-01-59-05.pth',
#  'lasso': 'nn_models\\mlp_lasso_2025-04-27-01-49-50.pth',
#  'ridge': 'nn_models\\mlp_ridge_2025-04-27-01-55-06.pth'}

# %% [raw]
# {'step': 'nn_models\\mlp_step_2025-04-27-01-59-05.pth',
#  'lasso': 'nn_models\\mlp_lasso_2025-04-27-01-49-50.pth',
#  'ridge': 'nn_models\\mlp_ridge_2025-04-27-01-55-06.pth'}
