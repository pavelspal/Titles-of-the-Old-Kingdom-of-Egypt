# %% [markdown]
# # NN network for corresponding

# %% [markdown]
# **Motivation:** This scripts aims to model a neural network model with same input parameters as logistic regression model (step, Lasso, ridge)
# The architecture is chose as

# %%
final_model_dict = {}

# %% [markdown]
# ### Load

# %%
import os
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

## NN
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from torch.optim.lr_scheduler import StepLR
import shap

# local
import set_path
import supp.support_load as sl
import supp.support_get_mapping as gm
from supp.support_analyze_model import GraphPlotter, plot_cdf, plot_roc, reliability_plot
from supp.support_save import save_df
from supp.support_model_nn import BinaryClassifier, save_nn_info
from supp.support_model_glm import get_model_coef_df, get_model_coef_dict
from supp.support_model_stats import find_viziers_above_overlap, find_non_viziers_in_overlap, find_viziers_in_overlap, find_persons_in_overlap

# %% [markdown]
# #### Load train, validation adn test set

# %%
# Load train, validation and test set
data_train = sl.read_csv('df_vizier_train_v1_2')
data_val = sl.read_csv('df_vizier_val_v1_2')
# set 'ID_person' as index
data_train.set_index('ID_person', inplace=True)
data_val.set_index('ID_person', inplace=True)

# Set response
response = 'vizier'
features_all = [col for col in data_train.columns if col != response]

# conver X to numpy
X_train0 = data_train[features_all].to_numpy()
X_val0 = data_val[features_all].to_numpy()
# conver y to numpy
y_train0 = data_train[response].to_numpy()
y_val0 = data_val[response].to_numpy()
# Out:
# CSV file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\df_vizier_train_v1_2.csv
# CSV file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\df_vizier_val_v1_2.csv

# %%
# Check loaded data shape
print(data_train.shape)
print(data_val.shape)
# Out:
# (2684, 44)
# (575, 44)

# %%
# Check features data shape
print(X_train0.shape)
print(X_val0.shape)
# Out:
# (2684, 43)
# (575, 43)

# %%
# Check response data shape
print(y_train0.shape)
print(y_val0.shape)
# Out:
# (2684,)
# (575,)

# %%
# Check count of viziers
print(y_train0.sum())
print(y_val0.sum())
# Out:
# 52
# 11

# %% [markdown]
# #### Get feature names from GLM models

# %%
# Get dataframe with all GLM coefficients
df_coef = get_model_coef_df()
df_coef
# Out:
# Excel file loaded.
# C:\Users\Stoja\OneDrive\Documents\diplomka\scr\data\summary_model_coefficients_v0.xlsx
# Variable   wr 5 (m) pr 9Hwty  zA ncwt n Xt.f cmcw  \
# step_glm             6.57170              5.83860
# lasso_glm            4.16820              3.67380
# ridge_glm            1.86355              1.63345
#
# Variable   imy-rA zS(w) a(w) (nw) ncwt  Xry-Hbt Hry-tp  imy-rA prwy-HD  \
# step_glm                       4.81280         4.19800         2.19740
# lasso_glm                      3.94330         2.07230         1.04850
# ridge_glm                      1.51053         0.86749         0.78677
#
# Variable   imy-rA kAt nbt (nt) ncwt  (Intercept)  zA ncwt n Xt.f  \
# step_glm                    2.17000     -6.11960             NaN
# lasso_glm                   1.61690     -5.78900         1.83910
# ridge_glm                   0.96656     -5.05323         1.13575
#
# Variable   xrp SnDt nbt  imy-rA izwy (n) Xkr(w) ncwt  ...  Xry-tp ncwt  \
# step_glm            NaN                          NaN  ...          NaN
# lasso_glm       1.05610                      0.86580  ...          NaN
# ridge_glm       0.72049                      0.62719  ...      0.23861
#
# Variable   imAxw xr Wcir   imy iz  aD-mr (n) zAb  Xry-Hbt  Htc(?) Inpw  \
# step_glm             NaN      NaN            NaN      NaN          NaN
# lasso_glm            NaN      NaN            NaN      NaN          NaN
# ridge_glm        0.23625  0.22832        0.21806  0.19908      0.12711
#
# Variable   Hry-cStA  [imAxw xr] nTr aA  Hry-tp Nxb   imAxw
# step_glm        NaN                NaN         NaN     NaN
# lasso_glm       NaN                NaN         NaN     NaN
# ridge_glm   0.10895            0.08321      0.0505  0.0207
#
# [3 rows x 37 columns]

# %%
# Get feature names for each GLM model
coef_step = get_model_coef_dict('step_glm', df=df_coef)
coef_lasso = get_model_coef_dict('lasso_glm', df=df_coef)
coef_ridge = get_model_coef_dict('ridge_glm', df=df_coef)

# %%
# Define set of features for each model
omit_features = ['(Intercept)']
features_step = [key for key in coef_step.keys() if key not in omit_features]
features_lasso = [key for key in coef_lasso.keys() if key not in omit_features]
features_ridge = [key for key in coef_ridge.keys() if key not in omit_features]

# %%
# Check features len
print(len(features_all))
print(len(features_step))
print(len(features_lasso))
print(len(features_ridge))
# Out:
# 43
# 6
# 16
# 36

# %%
print(list(coef_step.keys()))
print(list(coef_lasso.keys()))
print(list(coef_ridge.keys()))
# Out:
# ['wr 5 (m) pr 9Hwty', 'zA ncwt n Xt.f cmcw', 'imy-rA zS(w) a(w) (nw) ncwt', 'Xry-Hbt Hry-tp', 'imy-rA prwy-HD', 'imy-rA kAt nbt (nt) ncwt', '(Intercept)']
# ['wr 5 (m) pr 9Hwty', 'zA ncwt n Xt.f cmcw', 'imy-rA zS(w) a(w) (nw) ncwt', 'Xry-Hbt Hry-tp', 'imy-rA prwy-HD', 'imy-rA kAt nbt (nt) ncwt', '(Intercept)', 'zA ncwt n Xt.f', 'xrp SnDt nbt', 'imy-rA izwy (n) Xkr(w) ncwt', 'xtm(ty)-bity', 'cmr waty', 'iwn knmwt', 'imy-rA 5maw', 'imy-rA Snwty', 'aA 8wAw', 'Hry-cStA n wD(t)-mdw nbt nt ncwt']
# ['wr 5 (m) pr 9Hwty', 'zA ncwt n Xt.f cmcw', 'imy-rA zS(w) a(w) (nw) ncwt', 'Xry-Hbt Hry-tp', 'imy-rA prwy-HD', 'imy-rA kAt nbt (nt) ncwt', '(Intercept)', 'zA ncwt n Xt.f', 'xrp SnDt nbt', 'imy-rA izwy (n) Xkr(w) ncwt', 'xtm(ty)-bity', 'cmr waty', 'iwn knmwt', 'imy-rA 5maw', 'imy-rA Snwty', 'aA 8wAw', 'Hry-cStA n wD(t)-mdw nbt nt ncwt', 'imy-rA gc-pr', 'imy iz Nxn', 'zA ncwt', 'zS mDAt-nTr', 'xrp iAwt nbwt nTrwt', 'imy-rA prwy-nbw', 'imA-a', 'xrp aH', 'r P nb', 'Hry-cStA n pr-dwAt', 'Xry-tp ncwt', 'imAxw xr Wcir', 'imy iz', 'aD-mr (n) zAb', 'Xry-Hbt', 'Htc(?) Inpw', 'Hry-cStA', '[imAxw xr] nTr aA', 'Hry-tp Nxb', 'imAxw']

# %%
# this title was removed in GLM because of high VIF
set(features_all) - set(features_ridge)
# Out:
# {'HAty-a',
#  'cm / ctm',
#  'cmcw cnwt',
#  'imy-rA wabty',
#  'iry-pat',
#  'mdw rxyt',
#  'mniw Nxn / zAw Nxn'}

# %% [markdown]
# ### Train function

# %%
# define hidden_size
# (can be overwriten later)
hidden_size = [2]

# %%
# Define the weight of positive examples
sum_vizier = y_train0.sum() 
sum_non_vizier = y_train0.shape[0] - sum_vizier
pos_weight = sum_non_vizier / sum_vizier
#pos_weight = 1
pos_weight = torch.tensor([pos_weight], dtype=torch.float32)
# Set criterion
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight)  # Using BCEWithLogitsLoss

pos_weight
# Out:
# tensor([50.6154])

# %%
def train_nn(params):
    """
    This funtion serves as main method for training NN model
        - defines model
        - defines optimizer
        - carry the training process
        - choose the best model via early stopping
        - calc train and vall loss
        - plot evolution of loss
        - saves final model
        
    Parameters:
        params (dict): hyperparameters of the NN model
    """
    print(f'===================================')
    print(f' S T A R T I N G   M O D E L')
    print(f'===================================\n')
    current_time = datetime.now().strftime('%Y-%m-%d-%H-%M-%S')
    
    # Set params
    typ = params['typ']
    batch_size = params['batch_size']
    hidden_size = params['hidden_size']
    activation_name = params['activation_name']
    dropout_prob = params['dropout_prob']
    optimizer_name = params['optimizer_name']
    epochs = params['epochs']
    learning_rate = params['learning_rate']
    patience = params['patience']
    weight_decay_value = params['l2_lambda']

    # Set features space
    features = {'step': features_step,
                'lasso': features_lasso,
                'ridge': features_ridge
               }[typ]
    X_train = data_train[features].to_numpy()
    X_val = data_val[features].to_numpy()
    
    # Converting data to PyTorch tensors
    X_train = torch.tensor(X_train, dtype=torch.float32)
    X_val = torch.tensor(X_val, dtype=torch.float32)
    y_train = torch.tensor(y_train0, dtype=torch.float32).unsqueeze(1)
    y_val = torch.tensor(y_val0, dtype=torch.float32).unsqueeze(1)
    
    # Prepare datasets
    train_dataset = TensorDataset(X_train, y_train)
    val_dataset = TensorDataset(X_val, y_val)
    
    # Create DataLoaders
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    # Initialize the model
    input_size = X_train.shape[1]
    # Define model, loss function and optimizer
    model = BinaryClassifier(input_size, hidden_size, activation_name, dropout_prob=dropout_prob)
    
    if optimizer_name == "adam":
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay_value)
    elif optimizer_name == "sgd":
        optimizer = optim.SGD(model.parameters(), lr=learning_rate)
    elif optimizer_name == "rmsprop":
        optimizer = optim.RMSprop(model.parameters(), lr=learning_rate)
    elif optimizer_name == "nadam":
        optimizer = optim.NAdam(model.parameters(), lr=learning_rate)
    else:
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    #scheduler = StepLR(optimizer, step_size=100, gamma=0.5)
    print(f'Defined BinaryClassifier with {criterion=}')
    print(f'Defined BinaryClassifier with {optimizer=}')

    # Print model architecture
    print(f'\n===================================')
    print(f'MODEL ARCHITECTURE:\n{model}')
    print(f'===================================\n')

    # Print total number of parameters
    total_params = sum(p.numel() for p in model.parameters())
    print(f'\n===================================')
    print(f'NUMBER OF PARAMETERS: {total_params}')
    print(f'===================================\n')
    
    # Declare losses
    train_losses = []
    val_losses = []
    pio_list = []     # persons in overlap
    # Early stopping parameters
    best_val_loss = float('inf')
    patience_counter = 0

    # Flag for learning rate reduce
    lr_reduced_1 = False 
    lr_reduced_2 = False 
    # Train the model
    for epoch in range(epochs):

        # Training step
        model.train()
        train_loss = 0.0
        for batch_X, batch_y in train_loader:
            optimizer.zero_grad()
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * batch_X.size(0)
        # Compute average train loss
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        # Validation step
        model.eval()
        val_loss = 0.0
        y_true = []
        y_hat = []
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                outputs = model(batch_X)
                loss = criterion(outputs, batch_y)
                val_loss += loss.item() * batch_X.size(0)
                # Get y_true and y_hat batch
                y_true.extend([el.item() for el in batch_y])
                probabilities = torch.sigmoid(outputs)
                y_hat.extend([el.item() for el in probabilities])
        # Compute average validation loss
        val_loss /= len(val_loader.dataset)
        val_losses.append(val_loss)
        # Compute persons in overlap
        col = 'probs'
        df_probs= pd.DataFrame({'vizier': y_true, col: y_hat})
        pio = find_persons_in_overlap(df_probs, col)
        pio_list.append(pio)
    
        # Print current epoch performance
        print(
            f"Epoch {epoch+1}/{epochs},\t"
            f"Train Loss: {train_loss:.4f},\t"
            f"Validation Loss: {val_loss:.4f},\t"
            #f"LR: {scheduler.get_last_lr()[0]:.6f}"
        )
    
        # Early stopping check
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            # Save the best model
            torch.save(model.state_dict(), rf'nn_models\best_mlp_{typ}_v1.pth')
        else:
            patience_counter += 1
            print(f"\tEarly stopping patience counter: {patience_counter}/{patience}")
            if patience_counter >= patience:
                print("\tEarly stopping triggered. Stopping training.")
                break
        
        # Update learing rate
        if val_loss < 0.1 and not lr_reduced_1:
            for param_group in optimizer.param_groups:
                param_group['lr'] = param_group['lr'] / 10
            print(f"Learning rate reduced to: {param_group['lr']}")
            lr_reduced_1 = True
        # if val_loss < 0.061 and not lr_reduced_2:
        #     for param_group in optimizer.param_groups:
        #         param_group['lr'] = param_group['lr'] / 10
        #     print(f"Learning rate reduced to: {param_group['lr']}")
        #     lr_reduced_2 = True

        # Update learing rate
        #scheduler.step()
    
    # Load the best model after early stopping
    model.load_state_dict(torch.load(rf'nn_models\best_mlp_{typ}_v1.pth'))
    
    # Plot training and validation loss
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(train_losses)+1), train_losses, label='Train Loss')
    plt.plot(range(1, len(val_losses)+1), val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid()
    plt.show()
    # Plot evolutio of persons in overlap
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(val_losses)+1), pio_list, label='Persons in overlap')
    plt.xlabel('Epochs')
    plt.ylabel('Persons in overlap')
    plt.title('Evolution of Persons in Overlap')
    plt.legend()
    plt.grid()
    plt.show()
    
    # Save the model
    path_save = rf'nn_models\mlp_{typ}_{current_time}.pth'
    torch.save(model.state_dict(), path_save)
    save_nn_info(input_size, hidden_size, activation_name, features, path_save)


    # print model lacation
    print(f'\n\n===================================')
    print(f' M O D E L   L O C A T I O N :')
    print(f'{path_save}')
    print(f'===================================\n')
    final_model_dict[typ] = path_save

    # print model lacation
    print(f'\n\n===================================')
    print(f' persons_in_overlap: {pio_list[-1]}')
    print(f'===================================\n')

    model.eval()
    return model, val_loader

# %%
def plot_shaps(model, features_set, output_path=None):
    # Prepare data
    X_df = data_train[features_set]
    X_df = X_df.sample(frac=1, random_state=42).reset_index(drop=True)
    X_explain = torch.tensor(X_df.values, dtype=torch.float32)
    X_sample = X_explain[:150]
    
    # Choose Explainer
    model.eval()
    explainer = shap.GradientExplainer(model, X_sample)
    # Calculate SHAP values
    shap_values_step = explainer.shap_values(X_explain)
    # Remove the last dimension
    shap_values_step = shap_values_step.squeeze(-1)
    
    # Plot and save SHAP 
    plt.figure()
    shap.summary_plot(shap_values_step, X_explain.numpy(), feature_names=features_set, show=False)
    plt.tight_layout()
    if output_path is not None:
        plt.savefig(f'{output_path}.png', dpi=300, bbox_inches='tight')
        plt.savefig(f'{output_path}.pdf', bbox_inches='tight')
    plt.show()

# %%
def print_stats(model, val_loader, params):
    # Validation step
    model.eval()
    val_loss = 0.0
    y_true = []
    y_hat = []
    with torch.no_grad():
        for batch_X, batch_y in val_loader:
            outputs = model(batch_X)
            loss = criterion(outputs, batch_y)
            val_loss += loss.item() * batch_X.size(0)
            # Get y_true and y_hat batch
            y_true.extend([el.item() for el in batch_y])
            probabilities = torch.sigmoid(outputs)
            y_hat.extend([el.item() for el in probabilities])
    # Compute average validation loss
    val_loss /= len(val_loader.dataset)
    # Compute persons in overlap
    col = 'probs'
    df_probs= pd.DataFrame({'vizier': y_true, col: y_hat})
    pio_val = find_persons_in_overlap(df_probs, col)
    mean_vizier = df_probs.loc[df_probs['vizier']==1, col].mean()
    mean_non_vizier = df_probs.loc[df_probs['vizier']==0, col].mean()
    bottom_3_vizier = df_probs.loc[df_probs['vizier']==1, col].sort_values().to_list()[3]
    top_3_non_vizier = df_probs.loc[df_probs['vizier']==0, col].sort_values().to_list()[-3]
    
    print(params)
    print(f"Validation Loss:\t{val_loss:.4f}")
    print(f"Mean vizier:\t\t{mean_vizier:.4f}")
    print(f"Mean non-vizier:\t{mean_non_vizier:.4f}")
    print(f"bottom_3_vizier:\t{bottom_3_vizier:.4f}")
    print(f"top_3_non_vizier:\t{top_3_non_vizier:.4f}")
    print(f"PiO Validation:\t\t{pio_val}")

# %% [markdown]
# ### Step NN

# %%
params = {'typ': 'step',
          'batch_size': 512,
          'hidden_size': [4,2],
          'dropout_prob': 0.2,
          'activation_name': 'relu',
          'optimizer_name': 'adam',
          'epochs': 1000,
          'learning_rate': 0.002,
          'patience': 40,
          'l2_lambda': 0
         }
model_step, val_loader_step = train_nn(params)
# Out:
# ===================================
#  S T A R T I N G   M O D E L
# ===================================
#
# Defined BinaryClassifier with criterion=BCEWithLogitsLoss()
# Defined BinaryClassifier with optimizer=Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.002
#     maximize: False
#     weight_decay: 0
# )
#
# ===================================
# MODEL ARCHITECTURE:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=6, out_features=4, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=4, out_features=2, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=2, out_features=1, bias=True)
#   )
# )
# ===================================
#
#
# ===================================
# NUMBER OF PARAMETERS: 41
# ===================================
#
# Epoch 1/1000,	Train Loss: 1.3600,	Validation Loss: 1.3453,
# Epoch 2/1000,	Train Loss: 1.3562,	Validation Loss: 1.3432,
# Epoch 3/1000,	Train Loss: 1.3538,	Validation Loss: 1.3411,
# Epoch 4/1000,	Train Loss: 1.3547,	Validation Loss: 1.3389,
# Epoch 5/1000,	Train Loss: 1.3511,	Validation Loss: 1.3363,
# Epoch 6/1000,	Train Loss: 1.3461,	Validation Loss: 1.3332,
# Epoch 7/1000,	Train Loss: 1.3462,	Validation Loss: 1.3297,
# Epoch 8/1000,	Train Loss: 1.3419,	Validation Loss: 1.3255,
# Epoch 9/1000,	Train Loss: 1.3427,	Validation Loss: 1.3209,
# Epoch 10/1000,	Train Loss: 1.3367,	Validation Loss: 1.3157,
# Epoch 11/1000,	Train Loss: 1.3287,	Validation Loss: 1.3094,
# Epoch 12/1000,	Train Loss: 1.3235,	Validation Loss: 1.3017,
# Epoch 13/1000,	Train Loss: 1.3143,	Validation Loss: 1.2924,
# Epoch 14/1000,	Train Loss: 1.3148,	Validation Loss: 1.2825,
# Epoch 15/1000,	Train Loss: 1.3017,	Validation Loss: 1.2707,
# Epoch 16/1000,	Train Loss: 1.2857,	Validation Loss: 1.2572,
# Epoch 17/1000,	Train Loss: 1.2716,	Validation Loss: 1.2417,
# Epoch 18/1000,	Train Loss: 1.2721,	Validation Loss: 1.2252,
# Epoch 19/1000,	Train Loss: 1.2582,	Validation Loss: 1.2081,
# Epoch 20/1000,	Train Loss: 1.2613,	Validation Loss: 1.1911,
# Epoch 21/1000,	Train Loss: 1.2071,	Validation Loss: 1.1709,
# Epoch 22/1000,	Train Loss: 1.2321,	Validation Loss: 1.1506,
# Epoch 23/1000,	Train Loss: 1.1900,	Validation Loss: 1.1287,
# Epoch 24/1000,	Train Loss: 1.1614,	Validation Loss: 1.1051,
# Epoch 25/1000,	Train Loss: 1.1643,	Validation Loss: 1.0806,
# Epoch 26/1000,	Train Loss: 1.1595,	Validation Loss: 1.0569,
# Epoch 27/1000,	Train Loss: 1.0896,	Validation Loss: 1.0327,
# Epoch 28/1000,	Train Loss: 1.0725,	Validation Loss: 1.0072,
# Epoch 29/1000,	Train Loss: 1.0856,	Validation Loss: 0.9807,
# Epoch 30/1000,	Train Loss: 1.0858,	Validation Loss: 0.9561,
# Epoch 31/1000,	Train Loss: 1.0534,	Validation Loss: 0.9339,
# Epoch 32/1000,	Train Loss: 1.0776,	Validation Loss: 0.9124,
# Epoch 33/1000,	Train Loss: 1.0069,	Validation Loss: 0.8915,
# Epoch 34/1000,	Train Loss: 0.9543,	Validation Loss: 0.8700,
# Epoch 35/1000,	Train Loss: 1.0725,	Validation Loss: 0.8494,
# Epoch 36/1000,	Train Loss: 0.9964,	Validation Loss: 0.8279,
# Epoch 37/1000,	Train Loss: 0.9510,	Validation Loss: 0.8075,
# Epoch 38/1000,	Train Loss: 0.8938,	Validation Loss: 0.7867,
# Epoch 39/1000,	Train Loss: 0.9050,	Validation Loss: 0.7669,
# Epoch 40/1000,	Train Loss: 0.9218,	Validation Loss: 0.7461,
# Epoch 41/1000,	Train Loss: 0.9108,	Validation Loss: 0.7259,
# Epoch 42/1000,	Train Loss: 0.8714,	Validation Loss: 0.7076,
# Epoch 43/1000,	Train Loss: 0.9058,	Validation Loss: 0.6902,
# Epoch 44/1000,	Train Loss: 0.8738,	Validation Loss: 0.6743,
# Epoch 45/1000,	Train Loss: 0.8848,	Validation Loss: 0.6597,
# Epoch 46/1000,	Train Loss: 0.8970,	Validation Loss: 0.6470,
# Epoch 47/1000,	Train Loss: 0.8204,	Validation Loss: 0.6329,
# Epoch 48/1000,	Train Loss: 0.8273,	Validation Loss: 0.6183,
# Epoch 49/1000,	Train Loss: 0.8837,	Validation Loss: 0.6044,
# Epoch 50/1000,	Train Loss: 0.7551,	Validation Loss: 0.5905,
# Epoch 51/1000,	Train Loss: 0.6992,	Validation Loss: 0.5777,
# Epoch 52/1000,	Train Loss: 0.8261,	Validation Loss: 0.5667,
# Epoch 53/1000,	Train Loss: 0.7289,	Validation Loss: 0.5563,
# Epoch 54/1000,	Train Loss: 0.7662,	Validation Loss: 0.5459,
# Epoch 55/1000,	Train Loss: 0.7843,	Validation Loss: 0.5374,
# Epoch 56/1000,	Train Loss: 0.6804,	Validation Loss: 0.5286,
# Epoch 57/1000,	Train Loss: 0.6834,	Validation Loss: 0.5191,
# Epoch 58/1000,	Train Loss: 0.6917,	Validation Loss: 0.5108,
# Epoch 59/1000,	Train Loss: 0.6522,	Validation Loss: 0.5023,
# Epoch 60/1000,	Train Loss: 0.6936,	Validation Loss: 0.4937,
# Epoch 61/1000,	Train Loss: 0.6729,	Validation Loss: 0.4856,
# Epoch 62/1000,	Train Loss: 0.7151,	Validation Loss: 0.4782,
# Epoch 63/1000,	Train Loss: 0.7023,	Validation Loss: 0.4715,
# Epoch 64/1000,	Train Loss: 0.6225,	Validation Loss: 0.4650,
# Epoch 65/1000,	Train Loss: 0.6441,	Validation Loss: 0.4591,
# Epoch 66/1000,	Train Loss: 0.5868,	Validation Loss: 0.4531,
# Epoch 67/1000,	Train Loss: 0.7220,	Validation Loss: 0.4473,
# Epoch 68/1000,	Train Loss: 0.6816,	Validation Loss: 0.4421,
# Epoch 69/1000,	Train Loss: 0.5511,	Validation Loss: 0.4371,
# Epoch 70/1000,	Train Loss: 0.6305,	Validation Loss: 0.4322,
# Epoch 71/1000,	Train Loss: 0.7220,	Validation Loss: 0.4279,
# Epoch 72/1000,	Train Loss: 0.6186,	Validation Loss: 0.4240,
# Epoch 73/1000,	Train Loss: 0.6247,	Validation Loss: 0.4203,
# Epoch 74/1000,	Train Loss: 0.7352,	Validation Loss: 0.4177,
# Epoch 75/1000,	Train Loss: 0.6027,	Validation Loss: 0.4147,
# Epoch 76/1000,	Train Loss: 0.7301,	Validation Loss: 0.4121,
# Epoch 77/1000,	Train Loss: 0.6213,	Validation Loss: 0.4092,
# Epoch 78/1000,	Train Loss: 0.6067,	Validation Loss: 0.4062,
# Epoch 79/1000,	Train Loss: 0.6813,	Validation Loss: 0.4046,
# Epoch 80/1000,	Train Loss: 0.6223,	Validation Loss: 0.4029,
# Epoch 81/1000,	Train Loss: 0.6560,	Validation Loss: 0.4011,
# Epoch 82/1000,	Train Loss: 0.6150,	Validation Loss: 0.4002,
# Epoch 83/1000,	Train Loss: 0.6034,	Validation Loss: 0.3991,
# Epoch 84/1000,	Train Loss: 0.7178,	Validation Loss: 0.3987,
# Epoch 85/1000,	Train Loss: 0.5863,	Validation Loss: 0.3975,
# Epoch 86/1000,	Train Loss: 0.5873,	Validation Loss: 0.3961,
# Epoch 87/1000,	Train Loss: 0.6436,	Validation Loss: 0.3943,
# Epoch 88/1000,	Train Loss: 0.6551,	Validation Loss: 0.3939,
# Epoch 89/1000,	Train Loss: 0.5705,	Validation Loss: 0.3924,
# Epoch 90/1000,	Train Loss: 0.6212,	Validation Loss: 0.3907,
# Epoch 91/1000,	Train Loss: 0.6401,	Validation Loss: 0.3889,
# Epoch 92/1000,	Train Loss: 0.6089,	Validation Loss: 0.3876,
# Epoch 93/1000,	Train Loss: 0.5620,	Validation Loss: 0.3861,
# Epoch 94/1000,	Train Loss: 0.6083,	Validation Loss: 0.3847,
# Epoch 95/1000,	Train Loss: 0.6364,	Validation Loss: 0.3842,
# Epoch 96/1000,	Train Loss: 0.5870,	Validation Loss: 0.3833,
# Epoch 97/1000,	Train Loss: 0.6688,	Validation Loss: 0.3821,
# Epoch 98/1000,	Train Loss: 0.6207,	Validation Loss: 0.3814,
# Epoch 99/1000,	Train Loss: 0.5984,	Validation Loss: 0.3805,
# Epoch 100/1000,	Train Loss: 0.5957,	Validation Loss: 0.3795,
# Epoch 101/1000,	Train Loss: 0.5997,	Validation Loss: 0.3787,
# Epoch 102/1000,	Train Loss: 0.6161,	Validation Loss: 0.3776,
# Epoch 103/1000,	Train Loss: 0.6100,	Validation Loss: 0.3766,
# Epoch 104/1000,	Train Loss: 0.5733,	Validation Loss: 0.3756,
# Epoch 105/1000,	Train Loss: 0.6060,	Validation Loss: 0.3746,
# Epoch 106/1000,	Train Loss: 0.6384,	Validation Loss: 0.3739,
# Epoch 107/1000,	Train Loss: 0.5523,	Validation Loss: 0.3738,
# Epoch 108/1000,	Train Loss: 0.5262,	Validation Loss: 0.3731,
# Epoch 109/1000,	Train Loss: 0.6178,	Validation Loss: 0.3726,
# Epoch 110/1000,	Train Loss: 0.6010,	Validation Loss: 0.3718,
# Epoch 111/1000,	Train Loss: 0.5644,	Validation Loss: 0.3711,
# Epoch 112/1000,	Train Loss: 0.6914,	Validation Loss: 0.3705,
# Epoch 113/1000,	Train Loss: 0.5523,	Validation Loss: 0.3699,
# Epoch 114/1000,	Train Loss: 0.5660,	Validation Loss: 0.3689,
# Epoch 115/1000,	Train Loss: 0.6450,	Validation Loss: 0.3692,
# 	Early stopping patience counter: 1/40
# Epoch 116/1000,	Train Loss: 0.6351,	Validation Loss: 0.3695,
# 	Early stopping patience counter: 2/40
# Epoch 117/1000,	Train Loss: 0.5784,	Validation Loss: 0.3694,
# 	Early stopping patience counter: 3/40
# Epoch 118/1000,	Train Loss: 0.6761,	Validation Loss: 0.3696,
# 	Early stopping patience counter: 4/40
# Epoch 119/1000,	Train Loss: 0.6484,	Validation Loss: 0.3696,
# 	Early stopping patience counter: 5/40
# Epoch 120/1000,	Train Loss: 0.6998,	Validation Loss: 0.3707,
# 	Early stopping patience counter: 6/40
# Epoch 121/1000,	Train Loss: 0.6519,	Validation Loss: 0.3717,
# 	Early stopping patience counter: 7/40
# Epoch 122/1000,	Train Loss: 0.6823,	Validation Loss: 0.3723,
# 	Early stopping patience counter: 8/40
# Epoch 123/1000,	Train Loss: 0.6679,	Validation Loss: 0.3722,
# 	Early stopping patience counter: 9/40
# Epoch 124/1000,	Train Loss: 0.6433,	Validation Loss: 0.3722,
# 	Early stopping patience counter: 10/40
# Epoch 125/1000,	Train Loss: 0.6467,	Validation Loss: 0.3720,
# 	Early stopping patience counter: 11/40
# Epoch 126/1000,	Train Loss: 0.5045,	Validation Loss: 0.3715,
# 	Early stopping patience counter: 12/40
# Epoch 127/1000,	Train Loss: 0.5813,	Validation Loss: 0.3708,
# 	Early stopping patience counter: 13/40
# Epoch 128/1000,	Train Loss: 0.5694,	Validation Loss: 0.3701,
# 	Early stopping patience counter: 14/40
# Epoch 129/1000,	Train Loss: 0.6858,	Validation Loss: 0.3694,
# 	Early stopping patience counter: 15/40
# Epoch 130/1000,	Train Loss: 0.5017,	Validation Loss: 0.3687,
# Epoch 131/1000,	Train Loss: 0.6719,	Validation Loss: 0.3683,
# Epoch 132/1000,	Train Loss: 0.6052,	Validation Loss: 0.3686,
# 	Early stopping patience counter: 1/40
# Epoch 133/1000,	Train Loss: 0.5106,	Validation Loss: 0.3689,
# 	Early stopping patience counter: 2/40
# Epoch 134/1000,	Train Loss: 0.6528,	Validation Loss: 0.3690,
# 	Early stopping patience counter: 3/40
# Epoch 135/1000,	Train Loss: 0.5795,	Validation Loss: 0.3686,
# 	Early stopping patience counter: 4/40
# Epoch 136/1000,	Train Loss: 0.5174,	Validation Loss: 0.3677,
# Epoch 137/1000,	Train Loss: 0.5645,	Validation Loss: 0.3669,
# Epoch 138/1000,	Train Loss: 0.5387,	Validation Loss: 0.3664,
# Epoch 139/1000,	Train Loss: 0.6161,	Validation Loss: 0.3660,
# Epoch 140/1000,	Train Loss: 0.6650,	Validation Loss: 0.3659,
# Epoch 141/1000,	Train Loss: 0.5883,	Validation Loss: 0.3657,
# Epoch 142/1000,	Train Loss: 0.5758,	Validation Loss: 0.3653,
# Epoch 143/1000,	Train Loss: 0.5249,	Validation Loss: 0.3654,
# 	Early stopping patience counter: 1/40
# Epoch 144/1000,	Train Loss: 0.5556,	Validation Loss: 0.3649,
# Epoch 145/1000,	Train Loss: 0.6518,	Validation Loss: 0.3643,
# Epoch 146/1000,	Train Loss: 0.6477,	Validation Loss: 0.3640,
# Epoch 147/1000,	Train Loss: 0.5962,	Validation Loss: 0.3644,
# 	Early stopping patience counter: 1/40
# Epoch 148/1000,	Train Loss: 0.6821,	Validation Loss: 0.3646,
# 	Early stopping patience counter: 2/40
# Epoch 149/1000,	Train Loss: 0.6053,	Validation Loss: 0.3647,
# 	Early stopping patience counter: 3/40
# Epoch 150/1000,	Train Loss: 0.5752,	Validation Loss: 0.3643,
# 	Early stopping patience counter: 4/40
# Epoch 151/1000,	Train Loss: 0.5033,	Validation Loss: 0.3641,
# 	Early stopping patience counter: 5/40
# Epoch 152/1000,	Train Loss: 0.6689,	Validation Loss: 0.3637,
# Epoch 153/1000,	Train Loss: 0.5283,	Validation Loss: 0.3634,
# Epoch 154/1000,	Train Loss: 0.6627,	Validation Loss: 0.3630,
# Epoch 155/1000,	Train Loss: 0.6482,	Validation Loss: 0.3629,
# Epoch 156/1000,	Train Loss: 0.5179,	Validation Loss: 0.3633,
# 	Early stopping patience counter: 1/40
# Epoch 157/1000,	Train Loss: 0.5306,	Validation Loss: 0.3637,
# 	Early stopping patience counter: 2/40
# Epoch 158/1000,	Train Loss: 0.5133,	Validation Loss: 0.3636,
# 	Early stopping patience counter: 3/40
# Epoch 159/1000,	Train Loss: 0.5062,	Validation Loss: 0.3630,
# 	Early stopping patience counter: 4/40
# Epoch 160/1000,	Train Loss: 0.6436,	Validation Loss: 0.3626,
# Epoch 161/1000,	Train Loss: 0.5714,	Validation Loss: 0.3622,
# Epoch 162/1000,	Train Loss: 0.5219,	Validation Loss: 0.3623,
# 	Early stopping patience counter: 1/40
# Epoch 163/1000,	Train Loss: 0.6277,	Validation Loss: 0.3624,
# 	Early stopping patience counter: 2/40
# Epoch 164/1000,	Train Loss: 0.6278,	Validation Loss: 0.3627,
# 	Early stopping patience counter: 3/40
# Epoch 165/1000,	Train Loss: 0.6157,	Validation Loss: 0.3632,
# 	Early stopping patience counter: 4/40
# Epoch 166/1000,	Train Loss: 0.5645,	Validation Loss: 0.3631,
# 	Early stopping patience counter: 5/40
# Epoch 167/1000,	Train Loss: 0.6021,	Validation Loss: 0.3631,
# 	Early stopping patience counter: 6/40
# Epoch 168/1000,	Train Loss: 0.6014,	Validation Loss: 0.3630,
# 	Early stopping patience counter: 7/40
# Epoch 169/1000,	Train Loss: 0.5901,	Validation Loss: 0.3631,
# 	Early stopping patience counter: 8/40
# Epoch 170/1000,	Train Loss: 0.5841,	Validation Loss: 0.3629,
# 	Early stopping patience counter: 9/40
# Epoch 171/1000,	Train Loss: 0.6626,	Validation Loss: 0.3630,
# 	Early stopping patience counter: 10/40
# Epoch 172/1000,	Train Loss: 0.5953,	Validation Loss: 0.3628,
# 	Early stopping patience counter: 11/40
# Epoch 173/1000,	Train Loss: 0.6579,	Validation Loss: 0.3627,
# 	Early stopping patience counter: 12/40
# Epoch 174/1000,	Train Loss: 0.6143,	Validation Loss: 0.3626,
# 	Early stopping patience counter: 13/40
# Epoch 175/1000,	Train Loss: 0.5805,	Validation Loss: 0.3626,
# 	Early stopping patience counter: 14/40
# Epoch 176/1000,	Train Loss: 0.6872,	Validation Loss: 0.3632,
# 	Early stopping patience counter: 15/40
# Epoch 177/1000,	Train Loss: 0.6094,	Validation Loss: 0.3635,
# 	Early stopping patience counter: 16/40
# Epoch 178/1000,	Train Loss: 0.5373,	Validation Loss: 0.3637,
# 	Early stopping patience counter: 17/40
# Epoch 179/1000,	Train Loss: 0.5964,	Validation Loss: 0.3634,
# 	Early stopping patience counter: 18/40
# Epoch 180/1000,	Train Loss: 0.5152,	Validation Loss: 0.3630,
# 	Early stopping patience counter: 19/40
# Epoch 181/1000,	Train Loss: 0.5562,	Validation Loss: 0.3624,
# 	Early stopping patience counter: 20/40
# Epoch 182/1000,	Train Loss: 0.5807,	Validation Loss: 0.3621,
# Epoch 183/1000,	Train Loss: 0.6530,	Validation Loss: 0.3621,
# Epoch 184/1000,	Train Loss: 0.6475,	Validation Loss: 0.3623,
# 	Early stopping patience counter: 1/40
# Epoch 185/1000,	Train Loss: 0.5490,	Validation Loss: 0.3629,
# 	Early stopping patience counter: 2/40
# Epoch 186/1000,	Train Loss: 0.6651,	Validation Loss: 0.3631,
# 	Early stopping patience counter: 3/40
# Epoch 187/1000,	Train Loss: 0.5352,	Validation Loss: 0.3636,
# 	Early stopping patience counter: 4/40
# Epoch 188/1000,	Train Loss: 0.5651,	Validation Loss: 0.3636,
# 	Early stopping patience counter: 5/40
# Epoch 189/1000,	Train Loss: 0.6331,	Validation Loss: 0.3643,
# 	Early stopping patience counter: 6/40
# Epoch 190/1000,	Train Loss: 0.6319,	Validation Loss: 0.3646,
# 	Early stopping patience counter: 7/40
# Epoch 191/1000,	Train Loss: 0.6130,	Validation Loss: 0.3649,
# 	Early stopping patience counter: 8/40
# Epoch 192/1000,	Train Loss: 0.7072,	Validation Loss: 0.3651,
# 	Early stopping patience counter: 9/40
# Epoch 193/1000,	Train Loss: 0.5912,	Validation Loss: 0.3658,
# 	Early stopping patience counter: 10/40
# Epoch 194/1000,	Train Loss: 0.6003,	Validation Loss: 0.3658,
# 	Early stopping patience counter: 11/40
# Epoch 195/1000,	Train Loss: 0.7129,	Validation Loss: 0.3659,
# 	Early stopping patience counter: 12/40
# Epoch 196/1000,	Train Loss: 0.5431,	Validation Loss: 0.3657,
# 	Early stopping patience counter: 13/40
# Epoch 197/1000,	Train Loss: 0.5652,	Validation Loss: 0.3654,
# 	Early stopping patience counter: 14/40
# Epoch 198/1000,	Train Loss: 0.6294,	Validation Loss: 0.3651,
# 	Early stopping patience counter: 15/40
# Epoch 199/1000,	Train Loss: 0.5720,	Validation Loss: 0.3649,
# 	Early stopping patience counter: 16/40
# Epoch 200/1000,	Train Loss: 0.6484,	Validation Loss: 0.3656,
# 	Early stopping patience counter: 17/40
# Epoch 201/1000,	Train Loss: 0.6420,	Validation Loss: 0.3659,
# 	Early stopping patience counter: 18/40
# Epoch 202/1000,	Train Loss: 0.6105,	Validation Loss: 0.3658,
# 	Early stopping patience counter: 19/40
# Epoch 203/1000,	Train Loss: 0.6067,	Validation Loss: 0.3654,
# 	Early stopping patience counter: 20/40
# Epoch 204/1000,	Train Loss: 0.5740,	Validation Loss: 0.3650,
# 	Early stopping patience counter: 21/40
# Epoch 205/1000,	Train Loss: 0.6002,	Validation Loss: 0.3646,
# 	Early stopping patience counter: 22/40
# Epoch 206/1000,	Train Loss: 0.5606,	Validation Loss: 0.3640,
# 	Early stopping patience counter: 23/40
# Epoch 207/1000,	Train Loss: 0.6072,	Validation Loss: 0.3634,
# 	Early stopping patience counter: 24/40
# Epoch 208/1000,	Train Loss: 0.6806,	Validation Loss: 0.3638,
# 	Early stopping patience counter: 25/40
# Epoch 209/1000,	Train Loss: 0.6318,	Validation Loss: 0.3640,
# 	Early stopping patience counter: 26/40
# Epoch 210/1000,	Train Loss: 0.5807,	Validation Loss: 0.3641,
# 	Early stopping patience counter: 27/40
# Epoch 211/1000,	Train Loss: 0.5449,	Validation Loss: 0.3642,
# 	Early stopping patience counter: 28/40
# Epoch 212/1000,	Train Loss: 0.6596,	Validation Loss: 0.3640,
# 	Early stopping patience counter: 29/40
# Epoch 213/1000,	Train Loss: 0.6550,	Validation Loss: 0.3640,
# 	Early stopping patience counter: 30/40
# Epoch 214/1000,	Train Loss: 0.5136,	Validation Loss: 0.3637,
# 	Early stopping patience counter: 31/40
# Epoch 215/1000,	Train Loss: 0.5657,	Validation Loss: 0.3634,
# 	Early stopping patience counter: 32/40
# Epoch 216/1000,	Train Loss: 0.5967,	Validation Loss: 0.3635,
# 	Early stopping patience counter: 33/40
# Epoch 217/1000,	Train Loss: 0.6793,	Validation Loss: 0.3635,
# 	Early stopping patience counter: 34/40
# Epoch 218/1000,	Train Loss: 0.6407,	Validation Loss: 0.3639,
# 	Early stopping patience counter: 35/40
# Epoch 219/1000,	Train Loss: 0.6348,	Validation Loss: 0.3656,
# 	Early stopping patience counter: 36/40
# Epoch 220/1000,	Train Loss: 0.5812,	Validation Loss: 0.3672,
# 	Early stopping patience counter: 37/40
# Epoch 221/1000,	Train Loss: 0.5542,	Validation Loss: 0.3672,
# 	Early stopping patience counter: 38/40
# Epoch 222/1000,	Train Loss: 0.5502,	Validation Loss: 0.3670,
# 	Early stopping patience counter: 39/40
# Epoch 223/1000,	Train Loss: 0.6218,	Validation Loss: 0.3666,
# 	Early stopping patience counter: 40/40
# 	Early stopping triggered. Stopping training.
# ===================================
#  M O D E L   L O C A T I O N :
# nn_models\mlp_step_2025-05-13-23-35-01.pth
# ===================================
#
#
#
# ===================================
#  persons_in_overlap: 11
# ===================================

# %%
plot_shaps(model_step, features_step)

# %%
print_stats(model_step, val_loader_step, params)
# Out:
# {'typ': 'step', 'batch_size': 512, 'hidden_size': [4, 2], 'dropout_prob': 0.2, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40, 'l2_lambda': 0}
# Validation Loss:	0.3621
# Mean vizier:		0.9073
# Mean non-vizier:	0.1486
# bottom_3_vizier:	0.9902
# top_3_non_vizier:	0.9142
# PiO Validation:		11

# %% [raw]
# {'typ': 'step', 'batch_size': 128, 'hidden_size': [], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0788
# Mean vizier:		0.9926
# Mean non-vizier:	0.0489
# bottom_3_vizier:	0.9924
# top_3_non_vizier:	0.9721
# PiO Validation:		0
#
# {'typ': 'step', 'batch_size': 128, 'hidden_size': [2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0779
# Mean vizier:		0.9930
# Mean non-vizier:	0.0476
# bottom_3_vizier:	0.9941
# top_3_non_vizier:	0.9749
# PiO Validation:		0
#
# {'typ': 'step', 'batch_size': 64, 'hidden_size': [2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0722
# Mean vizier:		0.9920
# Mean non-vizier:	0.0461
# bottom_3_vizier:	0.9876
# top_3_non_vizier:	0.9190
# PiO Validation:		2
#
# {'typ': 'step', 'batch_size': 128, 'hidden_size': [4], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0739
# Mean vizier:		0.9939
# Mean non-vizier:	0.0456
# bottom_3_vizier:	0.9916
# top_3_non_vizier:	0.9663
# PiO Validation:		0
#
# {'typ': 'step', 'batch_size': 128, 'hidden_size': [4], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0.1, 'epochs': 1000, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0757
# Mean vizier:		0.9722
# Mean non-vizier:	0.0257
# bottom_3_vizier:	0.9666
# top_3_non_vizier:	0.9759
# PiO Validation:		7
#
# {'typ': 'step', 'batch_size': 128, 'hidden_size': [2, 2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.01, 'patience': 40}
# Validation Loss:	0.0794
# Mean vizier:		0.9758
# Mean non-vizier:	0.0324
# bottom_3_vizier:	0.9774
# top_3_non_vizier:	0.9748
# PiO Validation:		5
#
# {'typ': 'step', 'batch_size': 512, 'hidden_size': [4], 'activation_name': 'leaky_relu', 'optimizer_name': 'adam', 'dropout_prob': 0.1, 'epochs': 1500, 'learning_rate': 0.005, 'patience': 40}
# Validation Loss:	0.0778
# Mean vizier:		0.9888
# Mean non-vizier:	0.0464
# bottom_3_vizier:	0.9779
# top_3_non_vizier:	0.9482
# PiO Validation:		2

# %% [markdown]
# ### Lasso NN

# %%
params = {'typ': 'lasso',
          'batch_size': 512,
          'hidden_size': [12, 8],
          'dropout_prob': 0.5,
          'activation_name': 'relu',
          'optimizer_name': 'adam',
          'epochs': 1000,
          'learning_rate': 0.0005,
          'patience': 40,
          'l2_lambda': 0
         }
model_lasso, val_loader_lasso = train_nn(params)
# Out:
# ===================================
#  S T A R T I N G   M O D E L
# ===================================
#
# Defined BinaryClassifier with criterion=BCEWithLogitsLoss()
# Defined BinaryClassifier with optimizer=Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0
# )
#
# ===================================
# MODEL ARCHITECTURE:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=16, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=12, out_features=8, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=8, out_features=1, bias=True)
#   )
# )
# ===================================
#
#
# ===================================
# NUMBER OF PARAMETERS: 317
# ===================================
#
# Epoch 1/1000,	Train Loss: 1.3618,	Validation Loss: 1.3488,
# Epoch 2/1000,	Train Loss: 1.3589,	Validation Loss: 1.3469,
# Epoch 3/1000,	Train Loss: 1.3481,	Validation Loss: 1.3450,
# Epoch 4/1000,	Train Loss: 1.3557,	Validation Loss: 1.3433,
# Epoch 5/1000,	Train Loss: 1.3474,	Validation Loss: 1.3417,
# Epoch 6/1000,	Train Loss: 1.3470,	Validation Loss: 1.3400,
# Epoch 7/1000,	Train Loss: 1.3495,	Validation Loss: 1.3383,
# Epoch 8/1000,	Train Loss: 1.3459,	Validation Loss: 1.3366,
# Epoch 9/1000,	Train Loss: 1.3486,	Validation Loss: 1.3350,
# Epoch 10/1000,	Train Loss: 1.3442,	Validation Loss: 1.3335,
# Epoch 11/1000,	Train Loss: 1.3424,	Validation Loss: 1.3317,
# Epoch 12/1000,	Train Loss: 1.3355,	Validation Loss: 1.3298,
# Epoch 13/1000,	Train Loss: 1.3389,	Validation Loss: 1.3276,
# Epoch 14/1000,	Train Loss: 1.3413,	Validation Loss: 1.3255,
# Epoch 15/1000,	Train Loss: 1.3324,	Validation Loss: 1.3233,
# Epoch 16/1000,	Train Loss: 1.3325,	Validation Loss: 1.3211,
# Epoch 17/1000,	Train Loss: 1.3219,	Validation Loss: 1.3184,
# Epoch 18/1000,	Train Loss: 1.3164,	Validation Loss: 1.3155,
# Epoch 19/1000,	Train Loss: 1.3256,	Validation Loss: 1.3123,
# Epoch 20/1000,	Train Loss: 1.3340,	Validation Loss: 1.3091,
# Epoch 21/1000,	Train Loss: 1.3219,	Validation Loss: 1.3056,
# Epoch 22/1000,	Train Loss: 1.3186,	Validation Loss: 1.3020,
# Epoch 23/1000,	Train Loss: 1.3165,	Validation Loss: 1.2980,
# Epoch 24/1000,	Train Loss: 1.3090,	Validation Loss: 1.2932,
# Epoch 25/1000,	Train Loss: 1.3050,	Validation Loss: 1.2881,
# Epoch 26/1000,	Train Loss: 1.3064,	Validation Loss: 1.2833,
# Epoch 27/1000,	Train Loss: 1.3102,	Validation Loss: 1.2783,
# Epoch 28/1000,	Train Loss: 1.2900,	Validation Loss: 1.2729,
# Epoch 29/1000,	Train Loss: 1.2965,	Validation Loss: 1.2669,
# Epoch 30/1000,	Train Loss: 1.2934,	Validation Loss: 1.2606,
# Epoch 31/1000,	Train Loss: 1.2613,	Validation Loss: 1.2543,
# Epoch 32/1000,	Train Loss: 1.2751,	Validation Loss: 1.2478,
# Epoch 33/1000,	Train Loss: 1.2567,	Validation Loss: 1.2406,
# Epoch 34/1000,	Train Loss: 1.2522,	Validation Loss: 1.2324,
# Epoch 35/1000,	Train Loss: 1.2450,	Validation Loss: 1.2238,
# Epoch 36/1000,	Train Loss: 1.2407,	Validation Loss: 1.2148,
# Epoch 37/1000,	Train Loss: 1.2381,	Validation Loss: 1.2059,
# Epoch 38/1000,	Train Loss: 1.2371,	Validation Loss: 1.1968,
# Epoch 39/1000,	Train Loss: 1.2205,	Validation Loss: 1.1868,
# Epoch 40/1000,	Train Loss: 1.2456,	Validation Loss: 1.1769,
# Epoch 41/1000,	Train Loss: 1.1669,	Validation Loss: 1.1665,
# Epoch 42/1000,	Train Loss: 1.2188,	Validation Loss: 1.1548,
# Epoch 43/1000,	Train Loss: 1.2171,	Validation Loss: 1.1436,
# Epoch 44/1000,	Train Loss: 1.1606,	Validation Loss: 1.1314,
# Epoch 45/1000,	Train Loss: 1.1712,	Validation Loss: 1.1173,
# Epoch 46/1000,	Train Loss: 1.1965,	Validation Loss: 1.1041,
# Epoch 47/1000,	Train Loss: 1.1598,	Validation Loss: 1.0910,
# Epoch 48/1000,	Train Loss: 1.1883,	Validation Loss: 1.0765,
# Epoch 49/1000,	Train Loss: 1.1322,	Validation Loss: 1.0622,
# Epoch 50/1000,	Train Loss: 1.1551,	Validation Loss: 1.0478,
# Epoch 51/1000,	Train Loss: 1.1069,	Validation Loss: 1.0328,
# Epoch 52/1000,	Train Loss: 1.1078,	Validation Loss: 1.0162,
# Epoch 53/1000,	Train Loss: 1.0939,	Validation Loss: 0.9990,
# Epoch 54/1000,	Train Loss: 1.0782,	Validation Loss: 0.9810,
# Epoch 55/1000,	Train Loss: 1.0725,	Validation Loss: 0.9636,
# Epoch 56/1000,	Train Loss: 1.0057,	Validation Loss: 0.9466,
# Epoch 57/1000,	Train Loss: 1.0539,	Validation Loss: 0.9305,
# Epoch 58/1000,	Train Loss: 1.0470,	Validation Loss: 0.9143,
# Epoch 59/1000,	Train Loss: 1.0347,	Validation Loss: 0.8988,
# Epoch 60/1000,	Train Loss: 1.0168,	Validation Loss: 0.8827,
# Epoch 61/1000,	Train Loss: 0.9940,	Validation Loss: 0.8674,
# Epoch 62/1000,	Train Loss: 0.9841,	Validation Loss: 0.8530,
# Epoch 63/1000,	Train Loss: 1.0359,	Validation Loss: 0.8382,
# Epoch 64/1000,	Train Loss: 0.9624,	Validation Loss: 0.8227,
# Epoch 65/1000,	Train Loss: 0.9344,	Validation Loss: 0.8074,
# Epoch 66/1000,	Train Loss: 0.9378,	Validation Loss: 0.7928,
# Epoch 67/1000,	Train Loss: 0.9382,	Validation Loss: 0.7795,
# Epoch 68/1000,	Train Loss: 0.9149,	Validation Loss: 0.7655,
# Epoch 69/1000,	Train Loss: 0.9456,	Validation Loss: 0.7521,
# Epoch 70/1000,	Train Loss: 0.8675,	Validation Loss: 0.7375,
# Epoch 71/1000,	Train Loss: 0.8612,	Validation Loss: 0.7235,
# Epoch 72/1000,	Train Loss: 0.8653,	Validation Loss: 0.7098,
# Epoch 73/1000,	Train Loss: 0.8680,	Validation Loss: 0.6965,
# Epoch 74/1000,	Train Loss: 0.8733,	Validation Loss: 0.6844,
# Epoch 75/1000,	Train Loss: 0.9012,	Validation Loss: 0.6740,
# Epoch 76/1000,	Train Loss: 0.8233,	Validation Loss: 0.6631,
# Epoch 77/1000,	Train Loss: 0.8047,	Validation Loss: 0.6511,
# Epoch 78/1000,	Train Loss: 0.7872,	Validation Loss: 0.6394,
# Epoch 79/1000,	Train Loss: 0.8154,	Validation Loss: 0.6288,
# Epoch 80/1000,	Train Loss: 0.8086,	Validation Loss: 0.6182,
# Epoch 81/1000,	Train Loss: 0.8101,	Validation Loss: 0.6085,
# Epoch 82/1000,	Train Loss: 0.8085,	Validation Loss: 0.5990,
# Epoch 83/1000,	Train Loss: 0.7731,	Validation Loss: 0.5894,
# Epoch 84/1000,	Train Loss: 0.7669,	Validation Loss: 0.5793,
# Epoch 85/1000,	Train Loss: 0.7736,	Validation Loss: 0.5691,
# Epoch 86/1000,	Train Loss: 0.7538,	Validation Loss: 0.5593,
# Epoch 87/1000,	Train Loss: 0.7995,	Validation Loss: 0.5504,
# Epoch 88/1000,	Train Loss: 0.7631,	Validation Loss: 0.5417,
# Epoch 89/1000,	Train Loss: 0.7517,	Validation Loss: 0.5330,
# Epoch 90/1000,	Train Loss: 0.7576,	Validation Loss: 0.5245,
# Epoch 91/1000,	Train Loss: 0.7697,	Validation Loss: 0.5160,
# Epoch 92/1000,	Train Loss: 0.6928,	Validation Loss: 0.5078,
# Epoch 93/1000,	Train Loss: 0.7087,	Validation Loss: 0.4994,
# Epoch 94/1000,	Train Loss: 0.6945,	Validation Loss: 0.4912,
# Epoch 95/1000,	Train Loss: 0.7128,	Validation Loss: 0.4837,
# Epoch 96/1000,	Train Loss: 0.7171,	Validation Loss: 0.4778,
# Epoch 97/1000,	Train Loss: 0.6887,	Validation Loss: 0.4715,
# Epoch 98/1000,	Train Loss: 0.6608,	Validation Loss: 0.4645,
# Epoch 99/1000,	Train Loss: 0.6868,	Validation Loss: 0.4576,
# Epoch 100/1000,	Train Loss: 0.7099,	Validation Loss: 0.4507,
# Epoch 101/1000,	Train Loss: 0.6861,	Validation Loss: 0.4445,
# Epoch 102/1000,	Train Loss: 0.6408,	Validation Loss: 0.4382,
# Epoch 103/1000,	Train Loss: 0.6828,	Validation Loss: 0.4322,
# Epoch 104/1000,	Train Loss: 0.6628,	Validation Loss: 0.4261,
# Epoch 105/1000,	Train Loss: 0.6677,	Validation Loss: 0.4204,
# Epoch 106/1000,	Train Loss: 0.6374,	Validation Loss: 0.4163,
# Epoch 107/1000,	Train Loss: 0.6547,	Validation Loss: 0.4122,
# Epoch 108/1000,	Train Loss: 0.6265,	Validation Loss: 0.4078,
# Epoch 109/1000,	Train Loss: 0.6564,	Validation Loss: 0.4026,
# Epoch 110/1000,	Train Loss: 0.6307,	Validation Loss: 0.3974,
# Epoch 111/1000,	Train Loss: 0.6686,	Validation Loss: 0.3924,
# Epoch 112/1000,	Train Loss: 0.6105,	Validation Loss: 0.3875,
# Epoch 113/1000,	Train Loss: 0.6183,	Validation Loss: 0.3821,
# Epoch 114/1000,	Train Loss: 0.5924,	Validation Loss: 0.3767,
# Epoch 115/1000,	Train Loss: 0.6811,	Validation Loss: 0.3717,
# Epoch 116/1000,	Train Loss: 0.6292,	Validation Loss: 0.3669,
# Epoch 117/1000,	Train Loss: 0.5872,	Validation Loss: 0.3617,
# Epoch 118/1000,	Train Loss: 0.5891,	Validation Loss: 0.3564,
# Epoch 119/1000,	Train Loss: 0.5843,	Validation Loss: 0.3515,
# Epoch 120/1000,	Train Loss: 0.6469,	Validation Loss: 0.3491,
# Epoch 121/1000,	Train Loss: 0.5882,	Validation Loss: 0.3454,
# Epoch 122/1000,	Train Loss: 0.5594,	Validation Loss: 0.3413,
# Epoch 123/1000,	Train Loss: 0.6315,	Validation Loss: 0.3373,
# Epoch 124/1000,	Train Loss: 0.5789,	Validation Loss: 0.3342,
# Epoch 125/1000,	Train Loss: 0.5936,	Validation Loss: 0.3307,
# Epoch 126/1000,	Train Loss: 0.6113,	Validation Loss: 0.3271,
# Epoch 127/1000,	Train Loss: 0.6040,	Validation Loss: 0.3235,
# Epoch 128/1000,	Train Loss: 0.5712,	Validation Loss: 0.3198,
# Epoch 129/1000,	Train Loss: 0.5479,	Validation Loss: 0.3158,
# Epoch 130/1000,	Train Loss: 0.6317,	Validation Loss: 0.3120,
# Epoch 131/1000,	Train Loss: 0.6353,	Validation Loss: 0.3084,
# Epoch 132/1000,	Train Loss: 0.5274,	Validation Loss: 0.3046,
# Epoch 133/1000,	Train Loss: 0.5428,	Validation Loss: 0.3009,
# Epoch 134/1000,	Train Loss: 0.5694,	Validation Loss: 0.2980,
# Epoch 135/1000,	Train Loss: 0.6287,	Validation Loss: 0.2974,
# Epoch 136/1000,	Train Loss: 0.5347,	Validation Loss: 0.2949,
# Epoch 137/1000,	Train Loss: 0.5339,	Validation Loss: 0.2918,
# Epoch 138/1000,	Train Loss: 0.5917,	Validation Loss: 0.2888,
# Epoch 139/1000,	Train Loss: 0.5047,	Validation Loss: 0.2851,
# Epoch 140/1000,	Train Loss: 0.5524,	Validation Loss: 0.2819,
# Epoch 141/1000,	Train Loss: 0.5733,	Validation Loss: 0.2789,
# Epoch 142/1000,	Train Loss: 0.4569,	Validation Loss: 0.2755,
# Epoch 143/1000,	Train Loss: 0.5634,	Validation Loss: 0.2728,
# Epoch 144/1000,	Train Loss: 0.5595,	Validation Loss: 0.2701,
# Epoch 145/1000,	Train Loss: 0.5668,	Validation Loss: 0.2675,
# Epoch 146/1000,	Train Loss: 0.4931,	Validation Loss: 0.2654,
# Epoch 147/1000,	Train Loss: 0.5319,	Validation Loss: 0.2629,
# Epoch 148/1000,	Train Loss: 0.5490,	Validation Loss: 0.2603,
# Epoch 149/1000,	Train Loss: 0.5032,	Validation Loss: 0.2581,
# Epoch 150/1000,	Train Loss: 0.5077,	Validation Loss: 0.2559,
# Epoch 151/1000,	Train Loss: 0.4961,	Validation Loss: 0.2533,
# Epoch 152/1000,	Train Loss: 0.4649,	Validation Loss: 0.2503,
# Epoch 153/1000,	Train Loss: 0.4671,	Validation Loss: 0.2473,
# Epoch 154/1000,	Train Loss: 0.4503,	Validation Loss: 0.2448,
# Epoch 155/1000,	Train Loss: 0.5642,	Validation Loss: 0.2426,
# Epoch 156/1000,	Train Loss: 0.4496,	Validation Loss: 0.2403,
# Epoch 157/1000,	Train Loss: 0.4530,	Validation Loss: 0.2380,
# Epoch 158/1000,	Train Loss: 0.4790,	Validation Loss: 0.2357,
# Epoch 159/1000,	Train Loss: 0.5510,	Validation Loss: 0.2342,
# Epoch 160/1000,	Train Loss: 0.4501,	Validation Loss: 0.2327,
# Epoch 161/1000,	Train Loss: 0.5384,	Validation Loss: 0.2313,
# Epoch 162/1000,	Train Loss: 0.4744,	Validation Loss: 0.2302,
# Epoch 163/1000,	Train Loss: 0.5731,	Validation Loss: 0.2295,
# Epoch 164/1000,	Train Loss: 0.4738,	Validation Loss: 0.2281,
# Epoch 165/1000,	Train Loss: 0.6060,	Validation Loss: 0.2276,
# Epoch 166/1000,	Train Loss: 0.4402,	Validation Loss: 0.2264,
# Epoch 167/1000,	Train Loss: 0.5155,	Validation Loss: 0.2257,
# Epoch 168/1000,	Train Loss: 0.4716,	Validation Loss: 0.2246,
# Epoch 169/1000,	Train Loss: 0.5575,	Validation Loss: 0.2236,
# Epoch 170/1000,	Train Loss: 0.5430,	Validation Loss: 0.2229,
# Epoch 171/1000,	Train Loss: 0.4866,	Validation Loss: 0.2218,
# Epoch 172/1000,	Train Loss: 0.5850,	Validation Loss: 0.2209,
# Epoch 173/1000,	Train Loss: 0.4971,	Validation Loss: 0.2226,
# 	Early stopping patience counter: 1/40
# Epoch 174/1000,	Train Loss: 0.4792,	Validation Loss: 0.2222,
# 	Early stopping patience counter: 2/40
# Epoch 175/1000,	Train Loss: 0.4991,	Validation Loss: 0.2208,
# Epoch 176/1000,	Train Loss: 0.6060,	Validation Loss: 0.2202,
# Epoch 177/1000,	Train Loss: 0.4465,	Validation Loss: 0.2211,
# 	Early stopping patience counter: 1/40
# Epoch 178/1000,	Train Loss: 0.4462,	Validation Loss: 0.2207,
# 	Early stopping patience counter: 2/40
# Epoch 179/1000,	Train Loss: 0.4836,	Validation Loss: 0.2200,
# Epoch 180/1000,	Train Loss: 0.4191,	Validation Loss: 0.2186,
# Epoch 181/1000,	Train Loss: 0.4011,	Validation Loss: 0.2168,
# Epoch 182/1000,	Train Loss: 0.5271,	Validation Loss: 0.2158,
# Epoch 183/1000,	Train Loss: 0.4167,	Validation Loss: 0.2145,
# Epoch 184/1000,	Train Loss: 0.4294,	Validation Loss: 0.2129,
# Epoch 185/1000,	Train Loss: 0.4239,	Validation Loss: 0.2113,
# Epoch 186/1000,	Train Loss: 0.4830,	Validation Loss: 0.2098,
# Epoch 187/1000,	Train Loss: 0.3843,	Validation Loss: 0.2084,
# Epoch 188/1000,	Train Loss: 0.4393,	Validation Loss: 0.2071,
# Epoch 189/1000,	Train Loss: 0.5410,	Validation Loss: 0.2063,
# Epoch 190/1000,	Train Loss: 0.4816,	Validation Loss: 0.2060,
# Epoch 191/1000,	Train Loss: 0.4719,	Validation Loss: 0.2056,
# Epoch 192/1000,	Train Loss: 0.5206,	Validation Loss: 0.2052,
# Epoch 193/1000,	Train Loss: 0.4473,	Validation Loss: 0.2042,
# Epoch 194/1000,	Train Loss: 0.4853,	Validation Loss: 0.2032,
# Epoch 195/1000,	Train Loss: 0.4467,	Validation Loss: 0.2024,
# Epoch 196/1000,	Train Loss: 0.4503,	Validation Loss: 0.2021,
# Epoch 197/1000,	Train Loss: 0.4413,	Validation Loss: 0.2014,
# Epoch 198/1000,	Train Loss: 0.4554,	Validation Loss: 0.2011,
# Epoch 199/1000,	Train Loss: 0.4383,	Validation Loss: 0.2003,
# Epoch 200/1000,	Train Loss: 0.4011,	Validation Loss: 0.1996,
# Epoch 201/1000,	Train Loss: 0.4936,	Validation Loss: 0.1992,
# Epoch 202/1000,	Train Loss: 0.5224,	Validation Loss: 0.1989,
# Epoch 203/1000,	Train Loss: 0.4886,	Validation Loss: 0.1984,
# Epoch 204/1000,	Train Loss: 0.4349,	Validation Loss: 0.1979,
# Epoch 205/1000,	Train Loss: 0.4905,	Validation Loss: 0.1980,
# 	Early stopping patience counter: 1/40
# Epoch 206/1000,	Train Loss: 0.3854,	Validation Loss: 0.1978,
# Epoch 207/1000,	Train Loss: 0.4590,	Validation Loss: 0.1974,
# Epoch 208/1000,	Train Loss: 0.4749,	Validation Loss: 0.1974,
# Epoch 209/1000,	Train Loss: 0.3932,	Validation Loss: 0.1970,
# Epoch 210/1000,	Train Loss: 0.4517,	Validation Loss: 0.1967,
# Epoch 211/1000,	Train Loss: 0.4252,	Validation Loss: 0.1959,
# Epoch 212/1000,	Train Loss: 0.5033,	Validation Loss: 0.1958,
# Epoch 213/1000,	Train Loss: 0.4385,	Validation Loss: 0.1954,
# Epoch 214/1000,	Train Loss: 0.4497,	Validation Loss: 0.1952,
# Epoch 215/1000,	Train Loss: 0.4595,	Validation Loss: 0.1948,
# Epoch 216/1000,	Train Loss: 0.4163,	Validation Loss: 0.1945,
# Epoch 217/1000,	Train Loss: 0.3798,	Validation Loss: 0.1943,
# Epoch 218/1000,	Train Loss: 0.4920,	Validation Loss: 0.1940,
# Epoch 219/1000,	Train Loss: 0.4679,	Validation Loss: 0.1939,
# Epoch 220/1000,	Train Loss: 0.4290,	Validation Loss: 0.1937,
# Epoch 221/1000,	Train Loss: 0.4814,	Validation Loss: 0.1938,
# 	Early stopping patience counter: 1/40
# Epoch 222/1000,	Train Loss: 0.4365,	Validation Loss: 0.1936,
# Epoch 223/1000,	Train Loss: 0.4846,	Validation Loss: 0.1934,
# Epoch 224/1000,	Train Loss: 0.4623,	Validation Loss: 0.1938,
# 	Early stopping patience counter: 1/40
# Epoch 225/1000,	Train Loss: 0.4311,	Validation Loss: 0.1939,
# 	Early stopping patience counter: 2/40
# Epoch 226/1000,	Train Loss: 0.4370,	Validation Loss: 0.1938,
# 	Early stopping patience counter: 3/40
# Epoch 227/1000,	Train Loss: 0.4692,	Validation Loss: 0.1939,
# 	Early stopping patience counter: 4/40
# Epoch 228/1000,	Train Loss: 0.4232,	Validation Loss: 0.1943,
# 	Early stopping patience counter: 5/40
# Epoch 229/1000,	Train Loss: 0.5512,	Validation Loss: 0.1942,
# 	Early stopping patience counter: 6/40
# Epoch 230/1000,	Train Loss: 0.4508,	Validation Loss: 0.1943,
# 	Early stopping patience counter: 7/40
# Epoch 231/1000,	Train Loss: 0.4406,	Validation Loss: 0.1944,
# 	Early stopping patience counter: 8/40
# Epoch 232/1000,	Train Loss: 0.4744,	Validation Loss: 0.1951,
# 	Early stopping patience counter: 9/40
# Epoch 233/1000,	Train Loss: 0.4440,	Validation Loss: 0.1958,
# 	Early stopping patience counter: 10/40
# Epoch 234/1000,	Train Loss: 0.4025,	Validation Loss: 0.1960,
# 	Early stopping patience counter: 11/40
# Epoch 235/1000,	Train Loss: 0.3986,	Validation Loss: 0.1959,
# 	Early stopping patience counter: 12/40
# Epoch 236/1000,	Train Loss: 0.4133,	Validation Loss: 0.1957,
# 	Early stopping patience counter: 13/40
# Epoch 237/1000,	Train Loss: 0.4604,	Validation Loss: 0.1960,
# 	Early stopping patience counter: 14/40
# Epoch 238/1000,	Train Loss: 0.5138,	Validation Loss: 0.1968,
# 	Early stopping patience counter: 15/40
# Epoch 239/1000,	Train Loss: 0.5023,	Validation Loss: 0.1975,
# 	Early stopping patience counter: 16/40
# Epoch 240/1000,	Train Loss: 0.5259,	Validation Loss: 0.1991,
# 	Early stopping patience counter: 17/40
# Epoch 241/1000,	Train Loss: 0.4505,	Validation Loss: 0.2000,
# 	Early stopping patience counter: 18/40
# Epoch 242/1000,	Train Loss: 0.3619,	Validation Loss: 0.2002,
# 	Early stopping patience counter: 19/40
# Epoch 243/1000,	Train Loss: 0.4675,	Validation Loss: 0.2003,
# 	Early stopping patience counter: 20/40
# Epoch 244/1000,	Train Loss: 0.5106,	Validation Loss: 0.2007,
# 	Early stopping patience counter: 21/40
# Epoch 245/1000,	Train Loss: 0.4012,	Validation Loss: 0.2009,
# 	Early stopping patience counter: 22/40
# Epoch 246/1000,	Train Loss: 0.4435,	Validation Loss: 0.2008,
# 	Early stopping patience counter: 23/40
# Epoch 247/1000,	Train Loss: 0.4829,	Validation Loss: 0.2006,
# 	Early stopping patience counter: 24/40
# Epoch 248/1000,	Train Loss: 0.4524,	Validation Loss: 0.2011,
# 	Early stopping patience counter: 25/40
# Epoch 249/1000,	Train Loss: 0.4470,	Validation Loss: 0.2018,
# 	Early stopping patience counter: 26/40
# Epoch 250/1000,	Train Loss: 0.4719,	Validation Loss: 0.2025,
# 	Early stopping patience counter: 27/40
# Epoch 251/1000,	Train Loss: 0.3640,	Validation Loss: 0.2032,
# 	Early stopping patience counter: 28/40
# Epoch 252/1000,	Train Loss: 0.5134,	Validation Loss: 0.2039,
# 	Early stopping patience counter: 29/40
# Epoch 253/1000,	Train Loss: 0.4391,	Validation Loss: 0.2043,
# 	Early stopping patience counter: 30/40
# Epoch 254/1000,	Train Loss: 0.4382,	Validation Loss: 0.2048,
# 	Early stopping patience counter: 31/40
# Epoch 255/1000,	Train Loss: 0.5025,	Validation Loss: 0.2052,
# 	Early stopping patience counter: 32/40
# Epoch 256/1000,	Train Loss: 0.4531,	Validation Loss: 0.2055,
# 	Early stopping patience counter: 33/40
# Epoch 257/1000,	Train Loss: 0.3899,	Validation Loss: 0.2057,
# 	Early stopping patience counter: 34/40
# Epoch 258/1000,	Train Loss: 0.4841,	Validation Loss: 0.2061,
# 	Early stopping patience counter: 35/40
# Epoch 259/1000,	Train Loss: 0.4200,	Validation Loss: 0.2064,
# 	Early stopping patience counter: 36/40
# Epoch 260/1000,	Train Loss: 0.4376,	Validation Loss: 0.2065,
# 	Early stopping patience counter: 37/40
# Epoch 261/1000,	Train Loss: 0.3811,	Validation Loss: 0.2064,
# 	Early stopping patience counter: 38/40
# Epoch 262/1000,	Train Loss: 0.4070,	Validation Loss: 0.2063,
# 	Early stopping patience counter: 39/40
# Epoch 263/1000,	Train Loss: 0.3906,	Validation Loss: 0.2066,
# 	Early stopping patience counter: 40/40
# 	Early stopping triggered. Stopping training.
# ===================================
#  M O D E L   L O C A T I O N :
# nn_models\mlp_lasso_2025-05-13-23-35-52.pth
# ===================================
#
#
#
# ===================================
#  persons_in_overlap: 11
# ===================================

# %%
#output_path = rf'img/shap_summary_plot/model_lasso_dropout_{params["dropout_prob"]}'
#plot_shaps(model_lasso, features_lasso, output_path=output_path)

# %%
print_stats(model_lasso, val_loader_lasso, params)
# Out:
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [12, 8], 'dropout_prob': 0.5, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.0005, 'patience': 40, 'l2_lambda': 0}
# Validation Loss:	0.1934
# Mean vizier:		0.9569
# Mean non-vizier:	0.1136
# bottom_3_vizier:	0.9980
# top_3_non_vizier:	0.8918
# PiO Validation:		10

# %% [raw]
# BAD
# {'typ': 'lasso', 'batch_size': 128, 'hidden_size': [], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0540
# Mean vizier:		0.9975
# Mean non-vizier:	0.0373
# bottom_3_vizier:	0.9989
# top_3_non_vizier:	0.9173
# PiO Validation:		0
#
# BAD
# {'typ': 'lasso', 'batch_size': 128, 'hidden_size': [4], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0492
# Mean vizier:		0.9977
# Mean non-vizier:	0.0295
# bottom_3_vizier:	0.9971
# top_3_non_vizier:	0.8854
# PiO Validation:		0
#
# BAD
# {'typ': 'lasso', 'batch_size': 128, 'hidden_size': [4, 2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0492
# Mean vizier:		0.9976
# Mean non-vizier:	0.0294
# bottom_3_vizier:	0.9970
# top_3_non_vizier:	0.8781
# PiO Validation:		0
#
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [4], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0.2, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0883
# Mean vizier:		0.9986
# Mean non-vizier:	0.0634
# bottom_3_vizier:	0.9998
# top_3_non_vizier:	0.9704
# PiO Validation:		2
#
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [4, 2], 'activation_name': 'relu', 'optimizer_name': 'adam', 'dropout_prob': 0.2, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0834
# Mean vizier:		0.9828
# Mean non-vizier:	0.0478
# bottom_3_vizier:	0.9875
# top_3_non_vizier:	0.8996
# PiO Validation:		2
#
# GOOD!
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [4, 2], 'activation_name': 'leaky_relu', 'optimizer_name': 'adam', 'dropout_prob': 0.2, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0791
# Mean vizier:		0.9873
# Mean non-vizier:	0.0465
# bottom_3_vizier:	0.9900
# top_3_non_vizier:	0.9245
# PiO Validation:		3
#
# GOOD!
# {'typ': 'lasso', 'batch_size': 512, 'hidden_size': [4, 2], 'activation_name': 'leaky_relu', 'optimizer_name': 'adam', 'dropout_prob': 0.1, 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0609
# Mean vizier:		0.9910
# Mean non-vizier:	0.0324
# bottom_3_vizier:	0.9951
# top_3_non_vizier:	0.9415
# PiO Validation:		3

# %% [markdown]
# ### Ridge NN

# %%
params = {'typ': 'ridge',
          'batch_size': 512,
          'hidden_size': [12, 8],
          'dropout_prob': 0.5,
          'activation_name': 'relu',
          'optimizer_name': 'adam',
          'epochs': 1000,
          'learning_rate': 0.0005,
          'patience': 40,
          'l2_lambda': 0.07
         }
model_ridge, val_loader_ridge = train_nn(params)
# Out:
# ===================================
#  S T A R T I N G   M O D E L
# ===================================
#
# Defined BinaryClassifier with criterion=BCEWithLogitsLoss()
# Defined BinaryClassifier with optimizer=Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.0005
#     maximize: False
#     weight_decay: 0.07
# )
#
# ===================================
# MODEL ARCHITECTURE:
# BinaryClassifier(
#   (model): Sequential(
#     (0): Linear(in_features=36, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=12, out_features=8, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=8, out_features=1, bias=True)
#   )
# )
# ===================================
#
#
# ===================================
# NUMBER OF PARAMETERS: 557
# ===================================
#
# Epoch 1/1000,	Train Loss: 1.3538,	Validation Loss: 1.3357,
# Epoch 2/1000,	Train Loss: 1.3497,	Validation Loss: 1.3332,
# Epoch 3/1000,	Train Loss: 1.3550,	Validation Loss: 1.3303,
# Epoch 4/1000,	Train Loss: 1.3410,	Validation Loss: 1.3274,
# Epoch 5/1000,	Train Loss: 1.3529,	Validation Loss: 1.3251,
# Epoch 6/1000,	Train Loss: 1.3436,	Validation Loss: 1.3226,
# Epoch 7/1000,	Train Loss: 1.3476,	Validation Loss: 1.3201,
# Epoch 8/1000,	Train Loss: 1.3473,	Validation Loss: 1.3175,
# Epoch 9/1000,	Train Loss: 1.3247,	Validation Loss: 1.3143,
# Epoch 10/1000,	Train Loss: 1.3194,	Validation Loss: 1.3107,
# Epoch 11/1000,	Train Loss: 1.3290,	Validation Loss: 1.3071,
# Epoch 12/1000,	Train Loss: 1.3407,	Validation Loss: 1.3031,
# Epoch 13/1000,	Train Loss: 1.3419,	Validation Loss: 1.3000,
# Epoch 14/1000,	Train Loss: 1.3318,	Validation Loss: 1.2969,
# Epoch 15/1000,	Train Loss: 1.3243,	Validation Loss: 1.2939,
# Epoch 16/1000,	Train Loss: 1.3210,	Validation Loss: 1.2907,
# Epoch 17/1000,	Train Loss: 1.3249,	Validation Loss: 1.2878,
# Epoch 18/1000,	Train Loss: 1.3085,	Validation Loss: 1.2839,
# Epoch 19/1000,	Train Loss: 1.2996,	Validation Loss: 1.2787,
# Epoch 20/1000,	Train Loss: 1.3107,	Validation Loss: 1.2737,
# Epoch 21/1000,	Train Loss: 1.3010,	Validation Loss: 1.2683,
# Epoch 22/1000,	Train Loss: 1.2992,	Validation Loss: 1.2635,
# Epoch 23/1000,	Train Loss: 1.2878,	Validation Loss: 1.2576,
# Epoch 24/1000,	Train Loss: 1.3081,	Validation Loss: 1.2518,
# Epoch 25/1000,	Train Loss: 1.2947,	Validation Loss: 1.2463,
# Epoch 26/1000,	Train Loss: 1.3112,	Validation Loss: 1.2409,
# Epoch 27/1000,	Train Loss: 1.2958,	Validation Loss: 1.2360,
# Epoch 28/1000,	Train Loss: 1.2758,	Validation Loss: 1.2307,
# Epoch 29/1000,	Train Loss: 1.2944,	Validation Loss: 1.2257,
# Epoch 30/1000,	Train Loss: 1.2765,	Validation Loss: 1.2204,
# Epoch 31/1000,	Train Loss: 1.2645,	Validation Loss: 1.2143,
# Epoch 32/1000,	Train Loss: 1.2223,	Validation Loss: 1.2071,
# Epoch 33/1000,	Train Loss: 1.2424,	Validation Loss: 1.1983,
# Epoch 34/1000,	Train Loss: 1.2544,	Validation Loss: 1.1902,
# Epoch 35/1000,	Train Loss: 1.2577,	Validation Loss: 1.1821,
# Epoch 36/1000,	Train Loss: 1.1993,	Validation Loss: 1.1739,
# Epoch 37/1000,	Train Loss: 1.2158,	Validation Loss: 1.1648,
# Epoch 38/1000,	Train Loss: 1.2477,	Validation Loss: 1.1553,
# Epoch 39/1000,	Train Loss: 1.1778,	Validation Loss: 1.1453,
# Epoch 40/1000,	Train Loss: 1.2283,	Validation Loss: 1.1352,
# Epoch 41/1000,	Train Loss: 1.1872,	Validation Loss: 1.1257,
# Epoch 42/1000,	Train Loss: 1.1596,	Validation Loss: 1.1157,
# Epoch 43/1000,	Train Loss: 1.1966,	Validation Loss: 1.1064,
# Epoch 44/1000,	Train Loss: 1.1857,	Validation Loss: 1.0972,
# Epoch 45/1000,	Train Loss: 1.1584,	Validation Loss: 1.0875,
# Epoch 46/1000,	Train Loss: 1.1974,	Validation Loss: 1.0779,
# Epoch 47/1000,	Train Loss: 1.1582,	Validation Loss: 1.0696,
# Epoch 48/1000,	Train Loss: 1.1079,	Validation Loss: 1.0598,
# Epoch 49/1000,	Train Loss: 1.1301,	Validation Loss: 1.0505,
# Epoch 50/1000,	Train Loss: 1.1185,	Validation Loss: 1.0410,
# Epoch 51/1000,	Train Loss: 1.1446,	Validation Loss: 1.0317,
# Epoch 52/1000,	Train Loss: 1.1042,	Validation Loss: 1.0229,
# Epoch 53/1000,	Train Loss: 1.1194,	Validation Loss: 1.0139,
# Epoch 54/1000,	Train Loss: 1.1054,	Validation Loss: 1.0037,
# Epoch 55/1000,	Train Loss: 1.1214,	Validation Loss: 0.9935,
# Epoch 56/1000,	Train Loss: 1.0822,	Validation Loss: 0.9841,
# Epoch 57/1000,	Train Loss: 1.0766,	Validation Loss: 0.9747,
# Epoch 58/1000,	Train Loss: 1.1102,	Validation Loss: 0.9652,
# Epoch 59/1000,	Train Loss: 1.0909,	Validation Loss: 0.9563,
# Epoch 60/1000,	Train Loss: 1.0491,	Validation Loss: 0.9481,
# Epoch 61/1000,	Train Loss: 1.0779,	Validation Loss: 0.9401,
# Epoch 62/1000,	Train Loss: 1.0990,	Validation Loss: 0.9336,
# Epoch 63/1000,	Train Loss: 1.0681,	Validation Loss: 0.9273,
# Epoch 64/1000,	Train Loss: 1.0672,	Validation Loss: 0.9197,
# Epoch 65/1000,	Train Loss: 1.0304,	Validation Loss: 0.9112,
# Epoch 66/1000,	Train Loss: 1.0521,	Validation Loss: 0.9019,
# Epoch 67/1000,	Train Loss: 1.0549,	Validation Loss: 0.8926,
# Epoch 68/1000,	Train Loss: 1.0502,	Validation Loss: 0.8845,
# Epoch 69/1000,	Train Loss: 1.0294,	Validation Loss: 0.8767,
# Epoch 70/1000,	Train Loss: 0.9902,	Validation Loss: 0.8682,
# Epoch 71/1000,	Train Loss: 0.9872,	Validation Loss: 0.8591,
# Epoch 72/1000,	Train Loss: 1.0178,	Validation Loss: 0.8510,
# Epoch 73/1000,	Train Loss: 1.0317,	Validation Loss: 0.8435,
# Epoch 74/1000,	Train Loss: 1.0423,	Validation Loss: 0.8360,
# Epoch 75/1000,	Train Loss: 0.9853,	Validation Loss: 0.8281,
# Epoch 76/1000,	Train Loss: 0.9592,	Validation Loss: 0.8195,
# Epoch 77/1000,	Train Loss: 0.9855,	Validation Loss: 0.8117,
# Epoch 78/1000,	Train Loss: 1.0173,	Validation Loss: 0.8035,
# Epoch 79/1000,	Train Loss: 0.8975,	Validation Loss: 0.7963,
# Epoch 80/1000,	Train Loss: 0.9320,	Validation Loss: 0.7885,
# Epoch 81/1000,	Train Loss: 0.9752,	Validation Loss: 0.7806,
# Epoch 82/1000,	Train Loss: 0.9623,	Validation Loss: 0.7722,
# Epoch 83/1000,	Train Loss: 0.9792,	Validation Loss: 0.7657,
# Epoch 84/1000,	Train Loss: 0.9190,	Validation Loss: 0.7587,
# Epoch 85/1000,	Train Loss: 0.9760,	Validation Loss: 0.7523,
# Epoch 86/1000,	Train Loss: 0.9350,	Validation Loss: 0.7460,
# Epoch 87/1000,	Train Loss: 0.9742,	Validation Loss: 0.7387,
# Epoch 88/1000,	Train Loss: 0.9074,	Validation Loss: 0.7314,
# Epoch 89/1000,	Train Loss: 0.9761,	Validation Loss: 0.7242,
# Epoch 90/1000,	Train Loss: 0.8958,	Validation Loss: 0.7160,
# Epoch 91/1000,	Train Loss: 0.8778,	Validation Loss: 0.7079,
# Epoch 92/1000,	Train Loss: 0.9547,	Validation Loss: 0.7006,
# Epoch 93/1000,	Train Loss: 0.8473,	Validation Loss: 0.6933,
# Epoch 94/1000,	Train Loss: 0.9113,	Validation Loss: 0.6866,
# Epoch 95/1000,	Train Loss: 0.8441,	Validation Loss: 0.6800,
# Epoch 96/1000,	Train Loss: 0.8685,	Validation Loss: 0.6726,
# Epoch 97/1000,	Train Loss: 0.8725,	Validation Loss: 0.6656,
# Epoch 98/1000,	Train Loss: 0.7967,	Validation Loss: 0.6581,
# Epoch 99/1000,	Train Loss: 0.8337,	Validation Loss: 0.6514,
# Epoch 100/1000,	Train Loss: 0.8953,	Validation Loss: 0.6454,
# Epoch 101/1000,	Train Loss: 0.8410,	Validation Loss: 0.6387,
# Epoch 102/1000,	Train Loss: 0.8494,	Validation Loss: 0.6309,
# Epoch 103/1000,	Train Loss: 0.8341,	Validation Loss: 0.6240,
# Epoch 104/1000,	Train Loss: 0.7742,	Validation Loss: 0.6173,
# Epoch 105/1000,	Train Loss: 0.8370,	Validation Loss: 0.6110,
# Epoch 106/1000,	Train Loss: 0.7904,	Validation Loss: 0.6043,
# Epoch 107/1000,	Train Loss: 0.8064,	Validation Loss: 0.5957,
# Epoch 108/1000,	Train Loss: 0.8510,	Validation Loss: 0.5877,
# Epoch 109/1000,	Train Loss: 0.7943,	Validation Loss: 0.5810,
# Epoch 110/1000,	Train Loss: 0.8060,	Validation Loss: 0.5749,
# Epoch 111/1000,	Train Loss: 0.8516,	Validation Loss: 0.5689,
# Epoch 112/1000,	Train Loss: 0.7757,	Validation Loss: 0.5621,
# Epoch 113/1000,	Train Loss: 0.7159,	Validation Loss: 0.5553,
# Epoch 114/1000,	Train Loss: 0.7840,	Validation Loss: 0.5491,
# Epoch 115/1000,	Train Loss: 0.7607,	Validation Loss: 0.5432,
# Epoch 116/1000,	Train Loss: 0.7802,	Validation Loss: 0.5385,
# Epoch 117/1000,	Train Loss: 0.7805,	Validation Loss: 0.5343,
# Epoch 118/1000,	Train Loss: 0.7397,	Validation Loss: 0.5299,
# Epoch 119/1000,	Train Loss: 0.7582,	Validation Loss: 0.5253,
# Epoch 120/1000,	Train Loss: 0.7126,	Validation Loss: 0.5201,
# Epoch 121/1000,	Train Loss: 0.6962,	Validation Loss: 0.5146,
# Epoch 122/1000,	Train Loss: 0.7000,	Validation Loss: 0.5091,
# Epoch 123/1000,	Train Loss: 0.7406,	Validation Loss: 0.5033,
# Epoch 124/1000,	Train Loss: 0.6900,	Validation Loss: 0.4974,
# Epoch 125/1000,	Train Loss: 0.7092,	Validation Loss: 0.4928,
# Epoch 126/1000,	Train Loss: 0.6424,	Validation Loss: 0.4882,
# Epoch 127/1000,	Train Loss: 0.6809,	Validation Loss: 0.4838,
# Epoch 128/1000,	Train Loss: 0.6681,	Validation Loss: 0.4794,
# Epoch 129/1000,	Train Loss: 0.6918,	Validation Loss: 0.4747,
# Epoch 130/1000,	Train Loss: 0.7307,	Validation Loss: 0.4700,
# Epoch 131/1000,	Train Loss: 0.7339,	Validation Loss: 0.4654,
# Epoch 132/1000,	Train Loss: 0.6645,	Validation Loss: 0.4618,
# Epoch 133/1000,	Train Loss: 0.6815,	Validation Loss: 0.4576,
# Epoch 134/1000,	Train Loss: 0.7198,	Validation Loss: 0.4530,
# Epoch 135/1000,	Train Loss: 0.6001,	Validation Loss: 0.4488,
# Epoch 136/1000,	Train Loss: 0.6656,	Validation Loss: 0.4443,
# Epoch 137/1000,	Train Loss: 0.6139,	Validation Loss: 0.4402,
# Epoch 138/1000,	Train Loss: 0.6198,	Validation Loss: 0.4361,
# Epoch 139/1000,	Train Loss: 0.6166,	Validation Loss: 0.4327,
# Epoch 140/1000,	Train Loss: 0.6791,	Validation Loss: 0.4310,
# Epoch 141/1000,	Train Loss: 0.6941,	Validation Loss: 0.4290,
# Epoch 142/1000,	Train Loss: 0.6033,	Validation Loss: 0.4262,
# Epoch 143/1000,	Train Loss: 0.6907,	Validation Loss: 0.4247,
# Epoch 144/1000,	Train Loss: 0.6363,	Validation Loss: 0.4228,
# Epoch 145/1000,	Train Loss: 0.6637,	Validation Loss: 0.4196,
# Epoch 146/1000,	Train Loss: 0.6706,	Validation Loss: 0.4173,
# Epoch 147/1000,	Train Loss: 0.6537,	Validation Loss: 0.4152,
# Epoch 148/1000,	Train Loss: 0.6432,	Validation Loss: 0.4123,
# Epoch 149/1000,	Train Loss: 0.6766,	Validation Loss: 0.4101,
# Epoch 150/1000,	Train Loss: 0.6365,	Validation Loss: 0.4098,
# Epoch 151/1000,	Train Loss: 0.6121,	Validation Loss: 0.4081,
# Epoch 152/1000,	Train Loss: 0.6541,	Validation Loss: 0.4054,
# Epoch 153/1000,	Train Loss: 0.6022,	Validation Loss: 0.4024,
# Epoch 154/1000,	Train Loss: 0.5603,	Validation Loss: 0.3995,
# Epoch 155/1000,	Train Loss: 0.5996,	Validation Loss: 0.3963,
# Epoch 156/1000,	Train Loss: 0.6013,	Validation Loss: 0.3932,
# Epoch 157/1000,	Train Loss: 0.5707,	Validation Loss: 0.3898,
# Epoch 158/1000,	Train Loss: 0.6723,	Validation Loss: 0.3874,
# Epoch 159/1000,	Train Loss: 0.6492,	Validation Loss: 0.3859,
# Epoch 160/1000,	Train Loss: 0.6208,	Validation Loss: 0.3848,
# Epoch 161/1000,	Train Loss: 0.6173,	Validation Loss: 0.3836,
# Epoch 162/1000,	Train Loss: 0.5844,	Validation Loss: 0.3826,
# Epoch 163/1000,	Train Loss: 0.6086,	Validation Loss: 0.3809,
# Epoch 164/1000,	Train Loss: 0.6209,	Validation Loss: 0.3790,
# Epoch 165/1000,	Train Loss: 0.6911,	Validation Loss: 0.3784,
# Epoch 166/1000,	Train Loss: 0.5899,	Validation Loss: 0.3774,
# Epoch 167/1000,	Train Loss: 0.5367,	Validation Loss: 0.3767,
# Epoch 168/1000,	Train Loss: 0.5923,	Validation Loss: 0.3751,
# Epoch 169/1000,	Train Loss: 0.5589,	Validation Loss: 0.3736,
# Epoch 170/1000,	Train Loss: 0.5516,	Validation Loss: 0.3710,
# Epoch 171/1000,	Train Loss: 0.5941,	Validation Loss: 0.3691,
# Epoch 172/1000,	Train Loss: 0.5789,	Validation Loss: 0.3674,
# Epoch 173/1000,	Train Loss: 0.6377,	Validation Loss: 0.3667,
# Epoch 174/1000,	Train Loss: 0.5563,	Validation Loss: 0.3656,
# Epoch 175/1000,	Train Loss: 0.6191,	Validation Loss: 0.3644,
# Epoch 176/1000,	Train Loss: 0.5720,	Validation Loss: 0.3630,
# Epoch 177/1000,	Train Loss: 0.6129,	Validation Loss: 0.3619,
# Epoch 178/1000,	Train Loss: 0.5894,	Validation Loss: 0.3619,
# Epoch 179/1000,	Train Loss: 0.6133,	Validation Loss: 0.3610,
# Epoch 180/1000,	Train Loss: 0.5981,	Validation Loss: 0.3608,
# Epoch 181/1000,	Train Loss: 0.6757,	Validation Loss: 0.3602,
# Epoch 182/1000,	Train Loss: 0.6024,	Validation Loss: 0.3601,
# Epoch 183/1000,	Train Loss: 0.5687,	Validation Loss: 0.3598,
# Epoch 184/1000,	Train Loss: 0.6679,	Validation Loss: 0.3588,
# Epoch 185/1000,	Train Loss: 0.6193,	Validation Loss: 0.3581,
# Epoch 186/1000,	Train Loss: 0.5486,	Validation Loss: 0.3573,
# Epoch 187/1000,	Train Loss: 0.5184,	Validation Loss: 0.3563,
# Epoch 188/1000,	Train Loss: 0.5486,	Validation Loss: 0.3550,
# Epoch 189/1000,	Train Loss: 0.5773,	Validation Loss: 0.3539,
# Epoch 190/1000,	Train Loss: 0.6511,	Validation Loss: 0.3532,
# Epoch 191/1000,	Train Loss: 0.6702,	Validation Loss: 0.3522,
# Epoch 192/1000,	Train Loss: 0.5693,	Validation Loss: 0.3511,
# Epoch 193/1000,	Train Loss: 0.4930,	Validation Loss: 0.3496,
# Epoch 194/1000,	Train Loss: 0.5829,	Validation Loss: 0.3482,
# Epoch 195/1000,	Train Loss: 0.6168,	Validation Loss: 0.3469,
# Epoch 196/1000,	Train Loss: 0.5750,	Validation Loss: 0.3464,
# Epoch 197/1000,	Train Loss: 0.6271,	Validation Loss: 0.3472,
# 	Early stopping patience counter: 1/40
# Epoch 198/1000,	Train Loss: 0.5075,	Validation Loss: 0.3470,
# 	Early stopping patience counter: 2/40
# Epoch 199/1000,	Train Loss: 0.5793,	Validation Loss: 0.3462,
# Epoch 200/1000,	Train Loss: 0.6278,	Validation Loss: 0.3462,
# Epoch 201/1000,	Train Loss: 0.5159,	Validation Loss: 0.3459,
# Epoch 202/1000,	Train Loss: 0.6291,	Validation Loss: 0.3453,
# Epoch 203/1000,	Train Loss: 0.5664,	Validation Loss: 0.3451,
# Epoch 204/1000,	Train Loss: 0.5657,	Validation Loss: 0.3450,
# Epoch 205/1000,	Train Loss: 0.5595,	Validation Loss: 0.3448,
# Epoch 206/1000,	Train Loss: 0.4604,	Validation Loss: 0.3443,
# Epoch 207/1000,	Train Loss: 0.5718,	Validation Loss: 0.3437,
# Epoch 208/1000,	Train Loss: 0.5445,	Validation Loss: 0.3434,
# Epoch 209/1000,	Train Loss: 0.5300,	Validation Loss: 0.3425,
# Epoch 210/1000,	Train Loss: 0.4863,	Validation Loss: 0.3412,
# Epoch 211/1000,	Train Loss: 0.6023,	Validation Loss: 0.3400,
# Epoch 212/1000,	Train Loss: 0.5373,	Validation Loss: 0.3388,
# Epoch 213/1000,	Train Loss: 0.5778,	Validation Loss: 0.3373,
# Epoch 214/1000,	Train Loss: 0.5584,	Validation Loss: 0.3366,
# Epoch 215/1000,	Train Loss: 0.5396,	Validation Loss: 0.3364,
# Epoch 216/1000,	Train Loss: 0.5976,	Validation Loss: 0.3367,
# 	Early stopping patience counter: 1/40
# Epoch 217/1000,	Train Loss: 0.6947,	Validation Loss: 0.3368,
# 	Early stopping patience counter: 2/40
# Epoch 218/1000,	Train Loss: 0.5648,	Validation Loss: 0.3371,
# 	Early stopping patience counter: 3/40
# Epoch 219/1000,	Train Loss: 0.6046,	Validation Loss: 0.3381,
# 	Early stopping patience counter: 4/40
# Epoch 220/1000,	Train Loss: 0.5443,	Validation Loss: 0.3385,
# 	Early stopping patience counter: 5/40
# Epoch 221/1000,	Train Loss: 0.5267,	Validation Loss: 0.3381,
# 	Early stopping patience counter: 6/40
# Epoch 222/1000,	Train Loss: 0.5818,	Validation Loss: 0.3374,
# 	Early stopping patience counter: 7/40
# Epoch 223/1000,	Train Loss: 0.5715,	Validation Loss: 0.3361,
# Epoch 224/1000,	Train Loss: 0.5807,	Validation Loss: 0.3341,
# Epoch 225/1000,	Train Loss: 0.5524,	Validation Loss: 0.3330,
# Epoch 226/1000,	Train Loss: 0.5490,	Validation Loss: 0.3325,
# Epoch 227/1000,	Train Loss: 0.5674,	Validation Loss: 0.3322,
# Epoch 228/1000,	Train Loss: 0.5266,	Validation Loss: 0.3324,
# 	Early stopping patience counter: 1/40
# Epoch 229/1000,	Train Loss: 0.5444,	Validation Loss: 0.3326,
# 	Early stopping patience counter: 2/40
# Epoch 230/1000,	Train Loss: 0.5499,	Validation Loss: 0.3326,
# 	Early stopping patience counter: 3/40
# Epoch 231/1000,	Train Loss: 0.5087,	Validation Loss: 0.3326,
# 	Early stopping patience counter: 4/40
# Epoch 232/1000,	Train Loss: 0.6243,	Validation Loss: 0.3329,
# 	Early stopping patience counter: 5/40
# Epoch 233/1000,	Train Loss: 0.5794,	Validation Loss: 0.3331,
# 	Early stopping patience counter: 6/40
# Epoch 234/1000,	Train Loss: 0.5582,	Validation Loss: 0.3327,
# 	Early stopping patience counter: 7/40
# Epoch 235/1000,	Train Loss: 0.5961,	Validation Loss: 0.3320,
# Epoch 236/1000,	Train Loss: 0.5847,	Validation Loss: 0.3312,
# Epoch 237/1000,	Train Loss: 0.5424,	Validation Loss: 0.3307,
# Epoch 238/1000,	Train Loss: 0.6408,	Validation Loss: 0.3302,
# Epoch 239/1000,	Train Loss: 0.4856,	Validation Loss: 0.3298,
# Epoch 240/1000,	Train Loss: 0.5814,	Validation Loss: 0.3295,
# Epoch 241/1000,	Train Loss: 0.5960,	Validation Loss: 0.3293,
# Epoch 242/1000,	Train Loss: 0.5376,	Validation Loss: 0.3289,
# Epoch 243/1000,	Train Loss: 0.5511,	Validation Loss: 0.3282,
# Epoch 244/1000,	Train Loss: 0.5722,	Validation Loss: 0.3276,
# Epoch 245/1000,	Train Loss: 0.5411,	Validation Loss: 0.3268,
# Epoch 246/1000,	Train Loss: 0.5268,	Validation Loss: 0.3254,
# Epoch 247/1000,	Train Loss: 0.5161,	Validation Loss: 0.3254,
# Epoch 248/1000,	Train Loss: 0.5411,	Validation Loss: 0.3247,
# Epoch 249/1000,	Train Loss: 0.5931,	Validation Loss: 0.3239,
# Epoch 250/1000,	Train Loss: 0.5562,	Validation Loss: 0.3237,
# Epoch 251/1000,	Train Loss: 0.5655,	Validation Loss: 0.3237,
# Epoch 252/1000,	Train Loss: 0.5561,	Validation Loss: 0.3235,
# Epoch 253/1000,	Train Loss: 0.5254,	Validation Loss: 0.3226,
# Epoch 254/1000,	Train Loss: 0.5540,	Validation Loss: 0.3223,
# Epoch 255/1000,	Train Loss: 0.5289,	Validation Loss: 0.3223,
# 	Early stopping patience counter: 1/40
# Epoch 256/1000,	Train Loss: 0.5776,	Validation Loss: 0.3228,
# 	Early stopping patience counter: 2/40
# Epoch 257/1000,	Train Loss: 0.6465,	Validation Loss: 0.3233,
# 	Early stopping patience counter: 3/40
# Epoch 258/1000,	Train Loss: 0.5271,	Validation Loss: 0.3236,
# 	Early stopping patience counter: 4/40
# Epoch 259/1000,	Train Loss: 0.5114,	Validation Loss: 0.3231,
# 	Early stopping patience counter: 5/40
# Epoch 260/1000,	Train Loss: 0.5574,	Validation Loss: 0.3226,
# 	Early stopping patience counter: 6/40
# Epoch 261/1000,	Train Loss: 0.5629,	Validation Loss: 0.3224,
# 	Early stopping patience counter: 7/40
# Epoch 262/1000,	Train Loss: 0.5443,	Validation Loss: 0.3229,
# 	Early stopping patience counter: 8/40
# Epoch 263/1000,	Train Loss: 0.5153,	Validation Loss: 0.3221,
# Epoch 264/1000,	Train Loss: 0.5041,	Validation Loss: 0.3211,
# Epoch 265/1000,	Train Loss: 0.4864,	Validation Loss: 0.3199,
# Epoch 266/1000,	Train Loss: 0.5042,	Validation Loss: 0.3191,
# Epoch 267/1000,	Train Loss: 0.4858,	Validation Loss: 0.3179,
# Epoch 268/1000,	Train Loss: 0.5171,	Validation Loss: 0.3169,
# Epoch 269/1000,	Train Loss: 0.5046,	Validation Loss: 0.3160,
# Epoch 270/1000,	Train Loss: 0.5379,	Validation Loss: 0.3159,
# Epoch 271/1000,	Train Loss: 0.5669,	Validation Loss: 0.3179,
# 	Early stopping patience counter: 1/40
# Epoch 272/1000,	Train Loss: 0.5150,	Validation Loss: 0.3193,
# 	Early stopping patience counter: 2/40
# Epoch 273/1000,	Train Loss: 0.5594,	Validation Loss: 0.3199,
# 	Early stopping patience counter: 3/40
# Epoch 274/1000,	Train Loss: 0.5786,	Validation Loss: 0.3200,
# 	Early stopping patience counter: 4/40
# Epoch 275/1000,	Train Loss: 0.5927,	Validation Loss: 0.3202,
# 	Early stopping patience counter: 5/40
# Epoch 276/1000,	Train Loss: 0.6225,	Validation Loss: 0.3203,
# 	Early stopping patience counter: 6/40
# Epoch 277/1000,	Train Loss: 0.6097,	Validation Loss: 0.3213,
# 	Early stopping patience counter: 7/40
# Epoch 278/1000,	Train Loss: 0.5200,	Validation Loss: 0.3215,
# 	Early stopping patience counter: 8/40
# Epoch 279/1000,	Train Loss: 0.5362,	Validation Loss: 0.3210,
# 	Early stopping patience counter: 9/40
# Epoch 280/1000,	Train Loss: 0.4986,	Validation Loss: 0.3204,
# 	Early stopping patience counter: 10/40
# Epoch 281/1000,	Train Loss: 0.5522,	Validation Loss: 0.3198,
# 	Early stopping patience counter: 11/40
# Epoch 282/1000,	Train Loss: 0.5011,	Validation Loss: 0.3191,
# 	Early stopping patience counter: 12/40
# Epoch 283/1000,	Train Loss: 0.5446,	Validation Loss: 0.3192,
# 	Early stopping patience counter: 13/40
# Epoch 284/1000,	Train Loss: 0.5473,	Validation Loss: 0.3191,
# 	Early stopping patience counter: 14/40
# Epoch 285/1000,	Train Loss: 0.4932,	Validation Loss: 0.3190,
# 	Early stopping patience counter: 15/40
# Epoch 286/1000,	Train Loss: 0.5161,	Validation Loss: 0.3187,
# 	Early stopping patience counter: 16/40
# Epoch 287/1000,	Train Loss: 0.5758,	Validation Loss: 0.3187,
# 	Early stopping patience counter: 17/40
# Epoch 288/1000,	Train Loss: 0.5142,	Validation Loss: 0.3197,
# 	Early stopping patience counter: 18/40
# Epoch 289/1000,	Train Loss: 0.5201,	Validation Loss: 0.3200,
# 	Early stopping patience counter: 19/40
# Epoch 290/1000,	Train Loss: 0.5688,	Validation Loss: 0.3205,
# 	Early stopping patience counter: 20/40
# Epoch 291/1000,	Train Loss: 0.5306,	Validation Loss: 0.3203,
# 	Early stopping patience counter: 21/40
# Epoch 292/1000,	Train Loss: 0.5594,	Validation Loss: 0.3201,
# 	Early stopping patience counter: 22/40
# Epoch 293/1000,	Train Loss: 0.6224,	Validation Loss: 0.3200,
# 	Early stopping patience counter: 23/40
# Epoch 294/1000,	Train Loss: 0.5039,	Validation Loss: 0.3199,
# 	Early stopping patience counter: 24/40
# Epoch 295/1000,	Train Loss: 0.4410,	Validation Loss: 0.3193,
# 	Early stopping patience counter: 25/40
# Epoch 296/1000,	Train Loss: 0.5435,	Validation Loss: 0.3189,
# 	Early stopping patience counter: 26/40
# Epoch 297/1000,	Train Loss: 0.5626,	Validation Loss: 0.3184,
# 	Early stopping patience counter: 27/40
# Epoch 298/1000,	Train Loss: 0.5429,	Validation Loss: 0.3183,
# 	Early stopping patience counter: 28/40
# Epoch 299/1000,	Train Loss: 0.5060,	Validation Loss: 0.3179,
# 	Early stopping patience counter: 29/40
# Epoch 300/1000,	Train Loss: 0.5281,	Validation Loss: 0.3168,
# 	Early stopping patience counter: 30/40
# Epoch 301/1000,	Train Loss: 0.5739,	Validation Loss: 0.3158,
# Epoch 302/1000,	Train Loss: 0.5172,	Validation Loss: 0.3159,
# 	Early stopping patience counter: 1/40
# Epoch 303/1000,	Train Loss: 0.4462,	Validation Loss: 0.3157,
# Epoch 304/1000,	Train Loss: 0.5018,	Validation Loss: 0.3157,
# Epoch 305/1000,	Train Loss: 0.5323,	Validation Loss: 0.3158,
# 	Early stopping patience counter: 1/40
# Epoch 306/1000,	Train Loss: 0.5007,	Validation Loss: 0.3157,
# Epoch 307/1000,	Train Loss: 0.4824,	Validation Loss: 0.3157,
# Epoch 308/1000,	Train Loss: 0.5762,	Validation Loss: 0.3161,
# 	Early stopping patience counter: 1/40
# Epoch 309/1000,	Train Loss: 0.5798,	Validation Loss: 0.3157,
# 	Early stopping patience counter: 2/40
# Epoch 310/1000,	Train Loss: 0.5229,	Validation Loss: 0.3156,
# Epoch 311/1000,	Train Loss: 0.4739,	Validation Loss: 0.3152,
# Epoch 312/1000,	Train Loss: 0.5151,	Validation Loss: 0.3146,
# Epoch 313/1000,	Train Loss: 0.5364,	Validation Loss: 0.3137,
# Epoch 314/1000,	Train Loss: 0.4637,	Validation Loss: 0.3123,
# Epoch 315/1000,	Train Loss: 0.4959,	Validation Loss: 0.3108,
# Epoch 316/1000,	Train Loss: 0.5122,	Validation Loss: 0.3100,
# Epoch 317/1000,	Train Loss: 0.5488,	Validation Loss: 0.3100,
# Epoch 318/1000,	Train Loss: 0.5876,	Validation Loss: 0.3092,
# Epoch 319/1000,	Train Loss: 0.5601,	Validation Loss: 0.3091,
# Epoch 320/1000,	Train Loss: 0.5511,	Validation Loss: 0.3097,
# 	Early stopping patience counter: 1/40
# Epoch 321/1000,	Train Loss: 0.5280,	Validation Loss: 0.3108,
# 	Early stopping patience counter: 2/40
# Epoch 322/1000,	Train Loss: 0.5322,	Validation Loss: 0.3117,
# 	Early stopping patience counter: 3/40
# Epoch 323/1000,	Train Loss: 0.5676,	Validation Loss: 0.3120,
# 	Early stopping patience counter: 4/40
# Epoch 324/1000,	Train Loss: 0.5529,	Validation Loss: 0.3117,
# 	Early stopping patience counter: 5/40
# Epoch 325/1000,	Train Loss: 0.6212,	Validation Loss: 0.3128,
# 	Early stopping patience counter: 6/40
# Epoch 326/1000,	Train Loss: 0.5405,	Validation Loss: 0.3143,
# 	Early stopping patience counter: 7/40
# Epoch 327/1000,	Train Loss: 0.5594,	Validation Loss: 0.3146,
# 	Early stopping patience counter: 8/40
# Epoch 328/1000,	Train Loss: 0.5420,	Validation Loss: 0.3146,
# 	Early stopping patience counter: 9/40
# Epoch 329/1000,	Train Loss: 0.5424,	Validation Loss: 0.3147,
# 	Early stopping patience counter: 10/40
# Epoch 330/1000,	Train Loss: 0.5332,	Validation Loss: 0.3149,
# 	Early stopping patience counter: 11/40
# Epoch 331/1000,	Train Loss: 0.5634,	Validation Loss: 0.3154,
# 	Early stopping patience counter: 12/40
# Epoch 332/1000,	Train Loss: 0.5103,	Validation Loss: 0.3149,
# 	Early stopping patience counter: 13/40
# Epoch 333/1000,	Train Loss: 0.6130,	Validation Loss: 0.3142,
# 	Early stopping patience counter: 14/40
# Epoch 334/1000,	Train Loss: 0.5132,	Validation Loss: 0.3137,
# 	Early stopping patience counter: 15/40
# Epoch 335/1000,	Train Loss: 0.5186,	Validation Loss: 0.3132,
# 	Early stopping patience counter: 16/40
# Epoch 336/1000,	Train Loss: 0.5882,	Validation Loss: 0.3135,
# 	Early stopping patience counter: 17/40
# Epoch 337/1000,	Train Loss: 0.5151,	Validation Loss: 0.3136,
# 	Early stopping patience counter: 18/40
# Epoch 338/1000,	Train Loss: 0.4607,	Validation Loss: 0.3134,
# 	Early stopping patience counter: 19/40
# Epoch 339/1000,	Train Loss: 0.5448,	Validation Loss: 0.3133,
# 	Early stopping patience counter: 20/40
# Epoch 340/1000,	Train Loss: 0.5416,	Validation Loss: 0.3132,
# 	Early stopping patience counter: 21/40
# Epoch 341/1000,	Train Loss: 0.5309,	Validation Loss: 0.3134,
# 	Early stopping patience counter: 22/40
# Epoch 342/1000,	Train Loss: 0.5717,	Validation Loss: 0.3138,
# 	Early stopping patience counter: 23/40
# Epoch 343/1000,	Train Loss: 0.5848,	Validation Loss: 0.3147,
# 	Early stopping patience counter: 24/40
# Epoch 344/1000,	Train Loss: 0.4858,	Validation Loss: 0.3151,
# 	Early stopping patience counter: 25/40
# Epoch 345/1000,	Train Loss: 0.5421,	Validation Loss: 0.3150,
# 	Early stopping patience counter: 26/40
# Epoch 346/1000,	Train Loss: 0.4838,	Validation Loss: 0.3142,
# 	Early stopping patience counter: 27/40
# Epoch 347/1000,	Train Loss: 0.5292,	Validation Loss: 0.3134,
# 	Early stopping patience counter: 28/40
# Epoch 348/1000,	Train Loss: 0.6126,	Validation Loss: 0.3130,
# 	Early stopping patience counter: 29/40
# Epoch 349/1000,	Train Loss: 0.4662,	Validation Loss: 0.3123,
# 	Early stopping patience counter: 30/40
# Epoch 350/1000,	Train Loss: 0.5586,	Validation Loss: 0.3123,
# 	Early stopping patience counter: 31/40
# Epoch 351/1000,	Train Loss: 0.5311,	Validation Loss: 0.3125,
# 	Early stopping patience counter: 32/40
# Epoch 352/1000,	Train Loss: 0.5135,	Validation Loss: 0.3126,
# 	Early stopping patience counter: 33/40
# Epoch 353/1000,	Train Loss: 0.5687,	Validation Loss: 0.3127,
# 	Early stopping patience counter: 34/40
# Epoch 354/1000,	Train Loss: 0.4821,	Validation Loss: 0.3124,
# 	Early stopping patience counter: 35/40
# Epoch 355/1000,	Train Loss: 0.6100,	Validation Loss: 0.3121,
# 	Early stopping patience counter: 36/40
# Epoch 356/1000,	Train Loss: 0.5326,	Validation Loss: 0.3119,
# 	Early stopping patience counter: 37/40
# Epoch 357/1000,	Train Loss: 0.5049,	Validation Loss: 0.3114,
# 	Early stopping patience counter: 38/40
# Epoch 358/1000,	Train Loss: 0.5487,	Validation Loss: 0.3111,
# 	Early stopping patience counter: 39/40
# Epoch 359/1000,	Train Loss: 0.5821,	Validation Loss: 0.3110,
# 	Early stopping patience counter: 40/40
# 	Early stopping triggered. Stopping training.
# ===================================
#  M O D E L   L O C A T I O N :
# nn_models\mlp_ridge_2025-05-14-08-58-48.pth
# ===================================
#
#
#
# ===================================
#  persons_in_overlap: 12
# ===================================

# %%
plot_shaps(model_ridge, features_ridge)

# %%
print_stats(model_ridge, val_loader_ridge, params)
# Out:
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [12, 8], 'dropout_prob': 0.5, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.0005, 'patience': 40, 'l2_lambda': 0.07}
# Validation Loss:	0.3091
# Mean vizier:		0.9161
# Mean non-vizier:	0.1850
# bottom_3_vizier:	0.9582
# top_3_non_vizier:	0.8326
# PiO Validation:		11

# %% [raw]
# 4 ISSUES
# {'typ': 'ridge', 'batch_size': 256, 'hidden_size': [12, 8], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.005, 'patience': 40}
# Validation Loss:	0.0308
# Mean vizier:		0.9873
# Mean non-vizier:	0.0095
# bottom_3_vizier:	0.9953
# top_3_non_vizier:	0.5943
# PiO Validation:		2

# %% [raw]
# WITHOUT DROPOUT
#
# 1 ISSUE
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40}
# Validation Loss:	0.0840
# Mean vizier:		0.9883
# Mean non-vizier:	0.0638
# bottom_3_vizier:	0.9972
# top_3_non_vizier:	0.7765
# PiO Validation:		0
#
# 2 ISSUES
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [2], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40}
# Validation Loss:	0.0570
# Mean vizier:		0.9920
# Mean non-vizier:	0.0383
# bottom_3_vizier:	0.9980
# top_3_non_vizier:	0.8769
# PiO Validation:		2
#
# 2 ISSUES
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [2], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40}
# Validation Loss:	0.0570
# Mean vizier:		0.9920
# Mean non-vizier:	0.0383
# bottom_3_vizier:	0.9980
# top_3_non_vizier:	0.8769
# PiO Validation:		2
#
# 4 ISSUES
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [8], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40}
# Validation Loss:	0.0577
# Mean vizier:		0.9898
# Mean non-vizier:	0.0318
# bottom_3_vizier:	0.9985
# top_3_non_vizier:	0.9115
# PiO Validation:		4
#
# 1 ISSUE
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [8, 4], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.002, 'patience': 40}
# Validation Loss:	0.0475
# Mean vizier:		0.9923
# Mean non-vizier:	0.0296
# bottom_3_vizier:	0.9985
# top_3_non_vizier:	0.8505
# PiO Validation:		0
#
# 3 ISSUES
# {'typ': 'ridge', 'batch_size': 512, 'hidden_size': [12, 8, 4], 'dropout_prob': 0, 'activation_name': 'relu', 'optimizer_name': 'adam', 'epochs': 1000, 'learning_rate': 0.001, 'patience': 40}
# Validation Loss:	0.0393
# Mean vizier:		0.9893
# Mean non-vizier:	0.0196
# bottom_3_vizier:	0.9872
# top_3_non_vizier:	0.8418
# PiO Validation:		0

# %% [markdown]
# ### Models summary

# %%
# print final_model_list
final_model_dict
# Out:
# {'step': 'nn_models\\mlp_step_2025-05-13-23-35-01.pth',
#  'lasso': 'nn_models\\mlp_lasso_2025-05-13-23-35-52.pth',
#  'ridge': 'nn_models\\mlp_ridge_2025-05-13-23-41-55.pth'}

# %% [raw]
# {'ridge': 'nn_models\\mlp_ridge_2025-04-29-00-31-13.pth',
#  'lasso': 'nn_models\\mlp_lasso_2025-04-28-17-55-15.pth',
#  'step': 'nn_models\\mlp_step_2025-04-28-20-49-51.pth'}
